# %% [markdown]
# #Import Llibraries

# %%
import os



import glob


from IPython.display import Image, display


from IPython import display


display.clear_output()

# %% [markdown]
# #install Urtalytics

# %%
# !pip install ultralytics

# %%
import ultralytics


ultralytics.checks()
# Out:
# Ultralytics YOLOv8.2.18 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 30.0/78.2 GB disk)

# %%
# !mkdir -p content/datasets
# %cd content/datasets
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="dov8RyQjNaY81gQF91bM")
project = rf.workspace("nit-raipur-szo7o").project("hand-landmark-detection-zr3sz")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# /content/content/datasets
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# Dependency ultralytics==8.0.196 is required but found version=8.2.18, to fix: `pip install ultralytics==8.0.196`

# %%
# %cd /content/Hand-Landmark-Detection-1
# Out:
# [Errno 2] No such file or directory: '/content/Hand-Landmark-Detection-1'
# /content/content/datasets

# %%
# !yolo task=detect mode=train model=/content/yolov8s.pt data=/content/content/datasets/Hand-Landmark-Detection-1/data.yaml epochs=150 imgsz=640
# Out:
# Ultralytics YOLOv8.2.18 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
from IPython.display import Image, display

# Path to the image file
image_path = '/content/content/datasets/runs/detect/train/results.png'

# Display the image
display(Image(filename=image_path))

# %%
from IPython.display import Image, display

# Path to the image file
image_path = '/content/content/datasets/runs/detect/train/confusion_matrix_normalized.png'

# Display the image
display(Image(filename=image_path))

# %%
from IPython.display import Image, display

# Path to the image file
image_path = '/content/content/datasets/runs/detect/train/confusion_matrix.png'

# Display the image
display(Image(filename=image_path))

# %%
from IPython.display import Image, display

# Path to the image file
image_path = '/content/content/datasets/runs/detect/train/train_batch1540.jpg'

# Display the image
display(Image(filename=image_path))

# %%
from IPython.display import Image, display

# Path to the image file
image_path = '/content/content/datasets/runs/detect/train/val_batch1_labels.jpg'

# Display the image
display(Image(filename=image_path))
