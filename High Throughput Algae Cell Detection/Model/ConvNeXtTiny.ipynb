# %% [markdown]
# # ConvNeXtTiny Model Transfer Learning

# %%
import os
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt
from tensorflow.keras import layers, models
from tensorflow.keras.applications import ConvNeXtTiny
from tensorflow.keras.optimizers import Adam
import seaborn as sns
import numpy as np
from sklearn.utils.class_weight import compute_class_weight
import pandas as pd

# %%
train_datagen = ImageDataGenerator(
        rescale=1./255)
train_generator = train_datagen.flow_from_directory(
    directory=r"D:\SWOC-2024\DL-Simplified\High Throughput Algae Cell Detection\Dataset\alge_dataset\non_yolo",
    target_size=(71,71),
    color_mode="rgb",
    batch_size=64,
    class_mode="categorical",
    shuffle=True,
    seed=42
)
# Out:
# Found 1758 images belonging to 6 classes.

# %% [markdown]
# ### Class Distribution

# %%
class_indices = train_generator.class_indices

class_names = {v: k for k, v in class_indices.items()}

class_distribution = train_generator.classes

class_names_list = [class_names[class_idx] for class_idx in class_distribution]

# Plot the class distribution using Seaborn
plt.figure(figsize=(10, 5))
sns.countplot(x=class_names_list, palette='viridis')
plt.title('Class Distribution in the Training Dataset')
plt.xlabel('Class')
plt.ylabel('Number of Samples')
plt.xticks(rotation='vertical')
plt.show()

# %%
class_labels = train_generator.classes
class_weights = compute_class_weight(class_weight='balanced', classes=np.unique(class_labels), y=class_labels)

print("Class Weights:", class_weights)
# Out:
# Class Weights: [1.5923913  0.40581717 1.25213675 1.2907489  1.07720588 2.46218487]

# %%
class_weight_dict = {i: class_weights[i] for i in range(len(class_weights))}
class_weight_dict
# Out:
# {0: 1.5923913043478262,
#  1: 0.40581717451523547,
#  2: 1.2521367521367521,
#  3: 1.2907488986784141,
#  4: 1.0772058823529411,
#  5: 2.46218487394958}

# %% [markdown]
# - ##### This inverse proportion from our original distribution indicates Class_weight multiple requires for all class

# %%
class_weights = [1.5923913, 0.40581717, 1.25213675, 1.2907489, 1.07720588, 2.46218487]
class_names_list = ['Class 0', 'Class 1', 'Class 2', 'Class 3', 'Class 4', 'Class 5']

# Create a DataFrame for Seaborn
data = {'Class': class_names_list, 'Weight': class_weights}
df = pd.DataFrame(data)
# Plot the class distribution using Seaborn
plt.figure(figsize=(10, 5))
sns.barplot(x='Class', y='Weight', data=df, palette='viridis')
plt.title('Class Weight Distribution')
plt.xlabel('Class')
plt.ylabel('Class Weight')
plt.xticks(rotation='vertical')
plt.show()

# %% [markdown]
# - Ploting from majority classes which have relatively poor resolution

# %%
for _ in range(10):
    img, label = train_generator.next()
    if (label[0][1]==1):
        plt.imshow(img[0])
    plt.show()

# %%
base_model=ConvNeXtTiny(
    model_name="convnext_tiny",
    include_top=False,
    include_preprocessing=False,
    weights="imagenet",
    input_tensor=None,
    input_shape=(71, 71, 3),
    pooling=None,
    classes=6,
    classifier_activation="softmax",
)

# %%
for layer in base_model.layers:
    layer.trainable = False

# %%
ConvNeXtTiny_learner=models.Sequential([
    base_model,
    layers.GlobalAveragePooling2D(),
    layers.Dense(256, activation='relu'),
    layers.Dropout(0.2),
    layers.Dense(6, activation='softmax')
])

# %%
ConvNeXtTiny_learner.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  convnext_tiny (Functional)  (None, 2, 2, 768)         27820128
#
#  global_average_pooling2d (G  (None, 768)              0
#  lobalAveragePooling2D)
#
#  dense (Dense)               (None, 256)               196864
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_1 (Dense)             (None, 6)                 1542
#
# =================================================================
# Total params: 28,018,534
# Trainable params: 198,406
# Non-trainable params: 27,820,128
# _________________________________________________________________

# %%
METRICS = [
      keras.metrics.Precision(name='precision'),
      keras.metrics.Recall(name='recall'),
      keras.metrics.AUC(name='auc'),
      keras.metrics.AUC(name='prc', curve='PR'), # precision-recall curve
]

# %%
ConvNeXtTiny_learner.compile(
    optimizer=Adam(lr=0.0001),
    loss='categorical_crossentropy',
    metrics=['accuracy', METRICS],
)
# Out:
# c:\Users\arpit\anaconda3\envs\tf\lib\site-packages\keras\optimizers\optimizer_v2\adam.py:114: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)

# %%
ConvNeXtTiny_history=ConvNeXtTiny_learner.fit(train_generator,epochs=100,class_weight=class_weight_dict)
# Out:
# Epoch 1/100
# 28/28 [==============================] - 10s 76ms/step - loss: 1.3943 - accuracy: 0.4937 - precision: 0.6587 - recall: 0.3151 - auc: 0.7886 - prc: 0.5201
# Epoch 2/100
# 28/28 [==============================] - 2s 61ms/step - loss: 0.6697 - accuracy: 0.8180 - precision: 0.8833 - recall: 0.7452 - auc: 0.9627 - prc: 0.8800
# Epoch 3/100
# 28/28 [==============================] - 2s 60ms/step - loss: 0.4903 - accuracy: 0.8680 - precision: 0.9031 - recall: 0.8214 - auc: 0.9752 - prc: 0.9188
# Epoch 4/100
# 28/28 [==============================] - 2s 60ms/step - loss: 0.4255 - accuracy: 0.8879 - precision: 0.9121 - recall: 0.8555 - auc: 0.9789 - prc: 0.9293
# Epoch 5/100
# 28/28 [==============================] - 2s 61ms/step - loss: 0.3947 - accuracy: 0.8982 - precision: 0.9138 - recall: 0.8686 - auc: 0.9815 - prc: 0.9381
# Epoch 6/100
# 28/28 [==============================] - 2s 60ms/step - loss: 0.3537 - accuracy: 0.9050 - precision: 0.9184 - recall: 0.8840 - auc: 0.9837 - prc: 0.9434
# Epoch 7/100
# 28/28 [==============================] - 2s 59ms/step - loss: 0.3332 - accuracy: 0.9164 - precision: 0.9304 - recall: 0.8896 - auc: 0.9855 - prc: 0.9481
# Epoch 8/100
# 28/28 [==============================] - 2s 59ms/step - loss: 0.3099 - accuracy: 0.9170 - precision: 0.9284 - recall: 0.8999 - auc: 0.9862 - prc: 0.9507
# Epoch 9/100
# 28/28 [==============================] - 2s 59ms/step - loss: 0.2809 - accuracy: 0.9249 - precision: 0.9347 - recall: 0.9044 - auc: 0.9891 - prc: 0.9617
# Epoch 10/100
# 28/28 [==============================] - 2s 60ms/step - loss: 0.2816 - accuracy: 0.9187 - precision: 0.9330 - recall: 0.9033 - auc: 0.9886 - prc: 0.9595
# Epoch 11/100
# 28/28 [==============================] - 2s 60ms/step - loss: 0.2498 - accuracy: 0.9317 - precision: 0.9362 - recall: 0.9187 - auc: 0.9910 - prc: 0.9664
# Epoch 12/100
# 28/28 [==============================] - 2s 60ms/step - loss: 0.2507 - accuracy: 0.9272 - precision: 0.9383 - recall: 0.9170 - auc: 0.9916 - prc: 0.9678
# Epoch 13/100
# 28/28 [==============================] - 2s 60ms/step - loss: 0.2299 - accuracy: 0.9403 - precision: 0.9482 - recall: 0.9272 - auc: 0.9926 - prc: 0.9724
# Epoch 14/100
# 28/28 [==============================] - 2s 62ms/step - loss: 0.2262 - accuracy: 0.9329 - precision: 0.9447 - recall: 0.9226 - auc: 0.9927 - prc: 0.9720
# Epoch 15/100
# 28/28 [==============================] - 2s 60ms/step - loss: 0.2180 - accuracy: 0.9397 - precision: 0.9483 - recall: 0.9278 - auc: 0.9923 - prc: 0.9707
# Epoch 16/100
# 28/28 [==============================] - 2s 60ms/step - loss: 0.2075 - accuracy: 0.9408 - precision: 0.9463 - recall: 0.9329 - auc: 0.9935 - prc: 0.9752
# Epoch 17/100
# 28/28 [==============================] - 2s 61ms/step - loss: 0.2073 - accuracy: 0.9374 - precision: 0.9440 - recall: 0.9295 - auc: 0.9938 - prc: 0.9763
# Epoch 18/100
# 28/28 [==============================] - 2s 60ms/step - loss: 0.2075 - accuracy: 0.9403 - precision: 0.9464 - recall: 0.9334 - auc: 0.9933 - prc: 0.9736
# Epoch 19/100
# 28/28 [==============================] - 2s 61ms/step - loss: 0.1914 - accuracy: 0.9443 - precision: 0.9519 - recall: 0.9352 - auc: 0.9946 - prc: 0.9788
# Epoch 20/100
# 28/28 [==============================] - 2s 60ms/step - loss: 0.1770 - accuracy: 0.9499 - precision: 0.9571 - recall: 0.9397 - auc: 0.9950 - prc: 0.9804
# Epoch 21/100
# 28/28 [==============================] - 2s 61ms/step - loss: 0.1790 - accuracy: 0.9465 - precision: 0.9506 - recall: 0.9414 - auc: 0.9940 - prc: 0.9791
# Epoch 22/100
# 28/28 [==============================] - 2s 60ms/step - loss: 0.1676 - accuracy: 0.9505 - precision: 0.9583 - recall: 0.9420 - auc: 0.9955 - prc: 0.9833
# Epoch 23/100
# 28/28 [==============================] - 2s 62ms/step - loss: 0.1636 - accuracy: 0.9477 - precision: 0.9587 - recall: 0.9380 - auc: 0.9957 - prc: 0.9838
# Epoch 24/100
# 28/28 [==============================] - 2s 60ms/step - loss: 0.1688 - accuracy: 0.9465 - precision: 0.9532 - recall: 0.9391 - auc: 0.9956 - prc: 0.9825
# Epoch 25/100
# 28/28 [==============================] - 2s 60ms/step - loss: 0.1518 - accuracy: 0.9494 - precision: 0.9550 - recall: 0.9425 - auc: 0.9953 - prc: 0.9829
# Epoch 26/100
# 28/28 [==============================] - 2s 60ms/step - loss: 0.1558 - accuracy: 0.9499 - precision: 0.9556 - recall: 0.9425 - auc: 0.9955 - prc: 0.9833
# Epoch 27/100
# 28/28 [==============================] - 2s 60ms/step - loss: 0.1531 - accuracy: 0.9534 - precision: 0.9579 - recall: 0.9454 - auc: 0.9958 - prc: 0.9849
# Epoch 28/100
# 28/28 [==============================] - 2s 60ms/step - loss: 0.1390 - accuracy: 0.9556 - precision: 0.9597 - recall: 0.9477 - auc: 0.9959 - prc: 0.9856
# Epoch 29/100
# 28/28 [==============================] - 2s 61ms/step - loss: 0.1424 - accuracy: 0.9545 - precision: 0.9608 - recall: 0.9482 - auc: 0.9966 - prc: 0.9853
# Epoch 30/100
# 28/28 [==============================] - 2s 60ms/step - loss: 0.1488 - accuracy: 0.9608 - precision: 0.9645 - recall: 0.9573 - auc: 0.9960 - prc: 0.9856
# Epoch 31/100
# 28/28 [==============================] - 2s 61ms/step - loss: 0.1411 - accuracy: 0.9585 - precision: 0.9636 - recall: 0.9477 - auc: 0.9963 - prc: 0.9864
# Epoch 32/100
# 28/28 [==============================] - 2s 61ms/step - loss: 0.1337 - accuracy: 0.9562 - precision: 0.9620 - recall: 0.9516 - auc: 0.9957 - prc: 0.9851
# Epoch 33/100
# 28/28 [==============================] - 2s 63ms/step - loss: 0.1337 - accuracy: 0.9596 - precision: 0.9643 - recall: 0.9522 - auc: 0.9966 - prc: 0.9882
# Epoch 34/100
# 28/28 [==============================] - 2s 61ms/step - loss: 0.1254 - accuracy: 0.9647 - precision: 0.9672 - recall: 0.9556 - auc: 0.9965 - prc: 0.9870
# Epoch 35/100
# 28/28 [==============================] - 2s 60ms/step - loss: 0.1240 - accuracy: 0.9630 - precision: 0.9651 - recall: 0.9596 - auc: 0.9962 - prc: 0.9876
# Epoch 36/100
# 28/28 [==============================] - 2s 62ms/step - loss: 0.1262 - accuracy: 0.9613 - precision: 0.9677 - recall: 0.9551 - auc: 0.9972 - prc: 0.9892
# Epoch 37/100
# 28/28 [==============================] - 2s 61ms/step - loss: 0.1185 - accuracy: 0.9653 - precision: 0.9690 - recall: 0.9608 - auc: 0.9974 - prc: 0.9902
# Epoch 38/100
# 28/28 [==============================] - 2s 61ms/step - loss: 0.1228 - accuracy: 0.9590 - precision: 0.9615 - recall: 0.9522 - auc: 0.9968 - prc: 0.9881
# Epoch 39/100
# 28/28 [==============================] - 2s 63ms/step - loss: 0.1226 - accuracy: 0.9630 - precision: 0.9678 - recall: 0.9573 - auc: 0.9971 - prc: 0.9888
# Epoch 40/100
# 28/28 [==============================] - 2s 66ms/step - loss: 0.1118 - accuracy: 0.9664 - precision: 0.9702 - recall: 0.9625 - auc: 0.9976 - prc: 0.9908
# Epoch 41/100
# 28/28 [==============================] - 2s 63ms/step - loss: 0.1008 - accuracy: 0.9750 - precision: 0.9782 - recall: 0.9704 - auc: 0.9982 - prc: 0.9924
# Epoch 42/100
# 28/28 [==============================] - 2s 65ms/step - loss: 0.1105 - accuracy: 0.9653 - precision: 0.9706 - recall: 0.9573 - auc: 0.9973 - prc: 0.9897
# Epoch 43/100
# 28/28 [==============================] - 2s 65ms/step - loss: 0.1034 - accuracy: 0.9704 - precision: 0.9731 - recall: 0.9653 - auc: 0.9978 - prc: 0.9915
# Epoch 44/100
# 28/28 [==============================] - 2s 66ms/step - loss: 0.1090 - accuracy: 0.9676 - precision: 0.9697 - recall: 0.9659 - auc: 0.9972 - prc: 0.9893
# Epoch 45/100
# 28/28 [==============================] - 2s 68ms/step - loss: 0.1034 - accuracy: 0.9716 - precision: 0.9736 - recall: 0.9664 - auc: 0.9980 - prc: 0.9918
# Epoch 46/100
# 28/28 [==============================] - 2s 65ms/step - loss: 0.0987 - accuracy: 0.9681 - precision: 0.9736 - recall: 0.9647 - auc: 0.9977 - prc: 0.9921
# Epoch 47/100
# 28/28 [==============================] - 2s 65ms/step - loss: 0.0982 - accuracy: 0.9693 - precision: 0.9724 - recall: 0.9630 - auc: 0.9972 - prc: 0.9907
# Epoch 48/100
# 28/28 [==============================] - 2s 65ms/step - loss: 0.0955 - accuracy: 0.9721 - precision: 0.9753 - recall: 0.9670 - auc: 0.9979 - prc: 0.9923
# Epoch 49/100
# 28/28 [==============================] - 2s 65ms/step - loss: 0.0949 - accuracy: 0.9716 - precision: 0.9771 - recall: 0.9693 - auc: 0.9977 - prc: 0.9924
# Epoch 50/100
# 28/28 [==============================] - 2s 66ms/step - loss: 0.0948 - accuracy: 0.9727 - precision: 0.9764 - recall: 0.9659 - auc: 0.9980 - prc: 0.9921
# Epoch 51/100
# 28/28 [==============================] - 2s 66ms/step - loss: 0.0915 - accuracy: 0.9767 - precision: 0.9777 - recall: 0.9716 - auc: 0.9987 - prc: 0.9943
# Epoch 52/100
# 28/28 [==============================] - 2s 67ms/step - loss: 0.0934 - accuracy: 0.9750 - precision: 0.9754 - recall: 0.9710 - auc: 0.9982 - prc: 0.9933
# Epoch 53/100
# 28/28 [==============================] - 2s 66ms/step - loss: 0.0897 - accuracy: 0.9699 - precision: 0.9748 - recall: 0.9687 - auc: 0.9980 - prc: 0.9926
# Epoch 54/100
# 28/28 [==============================] - 2s 66ms/step - loss: 0.0875 - accuracy: 0.9778 - precision: 0.9799 - recall: 0.9727 - auc: 0.9985 - prc: 0.9943
# Epoch 55/100
# 28/28 [==============================] - 2s 67ms/step - loss: 0.0839 - accuracy: 0.9761 - precision: 0.9810 - recall: 0.9716 - auc: 0.9983 - prc: 0.9942
# Epoch 56/100
# 28/28 [==============================] - 2s 66ms/step - loss: 0.0826 - accuracy: 0.9772 - precision: 0.9789 - recall: 0.9755 - auc: 0.9984 - prc: 0.9943
# Epoch 57/100
# 28/28 [==============================] - 2s 66ms/step - loss: 0.0821 - accuracy: 0.9755 - precision: 0.9794 - recall: 0.9733 - auc: 0.9981 - prc: 0.9932
# Epoch 58/100
# 28/28 [==============================] - 2s 66ms/step - loss: 0.0765 - accuracy: 0.9755 - precision: 0.9783 - recall: 0.9755 - auc: 0.9984 - prc: 0.9951
# Epoch 59/100
# 28/28 [==============================] - 2s 65ms/step - loss: 0.0772 - accuracy: 0.9795 - precision: 0.9823 - recall: 0.9772 - auc: 0.9984 - prc: 0.9947
# Epoch 60/100
# 28/28 [==============================] - 2s 65ms/step - loss: 0.0813 - accuracy: 0.9755 - precision: 0.9777 - recall: 0.9721 - auc: 0.9983 - prc: 0.9947
# Epoch 61/100
# 28/28 [==============================] - 2s 65ms/step - loss: 0.0760 - accuracy: 0.9818 - precision: 0.9839 - recall: 0.9755 - auc: 0.9983 - prc: 0.9941
# Epoch 62/100
# 28/28 [==============================] - 2s 65ms/step - loss: 0.0713 - accuracy: 0.9795 - precision: 0.9817 - recall: 0.9738 - auc: 0.9991 - prc: 0.9962
# Epoch 63/100
# 28/28 [==============================] - 2s 65ms/step - loss: 0.0728 - accuracy: 0.9784 - precision: 0.9805 - recall: 0.9744 - auc: 0.9987 - prc: 0.9953
# Epoch 64/100
# 28/28 [==============================] - 2s 65ms/step - loss: 0.0694 - accuracy: 0.9807 - precision: 0.9818 - recall: 0.9795 - auc: 0.9988 - prc: 0.9957
# Epoch 65/100
# 28/28 [==============================] - 2s 65ms/step - loss: 0.0638 - accuracy: 0.9835 - precision: 0.9851 - recall: 0.9795 - auc: 0.9984 - prc: 0.9959
# Epoch 66/100
# 28/28 [==============================] - 2s 68ms/step - loss: 0.0738 - accuracy: 0.9772 - precision: 0.9822 - recall: 0.9716 - auc: 0.9985 - prc: 0.9952
# Epoch 67/100
# 28/28 [==============================] - 2s 66ms/step - loss: 0.0669 - accuracy: 0.9801 - precision: 0.9822 - recall: 0.9744 - auc: 0.9989 - prc: 0.9961
# Epoch 68/100
# 28/28 [==============================] - 2s 66ms/step - loss: 0.0645 - accuracy: 0.9795 - precision: 0.9829 - recall: 0.9784 - auc: 0.9992 - prc: 0.9963
# Epoch 69/100
# 28/28 [==============================] - 2s 68ms/step - loss: 0.0651 - accuracy: 0.9818 - precision: 0.9829 - recall: 0.9801 - auc: 0.9986 - prc: 0.9958
# Epoch 70/100
# 28/28 [==============================] - 2s 66ms/step - loss: 0.0662 - accuracy: 0.9818 - precision: 0.9834 - recall: 0.9784 - auc: 0.9989 - prc: 0.9963
# Epoch 71/100
# 28/28 [==============================] - 2s 64ms/step - loss: 0.0632 - accuracy: 0.9801 - precision: 0.9828 - recall: 0.9778 - auc: 0.9994 - prc: 0.9971
# Epoch 72/100
# 28/28 [==============================] - 2s 62ms/step - loss: 0.0664 - accuracy: 0.9812 - precision: 0.9845 - recall: 0.9784 - auc: 0.9992 - prc: 0.9966
# Epoch 73/100
# 28/28 [==============================] - 2s 60ms/step - loss: 0.0665 - accuracy: 0.9824 - precision: 0.9845 - recall: 0.9784 - auc: 0.9990 - prc: 0.9964
# Epoch 74/100
# 28/28 [==============================] - 2s 61ms/step - loss: 0.0615 - accuracy: 0.9795 - precision: 0.9806 - recall: 0.9790 - auc: 0.9991 - prc: 0.9971
# Epoch 75/100
# 28/28 [==============================] - 2s 62ms/step - loss: 0.0637 - accuracy: 0.9812 - precision: 0.9840 - recall: 0.9784 - auc: 0.9992 - prc: 0.9966
# Epoch 76/100
# 28/28 [==============================] - 2s 61ms/step - loss: 0.0599 - accuracy: 0.9795 - precision: 0.9829 - recall: 0.9790 - auc: 0.9992 - prc: 0.9966
# Epoch 77/100
# 28/28 [==============================] - 2s 61ms/step - loss: 0.0590 - accuracy: 0.9835 - precision: 0.9846 - recall: 0.9829 - auc: 0.9991 - prc: 0.9970
# Epoch 78/100
# 28/28 [==============================] - 2s 61ms/step - loss: 0.0581 - accuracy: 0.9829 - precision: 0.9829 - recall: 0.9795 - auc: 0.9991 - prc: 0.9970
# Epoch 79/100
# 28/28 [==============================] - 2s 61ms/step - loss: 0.0568 - accuracy: 0.9852 - precision: 0.9868 - recall: 0.9818 - auc: 0.9994 - prc: 0.9974
# Epoch 80/100
# 28/28 [==============================] - 2s 61ms/step - loss: 0.0564 - accuracy: 0.9841 - precision: 0.9869 - recall: 0.9829 - auc: 0.9994 - prc: 0.9974
# Epoch 81/100
# 28/28 [==============================] - 2s 61ms/step - loss: 0.0595 - accuracy: 0.9835 - precision: 0.9857 - recall: 0.9807 - auc: 0.9987 - prc: 0.9959
# Epoch 82/100
# 28/28 [==============================] - 2s 61ms/step - loss: 0.0575 - accuracy: 0.9852 - precision: 0.9863 - recall: 0.9824 - auc: 0.9994 - prc: 0.9972
# Epoch 83/100
# 28/28 [==============================] - 2s 61ms/step - loss: 0.0529 - accuracy: 0.9869 - precision: 0.9880 - recall: 0.9852 - auc: 0.9994 - prc: 0.9974
# Epoch 84/100
# 28/28 [==============================] - 2s 62ms/step - loss: 0.0523 - accuracy: 0.9852 - precision: 0.9891 - recall: 0.9841 - auc: 0.9996 - prc: 0.9979
# Epoch 85/100
# 28/28 [==============================] - 2s 64ms/step - loss: 0.0522 - accuracy: 0.9858 - precision: 0.9886 - recall: 0.9846 - auc: 0.9996 - prc: 0.9982
# Epoch 86/100
# 28/28 [==============================] - 2s 62ms/step - loss: 0.0522 - accuracy: 0.9824 - precision: 0.9829 - recall: 0.9795 - auc: 0.9994 - prc: 0.9975
# Epoch 87/100
# 28/28 [==============================] - 2s 62ms/step - loss: 0.0556 - accuracy: 0.9818 - precision: 0.9823 - recall: 0.9801 - auc: 0.9995 - prc: 0.9977
# Epoch 88/100
# 28/28 [==============================] - 2s 61ms/step - loss: 0.0515 - accuracy: 0.9835 - precision: 0.9846 - recall: 0.9807 - auc: 0.9996 - prc: 0.9982
# Epoch 89/100
# 28/28 [==============================] - 2s 62ms/step - loss: 0.0496 - accuracy: 0.9852 - precision: 0.9858 - recall: 0.9841 - auc: 0.9996 - prc: 0.9983
# Epoch 90/100
# 28/28 [==============================] - 2s 62ms/step - loss: 0.0492 - accuracy: 0.9875 - precision: 0.9892 - recall: 0.9858 - auc: 0.9996 - prc: 0.9983
# Epoch 91/100
# 28/28 [==============================] - 2s 63ms/step - loss: 0.0478 - accuracy: 0.9863 - precision: 0.9880 - recall: 0.9829 - auc: 0.9997 - prc: 0.9985
# Epoch 92/100
# 28/28 [==============================] - 2s 62ms/step - loss: 0.0483 - accuracy: 0.9858 - precision: 0.9874 - recall: 0.9841 - auc: 0.9996 - prc: 0.9981
# Epoch 93/100
# 28/28 [==============================] - 2s 62ms/step - loss: 0.0460 - accuracy: 0.9858 - precision: 0.9863 - recall: 0.9858 - auc: 0.9996 - prc: 0.9982
# Epoch 94/100
# 28/28 [==============================] - 2s 63ms/step - loss: 0.0465 - accuracy: 0.9846 - precision: 0.9886 - recall: 0.9835 - auc: 0.9996 - prc: 0.9980
# Epoch 95/100
# 28/28 [==============================] - 2s 63ms/step - loss: 0.0436 - accuracy: 0.9881 - precision: 0.9897 - recall: 0.9863 - auc: 0.9997 - prc: 0.9987
# Epoch 96/100
# 28/28 [==============================] - 2s 62ms/step - loss: 0.0450 - accuracy: 0.9852 - precision: 0.9874 - recall: 0.9824 - auc: 0.9996 - prc: 0.9983
# Epoch 97/100
# 28/28 [==============================] - 2s 61ms/step - loss: 0.0475 - accuracy: 0.9846 - precision: 0.9869 - recall: 0.9846 - auc: 0.9995 - prc: 0.9977
# Epoch 98/100
# 28/28 [==============================] - 2s 60ms/step - loss: 0.0474 - accuracy: 0.9869 - precision: 0.9886 - recall: 0.9858 - auc: 0.9997 - prc: 0.9986
# Epoch 99/100
# 28/28 [==============================] - 2s 62ms/step - loss: 0.0412 - accuracy: 0.9892 - precision: 0.9909 - recall: 0.9886 - auc: 0.9997 - prc: 0.9987
# Epoch 100/100
# 28/28 [==============================] - 2s 60ms/step - loss: 0.0448 - accuracy: 0.9875 - precision: 0.9892 - recall: 0.9858 - auc: 0.9996 - prc: 0.9983

# %%
df=pd.DataFrame(ConvNeXtTiny_history.history)
df.to_csv("ConvNeXtTiny_plot.csv",index=False)

# %%
# Plot training history for multiple metrics
plt.figure(figsize=(16, 8))

# Plot training & validation accuracy values
plt.subplot(2, 3, 1)
plt.plot(ConvNeXtTiny_history.history['accuracy'])
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Train'], loc='upper left')

# Plot training & validation loss values
plt.subplot(2, 3, 2)
plt.plot(ConvNeXtTiny_history.history['loss'])
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train'], loc='upper left')

# Plot training & validation precision values
plt.subplot(2, 3, 3)
plt.plot(ConvNeXtTiny_history.history['precision'])
plt.title('Model Precision')
plt.xlabel('Epoch')
plt.ylabel('Precision')
plt.legend(['Train'], loc='upper left')

# Plot training & validation recall values
plt.subplot(2, 3, 4)
plt.plot(ConvNeXtTiny_history.history['recall'])
plt.title('Model Recall')
plt.xlabel('Epoch')
plt.ylabel('Recall')
plt.legend(['Train'], loc='upper left')

# Plot training & validation AUC values
plt.subplot(2, 3, 5)
plt.plot(ConvNeXtTiny_history.history['auc'])
plt.title('Model AUC')
plt.xlabel('Epoch')
plt.ylabel('AUC')
plt.legend(['Train'], loc='upper left')

# Plot training & validation PRC values
plt.subplot(2, 3, 6)
plt.plot(ConvNeXtTiny_history.history['prc'])
plt.title('Model PRC')
plt.xlabel('Epoch')
plt.ylabel('PRC')
plt.legend(['Train'], loc='upper left')

plt.tight_layout()
plt.show()
