# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv(r"/Users/aryanverma/Downloads/owid-covid-data.csv")
# Out:
# /var/folders/l4/m0529sp123ncwq4hm1qccy180000gn/T/ipykernel_2964/1531085969.py:1: DtypeWarning: Columns (34) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv(r"/Users/aryanverma/Downloads/owid-covid-data.csv")

# %%
data
# Out:
#        iso_code continent     location      date  population_density  \
# 0           AFG      Asia  Afghanistan  03/01/20              54.422
# 1           AFG      Asia  Afghanistan  04/01/20              54.422
# 2           AFG      Asia  Afghanistan  05/01/20              54.422
# 3           AFG      Asia  Afghanistan  06/01/20              54.422
# 4           AFG      Asia  Afghanistan  07/01/20              54.422
# ...         ...       ...          ...       ...                 ...
# 311505      ZWE    Africa     Zimbabwe  13/05/23              42.729
# 311506      ZWE    Africa     Zimbabwe  14/05/23              42.729
# 311507      ZWE    Africa     Zimbabwe  15/05/23              42.729
# 311508      ZWE    Africa     Zimbabwe  16/05/23              42.729
# 311509      ZWE    Africa     Zimbabwe  17/05/23              42.729
#
#         total_cases  new_cases  new_cases_smoothed  total_deaths  new_deaths  \
# ...

# %%
data.head()
# Out:
#   iso_code continent     location      date  population_density  total_cases  \
# 0      AFG      Asia  Afghanistan  03/01/20              54.422          NaN
# 1      AFG      Asia  Afghanistan  04/01/20              54.422          NaN
# 2      AFG      Asia  Afghanistan  05/01/20              54.422          NaN
# 3      AFG      Asia  Afghanistan  06/01/20              54.422          NaN
# 4      AFG      Asia  Afghanistan  07/01/20              54.422          NaN
#
#    new_cases  new_cases_smoothed  total_deaths  new_deaths  ...  \
# 0        0.0                 NaN           NaN         0.0  ...
# 1        0.0                 NaN           NaN         0.0  ...
# 2        0.0                 NaN           NaN         0.0  ...
# 3        0.0                 NaN           NaN         0.0  ...
# 4        0.0                 NaN           NaN         0.0  ...
#
#    female_smokers  male_smokers  handwashing_facilities  \
# 0             NaN           NaN                  37.746
# ...

# %%
data.columns
# Out:
# Index(['iso_code', 'continent', 'location', 'date', 'population_density',
#        'total_cases', 'new_cases', 'new_cases_smoothed', 'total_deaths',
#        'new_deaths', 'new_deaths_smoothed', 'total_cases_per_million',
#        'new_cases_per_million', 'new_cases_smoothed_per_million',
#        'total_deaths_per_million', 'new_deaths_per_million',
#        'new_deaths_smoothed_per_million', 'reproduction_rate', 'icu_patients',
#        'icu_patients_per_million', 'hosp_patients',
#        'hosp_patients_per_million', 'weekly_icu_admissions',
#        'weekly_icu_admissions_per_million', 'weekly_hosp_admissions',
#        'weekly_hosp_admissions_per_million', 'total_tests', 'new_tests',
#        'total_tests_per_thousand', 'new_tests_per_thousand',
#        'new_tests_smoothed', 'new_tests_smoothed_per_thousand',
#        'positive_rate', 'tests_per_case', 'tests_units', 'total_vaccinations',
#        'people_vaccinated', 'people_fully_vaccinated', 'total_boosters',
# ...

# %%
data
# Out:
#        iso_code continent     location      date  population_density  \
# 0           AFG      Asia  Afghanistan  03/01/20              54.422
# 1           AFG      Asia  Afghanistan  04/01/20              54.422
# 2           AFG      Asia  Afghanistan  05/01/20              54.422
# 3           AFG      Asia  Afghanistan  06/01/20              54.422
# 4           AFG      Asia  Afghanistan  07/01/20              54.422
# ...         ...       ...          ...       ...                 ...
# 311505      ZWE    Africa     Zimbabwe  13/05/23              42.729
# 311506      ZWE    Africa     Zimbabwe  14/05/23              42.729
# 311507      ZWE    Africa     Zimbabwe  15/05/23              42.729
# 311508      ZWE    Africa     Zimbabwe  16/05/23              42.729
# 311509      ZWE    Africa     Zimbabwe  17/05/23              42.729
#
#         total_cases  new_cases  new_cases_smoothed  total_deaths  new_deaths  \
# ...

# %%
data.isnull().sum()
# Out:
# iso_code                                     0
# continent                                14827
# location                                     0
# date                                         0
# population_density                       47190
#                                          ...
# human_development_index                  77534
# population                                   0
# excess_mortality_cumulative_absolute    300841
# excess_mortality_cumulative             300841
# excess_mortality                        300841
# Length: 66, dtype: int64

# %%
data.columns
# Out:
# Index(['iso_code', 'continent', 'location', 'date', 'population_density',
#        'total_cases', 'new_cases', 'new_cases_smoothed', 'total_deaths',
#        'new_deaths', 'new_deaths_smoothed', 'total_cases_per_million',
#        'new_cases_per_million', 'new_cases_smoothed_per_million',
#        'total_deaths_per_million', 'new_deaths_per_million',
#        'new_deaths_smoothed_per_million', 'reproduction_rate', 'icu_patients',
#        'icu_patients_per_million', 'hosp_patients',
#        'hosp_patients_per_million', 'weekly_icu_admissions',
#        'weekly_icu_admissions_per_million', 'weekly_hosp_admissions',
#        'weekly_hosp_admissions_per_million', 'total_tests', 'new_tests',
#        'total_tests_per_thousand', 'new_tests_per_thousand',
#        'new_tests_smoothed', 'new_tests_smoothed_per_thousand',
#        'positive_rate', 'tests_per_case', 'tests_units', 'total_vaccinations',
#        'people_vaccinated', 'people_fully_vaccinated', 'total_boosters',
# ...

# %%
sns.relplot(x="total_cases",y="people_vaccinated",data=data)

# %%
sns.relplot(x="total_cases",y="total_deaths",data=data)

# %%
sns.relplot(x="new_tests_smoothed",y="new_vaccinations_smoothed",data=data)

# %%
data.columns
# Out:
# Index(['iso_code', 'continent', 'location', 'date', 'population_density',
#        'total_cases', 'new_cases', 'new_cases_smoothed', 'total_deaths',
#        'new_deaths', 'new_deaths_smoothed', 'total_cases_per_million',
#        'new_cases_per_million', 'new_cases_smoothed_per_million',
#        'total_deaths_per_million', 'new_deaths_per_million',
#        'new_deaths_smoothed_per_million', 'reproduction_rate', 'icu_patients',
#        'icu_patients_per_million', 'hosp_patients',
#        'hosp_patients_per_million', 'weekly_icu_admissions',
#        'weekly_icu_admissions_per_million', 'weekly_hosp_admissions',
#        'weekly_hosp_admissions_per_million', 'total_tests', 'new_tests',
#        'total_tests_per_thousand', 'new_tests_per_thousand',
#        'new_tests_smoothed', 'new_tests_smoothed_per_thousand',
#        'positive_rate', 'tests_per_case', 'tests_units', 'total_vaccinations',
#        'people_vaccinated', 'people_fully_vaccinated', 'total_boosters',
# ...

# %%
sns.relplot(x='extreme_poverty',y='gdp_per_capita',kind='line',data=data)

# %%
sns.catplot(x='extreme_poverty',y='gdp_per_capita',data=data)
