# %%
import numpy as np
import pandas as pd
from pathlib import Path

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split

import tensorflow as tf

from sklearn.metrics import confusion_matrix, classification_report

# %%
data = pd.read_csv(r"C:\Users\hp\Desktop\Honey Bee Pollen Detection\PollenDataset\pollen_data.csv",usecols=['filename', 'pollen_carrying'])

# %%
data
# Out:
#              filename  pollen_carrying
# 0     P10057-125r.jpg                1
# 1     P57380-120r.jpg                1
# 2    NP63671-221r.jpg                0
# 3     NP53776-47r.jpg                0
# 4    NP13382-201r.jpg                0
# ..                ...              ...
# 709  NP64239-233r.jpg                0
# 710  NP10304-132r.jpg                0
# 711  NP28671-238r.jpg                0
# 712   P14163-218r.jpg                1
# 713    NP1768-11r.jpg                0
#
# [714 rows x 2 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 714 entries, 0 to 713
# Data columns (total 2 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   filename         714 non-null    object
#  1   pollen_carrying  714 non-null    int64
# dtypes: int64(1), object(1)
# memory usage: 11.3+ KB

# %%
import os

path = os.path.join(r"C:\Users\hp\Desktop\Honey Bee Pollen Detection\PollenDataset\images", 'P10057-125r.jpg')

# %%
def preprocess_df(df, image_path):
    df = df.copy()
    
    # Change filenames into filepaths
    df['filename'] = df['filename'].apply(lambda x: image_path / Path(x)).astype(str)
    
    # Create text labels for the images
    df['pollen_carrying'] = df['pollen_carrying'].replace({0: "NO POLLEN", 1: "POLLEN"})
    
    # Train-test split
    train_df, test_df = train_test_split(df, train_size=0.7, shuffle=True, random_state=1)
    
    return train_df, test_df

# %%
train_df, test_df = preprocess_df(data, image_path=(r"C:\Users\hp\Desktop\Honey Bee Pollen Detection\PollenDataset\images"))

# %%
train_df
# Out:
#                                               filename pollen_carrying
# 507  C:\Users\hp\Desktop\Honey Bee Pollen Detection...          POLLEN
# 346  C:\Users\hp\Desktop\Honey Bee Pollen Detection...       NO POLLEN
# 160  C:\Users\hp\Desktop\Honey Bee Pollen Detection...          POLLEN
# 463  C:\Users\hp\Desktop\Honey Bee Pollen Detection...       NO POLLEN
# 432  C:\Users\hp\Desktop\Honey Bee Pollen Detection...          POLLEN
# ..                                                 ...             ...
# 144  C:\Users\hp\Desktop\Honey Bee Pollen Detection...          POLLEN
# 645  C:\Users\hp\Desktop\Honey Bee Pollen Detection...       NO POLLEN
# 72   C:\Users\hp\Desktop\Honey Bee Pollen Detection...          POLLEN
# 235  C:\Users\hp\Desktop\Honey Bee Pollen Detection...       NO POLLEN
# 37   C:\Users\hp\Desktop\Honey Bee Pollen Detection...          POLLEN
#
# [499 rows x 2 columns]

# %%
train_generator = tf.keras.preprocessing.image.ImageDataGenerator(
    rescale=1./255,
    validation_split=0.2
)

test_generator = tf.keras.preprocessing.image.ImageDataGenerator(
    rescale=1./255
)

# %%
train_images = train_generator.flow_from_dataframe(
    dataframe=train_df,
    x_col='filename',
    y_col='pollen_carrying',
    target_size=(224, 224),
    color_mode='rgb',
    class_mode='binary',
    batch_size=32,
    shuffle=True,
    seed=42,
    subset='training'
)

val_images = train_generator.flow_from_dataframe(
    dataframe=train_df,
    x_col='filename',
    y_col='pollen_carrying',
    target_size=(224, 224),
    color_mode='rgb',
    class_mode='binary',
    batch_size=32,
    shuffle=True,
    seed=42,
    subset='validation'
)

test_images = test_generator.flow_from_dataframe(
    dataframe=test_df,
    x_col='filename',
    y_col='pollen_carrying',
    target_size=(224, 224),
    color_mode='rgb',
    class_mode='binary',
    batch_size=32,
    shuffle=False
)
# Out:
# Found 400 validated image filenames belonging to 2 classes.
# Found 99 validated image filenames belonging to 2 classes.
# Found 215 validated image filenames belonging to 2 classes.

# %%
inputs = tf.keras.Input(shape=(224, 224, 3))
x = tf.keras.layers.Conv2D(filters=16, kernel_size=(3, 3), activation='relu')(inputs)
x = tf.keras.layers.MaxPool2D()(x)
x = tf.keras.layers.Conv2D(filters=32, kernel_size=(3, 3), activation='relu')(x)
x = tf.keras.layers.MaxPool2D()(x)
x = tf.keras.layers.GlobalAveragePooling2D()(x)
x = tf.keras.layers.Dense(128, activation='relu')(x)
x = tf.keras.layers.Dense(128, activation='relu')(x)
outputs = tf.keras.layers.Dense(1, activation='sigmoid')(x)

model = tf.keras.Model(inputs=inputs, outputs=outputs)

model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)
history = model.fit(
    train_images,
    validation_data=val_images,
    epochs=100,
    callbacks=[
        tf.keras.callbacks.EarlyStopping(
            monitor='val_loss',
            patience=5,
            restore_best_weights=True
        )
    ]
)
# Out:
# Epoch 1/100
# 13/13 [==============================] - 35s 2s/step - loss: 0.6932 - accuracy: 0.5250 - val_loss: 0.6978 - val_accuracy: 0.4545
# Epoch 2/100
# 13/13 [==============================] - 25s 2s/step - loss: 0.6925 - accuracy: 0.5275 - val_loss: 0.7003 - val_accuracy: 0.4545
# Epoch 3/100
# 13/13 [==============================] - 28s 2s/step - loss: 0.6907 - accuracy: 0.5275 - val_loss: 0.6937 - val_accuracy: 0.4545
# Epoch 4/100
# 13/13 [==============================] - 25s 2s/step - loss: 0.6934 - accuracy: 0.5275 - val_loss: 0.6980 - val_accuracy: 0.4545
# Epoch 5/100
# 13/13 [==============================] - 26s 2s/step - loss: 0.6888 - accuracy: 0.5275 - val_loss: 0.6930 - val_accuracy: 0.4545
# Epoch 6/100
# 13/13 [==============================] - 28s 2s/step - loss: 0.6860 - accuracy: 0.5275 - val_loss: 0.6906 - val_accuracy: 0.4545
# Epoch 7/100
# 13/13 [==============================] - 26s 2s/step - loss: 0.6821 - accuracy: 0.5825 - val_loss: 0.6789 - val_accuracy: 0.7778
# Epoch 8/100
# 13/13 [==============================] - 26s 2s/step - loss: 0.6687 - accuracy: 0.6625 - val_loss: 0.6735 - val_accuracy: 0.5152
# Epoch 9/100
# 13/13 [==============================] - 25s 2s/step - loss: 0.6491 - accuracy: 0.7075 - val_loss: 0.6320 - val_accuracy: 0.7677
# Epoch 10/100
# 13/13 [==============================] - 28s 2s/step - loss: 0.6304 - accuracy: 0.6875 - val_loss: 0.6440 - val_accuracy: 0.5859
# Epoch 11/100
# 13/13 [==============================] - 24s 2s/step - loss: 0.6080 - accuracy: 0.6900 - val_loss: 0.5637 - val_accuracy: 0.7475
# Epoch 12/100
# 13/13 [==============================] - 25s 2s/step - loss: 0.5675 - accuracy: 0.7100 - val_loss: 0.5261 - val_accuracy: 0.7879
# Epoch 13/100
# 13/13 [==============================] - 24s 2s/step - loss: 0.5407 - accuracy: 0.7400 - val_loss: 0.5804 - val_accuracy: 0.6768
# Epoch 14/100
# 13/13 [==============================] - 26s 2s/step - loss: 0.4999 - accuracy: 0.8000 - val_loss: 0.5110 - val_accuracy: 0.7475
# Epoch 15/100
# 13/13 [==============================] - 27s 2s/step - loss: 0.4653 - accuracy: 0.8100 - val_loss: 0.4616 - val_accuracy: 0.7879
# Epoch 16/100
# 13/13 [==============================] - 25s 2s/step - loss: 0.4555 - accuracy: 0.7975 - val_loss: 0.4307 - val_accuracy: 0.7879
# Epoch 17/100
# 13/13 [==============================] - 25s 2s/step - loss: 0.4470 - accuracy: 0.8050 - val_loss: 0.4179 - val_accuracy: 0.7980
# Epoch 18/100
# 13/13 [==============================] - 25s 2s/step - loss: 0.4294 - accuracy: 0.8325 - val_loss: 0.4226 - val_accuracy: 0.7879
# Epoch 19/100
# 13/13 [==============================] - 25s 2s/step - loss: 0.4244 - accuracy: 0.8325 - val_loss: 0.4585 - val_accuracy: 0.7475
# Epoch 20/100
# 13/13 [==============================] - 27s 2s/step - loss: 0.4189 - accuracy: 0.8150 - val_loss: 0.4599 - val_accuracy: 0.7475
# Epoch 21/100
# 13/13 [==============================] - 26s 2s/step - loss: 0.4055 - accuracy: 0.8425 - val_loss: 0.4736 - val_accuracy: 0.7677
# Epoch 22/100
# 13/13 [==============================] - 26s 2s/step - loss: 0.3923 - accuracy: 0.8275 - val_loss: 0.4131 - val_accuracy: 0.7677
# Epoch 23/100
# 13/13 [==============================] - 26s 2s/step - loss: 0.4087 - accuracy: 0.8225 - val_loss: 0.5435 - val_accuracy: 0.7273
# Epoch 24/100
# 13/13 [==============================] - 24s 2s/step - loss: 0.4061 - accuracy: 0.8350 - val_loss: 0.4002 - val_accuracy: 0.7778
# Epoch 25/100
# 13/13 [==============================] - 26s 2s/step - loss: 0.3999 - accuracy: 0.8300 - val_loss: 0.4396 - val_accuracy: 0.7677
# Epoch 26/100
# 13/13 [==============================] - 25s 2s/step - loss: 0.3988 - accuracy: 0.8275 - val_loss: 0.4576 - val_accuracy: 0.7677
# Epoch 27/100
# 13/13 [==============================] - 26s 2s/step - loss: 0.3961 - accuracy: 0.8350 - val_loss: 0.4019 - val_accuracy: 0.7879
# Epoch 28/100
# 13/13 [==============================] - 25s 2s/step - loss: 0.4060 - accuracy: 0.8300 - val_loss: 0.4820 - val_accuracy: 0.7677
# Epoch 29/100
# 13/13 [==============================] - 27s 2s/step - loss: 0.4145 - accuracy: 0.8225 - val_loss: 0.3986 - val_accuracy: 0.7677
# Epoch 30/100
# 13/13 [==============================] - 24s 2s/step - loss: 0.4440 - accuracy: 0.8025 - val_loss: 0.5022 - val_accuracy: 0.7677
# Epoch 31/100
# 13/13 [==============================] - 33s 3s/step - loss: 0.3916 - accuracy: 0.8300 - val_loss: 0.3985 - val_accuracy: 0.7778
# Epoch 32/100
# 13/13 [==============================] - 33s 3s/step - loss: 0.3792 - accuracy: 0.8400 - val_loss: 0.4367 - val_accuracy: 0.7677
# Epoch 33/100
# 13/13 [==============================] - 34s 3s/step - loss: 0.3664 - accuracy: 0.8475 - val_loss: 0.4101 - val_accuracy: 0.7475
# Epoch 34/100
# 13/13 [==============================] - 33s 3s/step - loss: 0.3690 - accuracy: 0.8375 - val_loss: 0.4257 - val_accuracy: 0.7677
# Epoch 35/100
# 13/13 [==============================] - 36s 3s/step - loss: 0.3844 - accuracy: 0.8250 - val_loss: 0.5862 - val_accuracy: 0.7374
# Epoch 36/100
# 13/13 [==============================] - 33s 3s/step - loss: 0.4038 - accuracy: 0.8200 - val_loss: 0.4183 - val_accuracy: 0.7677

# %%
results = model.evaluate(test_images, verbose=0)
print("Accuracy: {:.2f}%".format(results[1] * 100))

predictions = np.squeeze(model.predict(test_images) >= 0.5).astype(np.int)

cm = confusion_matrix(test_images.labels, predictions, labels=[0, 1])
clr = classification_report(test_images.labels, predictions, labels=[0, 1], target_names=["NO POLLEN", "POLLEN"])

plt.figure(figsize=(6, 6))
sns.heatmap(cm, annot=True, fmt='g', vmin=0, cmap='Reds', cbar=False)
plt.xticks(ticks=[0.5, 1.5], labels=["NO POLLEN", "POLLEN"])
plt.yticks(ticks=[0.5, 1.5], labels=["NO POLLEN", "POLLEN"])
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.show()

print("Classification Report:\n----------------------\n", clr)
# Out:
# Accuracy: 85.12%
# 7/7 [==============================] - 6s 594ms/step
# C:\Users\hp\AppData\Local\Temp\ipykernel_29900\4168585647.py:4: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   predictions = np.squeeze(model.predict(test_images) >= 0.5).astype(np.int)
# Classification Report:
# ----------------------
#                precision    recall  f1-score   support
#
#    NO POLLEN       0.88      0.79      0.84       102
#       POLLEN       0.83      0.90      0.86       113
#
#     accuracy                           0.85       215
#    macro avg       0.85      0.85      0.85       215
# weighted avg       0.85      0.85      0.85       215

# %%
plt.figure(figsize=(10, 10))

for i in range(16):
    plt.subplot(4, 4, i + 1)
    plt.imshow(test_images[0][0][i])
    plt.title(
        "NO POLLEN" if predictions[i] == 0 else "POLLEN",
        color='blue' if predictions[i] == test_images.labels[i] else 'red'
    )
    plt.axis('off')

plt.suptitle("Sample Classifications", size=24)
plt.show()
