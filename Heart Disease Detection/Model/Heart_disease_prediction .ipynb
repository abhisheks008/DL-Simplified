# %% [markdown]
# ## HEART DISEASE DETECTION USING DEEP NEURAL NETWORK
#
# DATASET - https://www.kaggle.com/datasets/andrewmvd/heart-failure-clinical-data

# %%
import pandas as pd

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, Flatten, Dense

# %%
data = pd.read_csv("/Users/kamakshiojha/Downloads/heart_failure_clinical_records_dataset.csv")

# %%
data
# Out:
#       age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0    75.0        0                       582         0                 20
# 1    55.0        0                      7861         0                 38
# 2    65.0        0                       146         0                 20
# 3    50.0        1                       111         0                 20
# 4    65.0        1                       160         1                 20
# ..    ...      ...                       ...       ...                ...
# 294  62.0        0                        61         1                 38
# 295  55.0        0                      1820         0                 38
# 296  45.0        0                      2060         1                 60
# 297  45.0        0                      2413         0                 38
# 298  50.0        0                       196         0                 45
#
#      high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# 0                      1  265000.00               1.9           130    1
# 1                      0  263358.03               1.1           136    1
# 2                      0  162000.00               1.3           129    1
# 3                      0  210000.00               1.9           137    1
# 4                      0  327000.00               2.7           116    0
# ..                   ...        ...               ...           ...  ...
# 294                    1  155000.00               1.1           143    1
# 295                    0  270000.00               1.2           139    0
# 296                    0  742000.00               0.8           138    0
# 297                    0  140000.00               1.4           140    1
# 298                    0  395000.00               1.6           136    1
#
#      smoking  time  DEATH_EVENT
# 0          0     4            1
# 1          0     6            1
# 2          1     7            1
# 3          0     7            1
# 4          0     8            1
# ..       ...   ...          ...
# 294        1   270            0
# 295        0   271            0
# 296        0   278            0
# 297        1   280            0
# 298        1   285            0
#
# [299 rows x 13 columns]

# %%
data.tail()
# Out:
#       age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 294  62.0        0                        61         1                 38
# 295  55.0        0                      1820         0                 38
# 296  45.0        0                      2060         1                 60
# 297  45.0        0                      2413         0                 38
# 298  50.0        0                       196         0                 45
#
#      high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# 294                    1   155000.0               1.1           143    1
# 295                    0   270000.0               1.2           139    0
# 296                    0   742000.0               0.8           138    0
# 297                    0   140000.0               1.4           140    1
# 298                    0   395000.0               1.6           136    1
#
#      smoking  time  DEATH_EVENT
# 294        1   270            0
# 295        0   271            0
# 296        0   278            0
# 297        1   280            0
# 298        1   285            0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 299 entries, 0 to 298
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   age                       299 non-null    float64
#  1   anaemia                   299 non-null    int64
#  2   creatinine_phosphokinase  299 non-null    int64
#  3   diabetes                  299 non-null    int64
#  4   ejection_fraction         299 non-null    int64
#  5   high_blood_pressure       299 non-null    int64
#  6   platelets                 299 non-null    float64
#  7   serum_creatinine          299 non-null    float64
#  8   serum_sodium              299 non-null    int64
#  9   sex                       299 non-null    int64
#  10  smoking                   299 non-null    int64
#  11  time                      299 non-null    int64
#  12  DEATH_EVENT               299 non-null    int64
# dtypes: float64(3), int64(10)
# memory usage: 30.5 KB

# %%
data.isnull().sum()
# Out:
# age                         0
# anaemia                     0
# creatinine_phosphokinase    0
# diabetes                    0
# ejection_fraction           0
# high_blood_pressure         0
# platelets                   0
# serum_creatinine            0
# serum_sodium                0
# sex                         0
# smoking                     0
# time                        0
# DEATH_EVENT                 0
# dtype: int64

# %%
data.shape
# Out:
# (299, 13)

# %%
# data[12].value_counts()

# %%
data.rename(columns = {'DEATH_EVENT' :'class'}, inplace = True)

# %%
data['class'].value_counts()
# Out:
# class
# 0    203
# 1     96
# Name: count, dtype: int64

# %%
X = data.drop(columns = 'class', axis=1)
Y = data['class']

# %%
print(X)
# Out:
#       age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0    75.0        0                       582         0                 20
# 1    55.0        0                      7861         0                 38
# 2    65.0        0                       146         0                 20
# 3    50.0        1                       111         0                 20
# 4    65.0        1                       160         1                 20
# ..    ...      ...                       ...       ...                ...
# 294  62.0        0                        61         1                 38
# 295  55.0        0                      1820         0                 38
# 296  45.0        0                      2060         1                 60
# 297  45.0        0                      2413         0                 38
# 298  50.0        0                       196         0                 45
#
#      high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# 0                      1  265000.00               1.9           130    1
# 1                      0  263358.03               1.1           136    1
# 2                      0  162000.00               1.3           129    1
# 3                      0  210000.00               1.9           137    1
# 4                      0  327000.00               2.7           116    0
# ..                   ...        ...               ...           ...  ...
# 294                    1  155000.00               1.1           143    1
# 295                    0  270000.00               1.2           139    0
# 296                    0  742000.00               0.8           138    0
# 297                    0  140000.00               1.4           140    1
# 298                    0  395000.00               1.6           136    1
#
#      smoking  time
# 0          0     4
# 1          0     6
# 2          1     7
# 3          0     7
# 4          0     8
# ..       ...   ...
# 294        1   270
# 295        0   271
# 296        0   278
# 297        1   280
# 298        1   285
#
# [299 rows x 12 columns]

# %%
# Importing the library 
# import pandas as pd 
from sklearn.preprocessing import StandardScaler 

# define standard scaler 
scaler = StandardScaler() 

# transform data 
X1 = scaler.fit_transform(X)

# %%
X1.shape
# Out:
# (299, 12)

# %%
print(Y)
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 294    0
# 295    0
# 296    0
# 297    0
# 298    0
# Name: class, Length: 299, dtype: int64

# %%
X_train, X_test, y_train, y_test = train_test_split(X1, Y, test_size=0.2, random_state=42)

# %%
X_train.shape
# Out:
# (239, 12)

# %%
X_train = np.array(X_train)
X_test = np.array(X_test)

# %%
X_train2 = X_train.reshape(-1, X_train.shape[1],1)
X_test2 = X_test.reshape(-1, X_test.shape[1],1)

# %%
# X_train1 = np.squeeze(X_train1, axis=(2, 3)) 
# X_test1 = np.squeeze(X_test1, axis=(2, 3)) 
X_train2.shape
# Out:
# (239, 12, 1)

# %% [markdown]
# ## MODEL - 1

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv1D, Add, Multiply, Concatenate, AveragePooling1D, Flatten, DepthwiseConv2D
from tensorflow.keras.layers import SeparableConv1D, MaxPooling1D, Dense, GlobalAveragePooling1D
import keras

# model = Sequential()
visible = Input((12,1))
x1 = Conv1D(filters = 32, kernel_size = (1), strides = 1, activation = "relu")(visible)
m1 = Conv1D(filters = 32, kernel_size = (1), activation = "relu")(x1)
a1 = Add()([x1, m1])

x2 = Conv1D(filters = 64, kernel_size = (1), strides = 1, activation = "relu")(a1)
m2 = Conv1D(filters = 64, kernel_size = (1), activation = "relu")(x2)
a2 = Add()([x2, m2])

x3 = Conv1D(filters = 128, kernel_size = (1), strides = 1, activation = "relu")(a2)
m3 = Conv1D(filters = 128, kernel_size = (1), activation = "relu")(x3)
a3 = Add()([x3, m3])

x4 = Conv1D(filters = 256, kernel_size = (1), strides = 1, activation = "relu")(a3)
m4 = Conv1D(filters = 256, kernel_size = (1), activation = "relu")(x4)
a4 = Add()([x4, m4])

# x5 = MaxPooling1D(pool_size=2, strides=1)(a4)

# flat = Flatten()(x4)
gap = GlobalAveragePooling1D()(a4) 

x = Dense(128, activation='relu')(gap)
x = Dense(90, activation='relu')(x)
x = Dense(64, activation='relu')(x)
x = Dense(32, activation='relu')(x)
output = Dense(1, activation='sigmoid')(x)


model = Model(inputs=visible, outputs=output)
opt = keras.optimizers.SGD(learning_rate=0.001,momentum=0.9)
model.compile(optimizer=opt, loss= 'binary_crossentropy', metrics=["accuracy"])

model.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 12, 1)     │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d (Conv1D)     │ (None, 12, 32)    │         64 │ input_layer[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_1 (Conv1D)   │ (None, 12, 32)    │      1,056 │ conv1d[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add (Add)           │ (None, 12, 32)    │          0 │ conv1d[0][0],     │
# │                     │                   │            │ conv1d_1[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_2 (Conv1D)   │ (None, 12, 64)    │      2,112 │ add[0][0]         │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_3 (Conv1D)   │ (None, 12, 64)    │      4,160 │ conv1d_2[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_1 (Add)         │ (None, 12, 64)    │          0 │ conv1d_2[0][0],   │
# │                     │                   │            │ conv1d_3[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_4 (Conv1D)   │ (None, 12, 128)   │      8,320 │ add_1[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_5 (Conv1D)   │ (None, 12, 128)   │     16,512 │ conv1d_4[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_2 (Add)         │ (None, 12, 128)   │          0 │ conv1d_4[0][0],   │
# │                     │                   │            │ conv1d_5[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_6 (Conv1D)   │ (None, 12, 256)   │     33,024 │ add_2[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_7 (Conv1D)   │ (None, 12, 256)   │     65,792 │ conv1d_6[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_3 (Add)         │ (None, 12, 256)   │          0 │ conv1d_6[0][0],   │
# │                     │                   │            │ conv1d_7[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 256)       │          0 │ add_3[0][0]       │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 128)       │     32,896 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 90)        │     11,610 │ dense[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_2 (Dense)     │ (None, 64)        │      5,824 │ dense_1[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_3 (Dense)     │ (None, 32)        │      2,080 │ dense_2[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_4 (Dense)     │ (None, 1)         │         33 │ dense_3[0][0]     │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 183,483 (716.73 KB)
#  Trainable params: 183,483 (716.73 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Train the model
model.fit(X_train2, y_train, epochs=150, batch_size=4, validation_data=(X_test2, y_test))
# Out:
# Epoch 1/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6490 - loss: 0.6815 - val_accuracy: 0.5833 - val_loss: 0.6814
# Epoch 2/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7142 - loss: 0.6318 - val_accuracy: 0.5833 - val_loss: 0.6887
# Epoch 3/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7027 - loss: 0.6176 - val_accuracy: 0.5833 - val_loss: 0.6980
# Epoch 4/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6629 - loss: 0.6433 - val_accuracy: 0.5833 - val_loss: 0.7057
# Epoch 5/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7309 - loss: 0.5903 - val_accuracy: 0.5833 - val_loss: 0.7028
# Epoch 6/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7114 - loss: 0.6051 - val_accuracy: 0.5833 - val_loss: 0.7046
# Epoch 7/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7068 - loss: 0.6081 - val_accuracy: 0.5833 - val_loss: 0.7058
# Epoch 8/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6576 - loss: 0.6475 - val_accuracy: 0.5833 - val_loss: 0.7127
# Epoch 9/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6892 - loss: 0.6207 - val_accuracy: 0.5833 - val_loss: 0.7071
# Epoch 10/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6899 - loss: 0.6189 - val_accuracy: 0.5833 - val_loss: 0.7109
# Epoch 11/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7351 - loss: 0.5790 - val_accuracy: 0.5833 - val_loss: 0.6952
# Epoch 12/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6977 - loss: 0.6090 - val_accuracy: 0.5833 - val_loss: 0.6979
# Epoch 13/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6834 - loss: 0.6171 - val_accuracy: 0.5833 - val_loss: 0.6999
# Epoch 14/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7229 - loss: 0.5871 - val_accuracy: 0.5833 - val_loss: 0.6864
# Epoch 15/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7279 - loss: 0.5842 - val_accuracy: 0.5833 - val_loss: 0.6851
# Epoch 16/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6608 - loss: 0.6282 - val_accuracy: 0.5833 - val_loss: 0.7162
# Epoch 17/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6747 - loss: 0.6255 - val_accuracy: 0.5833 - val_loss: 0.7167
# Epoch 18/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6765 - loss: 0.6238 - val_accuracy: 0.5833 - val_loss: 0.6986
# Epoch 19/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7017 - loss: 0.5972 - val_accuracy: 0.5833 - val_loss: 0.6834
# Epoch 20/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6719 - loss: 0.6063 - val_accuracy: 0.5833 - val_loss: 0.7522
# Epoch 21/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6952 - loss: 0.6081 - val_accuracy: 0.5833 - val_loss: 0.6677
# Epoch 22/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7440 - loss: 0.5594 - val_accuracy: 0.6167 - val_loss: 0.6553
# Epoch 23/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7160 - loss: 0.5677 - val_accuracy: 0.5833 - val_loss: 0.6670
# Epoch 24/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6748 - loss: 0.6010 - val_accuracy: 0.5833 - val_loss: 0.6785
# Epoch 25/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7378 - loss: 0.5472 - val_accuracy: 0.6333 - val_loss: 0.6546
# Epoch 26/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7193 - loss: 0.5537 - val_accuracy: 0.6333 - val_loss: 0.6573
# Epoch 27/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7638 - loss: 0.5322 - val_accuracy: 0.6333 - val_loss: 0.6472
# Epoch 28/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7177 - loss: 0.5541 - val_accuracy: 0.6000 - val_loss: 0.7192
# Epoch 29/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7432 - loss: 0.5186 - val_accuracy: 0.6333 - val_loss: 0.6456
# Epoch 30/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7529 - loss: 0.5295 - val_accuracy: 0.6833 - val_loss: 0.6259
# Epoch 31/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7175 - loss: 0.5748 - val_accuracy: 0.6333 - val_loss: 0.6398
# Epoch 32/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6748 - loss: 0.5985 - val_accuracy: 0.6000 - val_loss: 0.7864
# Epoch 33/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7422 - loss: 0.5461 - val_accuracy: 0.6500 - val_loss: 0.6540
# Epoch 34/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7530 - loss: 0.5295 - val_accuracy: 0.6500 - val_loss: 0.6261
# Epoch 35/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6546 - loss: 0.5584 - val_accuracy: 0.6833 - val_loss: 0.6227
# Epoch 36/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7588 - loss: 0.5142 - val_accuracy: 0.6500 - val_loss: 0.6366
# Epoch 37/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7816 - loss: 0.5127 - val_accuracy: 0.6333 - val_loss: 0.7542
# Epoch 38/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6934 - loss: 0.5897 - val_accuracy: 0.6500 - val_loss: 0.6658
# Epoch 39/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7651 - loss: 0.5094 - val_accuracy: 0.6333 - val_loss: 0.7912
# Epoch 40/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7169 - loss: 0.5379 - val_accuracy: 0.6333 - val_loss: 0.6904
# Epoch 41/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7877 - loss: 0.5028 - val_accuracy: 0.6333 - val_loss: 0.6296
# Epoch 42/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6798 - loss: 0.6005 - val_accuracy: 0.6167 - val_loss: 0.6384
# Epoch 43/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7426 - loss: 0.5148 - val_accuracy: 0.6667 - val_loss: 0.6283
# Epoch 44/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7700 - loss: 0.5107 - val_accuracy: 0.6500 - val_loss: 0.6354
# Epoch 45/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8071 - loss: 0.5059 - val_accuracy: 0.6167 - val_loss: 0.7239
# Epoch 46/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7644 - loss: 0.4847 - val_accuracy: 0.6333 - val_loss: 0.6844
# Epoch 47/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7656 - loss: 0.4940 - val_accuracy: 0.6167 - val_loss: 0.7253
# Epoch 48/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7457 - loss: 0.4973 - val_accuracy: 0.6333 - val_loss: 0.6972
# Epoch 49/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7063 - loss: 0.5490 - val_accuracy: 0.6333 - val_loss: 0.6713
# Epoch 50/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7328 - loss: 0.5330 - val_accuracy: 0.6333 - val_loss: 0.7141
# Epoch 51/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7393 - loss: 0.5333 - val_accuracy: 0.6333 - val_loss: 0.6648
# Epoch 52/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7302 - loss: 0.5281 - val_accuracy: 0.6333 - val_loss: 0.6719
# Epoch 53/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7758 - loss: 0.5138 - val_accuracy: 0.6333 - val_loss: 0.7196
# Epoch 54/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8085 - loss: 0.4755 - val_accuracy: 0.6333 - val_loss: 0.6558
# Epoch 55/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7111 - loss: 0.5421 - val_accuracy: 0.6167 - val_loss: 0.7362
# Epoch 56/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7288 - loss: 0.5341 - val_accuracy: 0.6333 - val_loss: 0.6927
# Epoch 57/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7241 - loss: 0.5747 - val_accuracy: 0.6333 - val_loss: 0.6594
# Epoch 58/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7485 - loss: 0.5216 - val_accuracy: 0.6500 - val_loss: 0.6348
# Epoch 59/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7535 - loss: 0.5321 - val_accuracy: 0.6333 - val_loss: 0.7078
# Epoch 60/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7850 - loss: 0.4479 - val_accuracy: 0.6667 - val_loss: 0.6317
# Epoch 61/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7064 - loss: 0.5384 - val_accuracy: 0.6167 - val_loss: 0.8035
# Epoch 62/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7054 - loss: 0.5774 - val_accuracy: 0.6333 - val_loss: 0.7282
# Epoch 63/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7870 - loss: 0.4695 - val_accuracy: 0.6333 - val_loss: 0.6584
# Epoch 64/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7402 - loss: 0.5322 - val_accuracy: 0.6500 - val_loss: 0.6766
# Epoch 65/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7505 - loss: 0.5120 - val_accuracy: 0.6667 - val_loss: 0.6367
# Epoch 66/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7223 - loss: 0.5358 - val_accuracy: 0.6167 - val_loss: 0.6900
# Epoch 67/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7748 - loss: 0.4523 - val_accuracy: 0.6500 - val_loss: 0.6234
# Epoch 68/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7288 - loss: 0.5563 - val_accuracy: 0.6333 - val_loss: 0.6516
# Epoch 69/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7673 - loss: 0.4728 - val_accuracy: 0.6333 - val_loss: 0.7056
# Epoch 70/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7464 - loss: 0.5026 - val_accuracy: 0.6333 - val_loss: 0.6498
# Epoch 71/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6960 - loss: 0.5449 - val_accuracy: 0.6500 - val_loss: 0.6776
# Epoch 72/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7513 - loss: 0.4792 - val_accuracy: 0.6667 - val_loss: 0.6758
# Epoch 73/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7733 - loss: 0.4841 - val_accuracy: 0.6333 - val_loss: 0.6255
# Epoch 74/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7552 - loss: 0.5215 - val_accuracy: 0.6333 - val_loss: 0.6868
# Epoch 75/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7557 - loss: 0.5291 - val_accuracy: 0.6333 - val_loss: 0.6687
# Epoch 76/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7378 - loss: 0.5322 - val_accuracy: 0.6333 - val_loss: 0.7111
# Epoch 77/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7265 - loss: 0.5249 - val_accuracy: 0.6333 - val_loss: 0.6419
# Epoch 78/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7520 - loss: 0.4845 - val_accuracy: 0.6667 - val_loss: 0.6253
# Epoch 79/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7885 - loss: 0.5102 - val_accuracy: 0.6500 - val_loss: 0.6293
# Epoch 80/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7110 - loss: 0.5479 - val_accuracy: 0.6333 - val_loss: 0.6499
# Epoch 81/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7648 - loss: 0.4724 - val_accuracy: 0.6333 - val_loss: 0.7070
# Epoch 82/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7411 - loss: 0.5272 - val_accuracy: 0.6667 - val_loss: 0.6242
# Epoch 83/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7287 - loss: 0.5364 - val_accuracy: 0.6167 - val_loss: 0.6686
# Epoch 84/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7462 - loss: 0.5319 - val_accuracy: 0.6167 - val_loss: 0.6790
# Epoch 85/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7810 - loss: 0.4777 - val_accuracy: 0.6167 - val_loss: 0.6778
# Epoch 86/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7535 - loss: 0.4716 - val_accuracy: 0.6333 - val_loss: 0.6486
# Epoch 87/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7046 - loss: 0.5561 - val_accuracy: 0.6333 - val_loss: 0.7171
# Epoch 88/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.7299 - loss: 0.5416 - val_accuracy: 0.6333 - val_loss: 0.6533
# Epoch 89/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6800 - loss: 0.5689 - val_accuracy: 0.6167 - val_loss: 0.7400
# Epoch 90/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7466 - loss: 0.5274 - val_accuracy: 0.6167 - val_loss: 0.7190
# Epoch 91/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7155 - loss: 0.5376 - val_accuracy: 0.6500 - val_loss: 0.6583
# Epoch 92/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6939 - loss: 0.5202 - val_accuracy: 0.6167 - val_loss: 0.7830
# Epoch 93/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7182 - loss: 0.5336 - val_accuracy: 0.6333 - val_loss: 0.6754
# Epoch 94/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7339 - loss: 0.5221 - val_accuracy: 0.6333 - val_loss: 0.6909
# Epoch 95/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7477 - loss: 0.5368 - val_accuracy: 0.6167 - val_loss: 0.6465
# Epoch 96/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7445 - loss: 0.5604 - val_accuracy: 0.6167 - val_loss: 0.7821
# Epoch 97/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7961 - loss: 0.4580 - val_accuracy: 0.6333 - val_loss: 0.6773
# Epoch 98/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8036 - loss: 0.4304 - val_accuracy: 0.6333 - val_loss: 0.6775
# Epoch 99/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7357 - loss: 0.5413 - val_accuracy: 0.6167 - val_loss: 0.6751
# Epoch 100/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7741 - loss: 0.5041 - val_accuracy: 0.6667 - val_loss: 0.6301
# Epoch 101/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7943 - loss: 0.4931 - val_accuracy: 0.6333 - val_loss: 0.6555
# Epoch 102/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8039 - loss: 0.4494 - val_accuracy: 0.6333 - val_loss: 0.6980
# Epoch 103/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7104 - loss: 0.5392 - val_accuracy: 0.6500 - val_loss: 0.6296
# Epoch 104/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7533 - loss: 0.4953 - val_accuracy: 0.6333 - val_loss: 0.6282
# Epoch 105/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7728 - loss: 0.5141 - val_accuracy: 0.6333 - val_loss: 0.6540
# Epoch 106/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7293 - loss: 0.5296 - val_accuracy: 0.6667 - val_loss: 0.6326
# Epoch 107/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7346 - loss: 0.5141 - val_accuracy: 0.6500 - val_loss: 0.6823
# Epoch 108/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7710 - loss: 0.4740 - val_accuracy: 0.6167 - val_loss: 0.7469
# Epoch 109/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7233 - loss: 0.5265 - val_accuracy: 0.6333 - val_loss: 0.6408
# Epoch 110/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7880 - loss: 0.4974 - val_accuracy: 0.6333 - val_loss: 0.6869
# Epoch 111/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7940 - loss: 0.4956 - val_accuracy: 0.6333 - val_loss: 0.6758
# Epoch 112/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7702 - loss: 0.5051 - val_accuracy: 0.6333 - val_loss: 0.6457
# Epoch 113/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7902 - loss: 0.4625 - val_accuracy: 0.6333 - val_loss: 0.6728
# Epoch 114/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7722 - loss: 0.5094 - val_accuracy: 0.6500 - val_loss: 0.6572
# Epoch 115/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7851 - loss: 0.4868 - val_accuracy: 0.6333 - val_loss: 0.6340
# Epoch 116/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7707 - loss: 0.5381 - val_accuracy: 0.6500 - val_loss: 0.6685
# Epoch 117/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7861 - loss: 0.4619 - val_accuracy: 0.6500 - val_loss: 0.6290
# Epoch 118/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7327 - loss: 0.5343 - val_accuracy: 0.6333 - val_loss: 0.6442
# Epoch 119/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7882 - loss: 0.4873 - val_accuracy: 0.6500 - val_loss: 0.6750
# Epoch 120/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7036 - loss: 0.5731 - val_accuracy: 0.6333 - val_loss: 0.6681
# Epoch 121/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7351 - loss: 0.5278 - val_accuracy: 0.6167 - val_loss: 0.7339
# Epoch 122/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7561 - loss: 0.5221 - val_accuracy: 0.6333 - val_loss: 0.6845
# Epoch 123/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7375 - loss: 0.5068 - val_accuracy: 0.6333 - val_loss: 0.6961
# Epoch 124/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7116 - loss: 0.5317 - val_accuracy: 0.6500 - val_loss: 0.6590
# Epoch 125/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7984 - loss: 0.4776 - val_accuracy: 0.6333 - val_loss: 0.6861
# Epoch 126/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7276 - loss: 0.5400 - val_accuracy: 0.6500 - val_loss: 0.6571
# Epoch 127/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7255 - loss: 0.5167 - val_accuracy: 0.6500 - val_loss: 0.6748
# Epoch 128/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.8001 - loss: 0.4685 - val_accuracy: 0.6333 - val_loss: 0.6258
# Epoch 129/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.7163 - loss: 0.5167 - val_accuracy: 0.6333 - val_loss: 0.6523
# Epoch 130/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7592 - loss: 0.5152 - val_accuracy: 0.6667 - val_loss: 0.6609
# Epoch 131/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7258 - loss: 0.5318 - val_accuracy: 0.6667 - val_loss: 0.6673
# Epoch 132/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7071 - loss: 0.5719 - val_accuracy: 0.6167 - val_loss: 0.7388
# Epoch 133/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6807 - loss: 0.5681 - val_accuracy: 0.6333 - val_loss: 0.6913
# Epoch 134/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7521 - loss: 0.4872 - val_accuracy: 0.6333 - val_loss: 0.6341
# Epoch 135/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7747 - loss: 0.4836 - val_accuracy: 0.6333 - val_loss: 0.6389
# Epoch 136/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7679 - loss: 0.5294 - val_accuracy: 0.6333 - val_loss: 0.6848
# Epoch 137/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7682 - loss: 0.4546 - val_accuracy: 0.6333 - val_loss: 0.6899
# Epoch 138/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7363 - loss: 0.5297 - val_accuracy: 0.6167 - val_loss: 0.7401
# Epoch 139/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7495 - loss: 0.5183 - val_accuracy: 0.6333 - val_loss: 0.6462
# Epoch 140/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7343 - loss: 0.5011 - val_accuracy: 0.6333 - val_loss: 0.8063
# Epoch 141/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6475 - loss: 0.6668 - val_accuracy: 0.6167 - val_loss: 0.7208
# Epoch 142/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7564 - loss: 0.5026 - val_accuracy: 0.6333 - val_loss: 0.6402
# Epoch 143/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7392 - loss: 0.5266 - val_accuracy: 0.6500 - val_loss: 0.6540
# Epoch 144/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7564 - loss: 0.5011 - val_accuracy: 0.6500 - val_loss: 0.6258
# Epoch 145/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6963 - loss: 0.5222 - val_accuracy: 0.6167 - val_loss: 0.6384
# Epoch 146/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7188 - loss: 0.5427 - val_accuracy: 0.6333 - val_loss: 0.6344
# Epoch 147/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7280 - loss: 0.5260 - val_accuracy: 0.6333 - val_loss: 0.7049
# Epoch 148/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7385 - loss: 0.5050 - val_accuracy: 0.6333 - val_loss: 0.6422
# Epoch 149/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7032 - loss: 0.5190 - val_accuracy: 0.6333 - val_loss: 0.7069
# Epoch 150/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7529 - loss: 0.5107 - val_accuracy: 0.6500 - val_loss: 0.6686

# %%
train_acc =  model.history.history['accuracy']
val_acc = model.history.history['val_accuracy']
train_loss = model.history.history['loss']
val_loss = model.history.history['val_loss']

# %%
from matplotlib import pyplot as plt
epochs = range(len(train_acc))
plt.plot(epochs, train_acc, 'b', label='Training Accuracy')
plt.plot(epochs, val_acc, 'g', label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.grid()
plt.legend()
plt.figure()
plt.show()

plt.plot(epochs, train_loss, 'b', label='Training Loss')
plt.plot(epochs, val_loss, 'g', label='Validation Loss')
plt.title('Training and Validation Loss')
plt.grid()
plt.legend()
plt.show()

# %% [markdown]
# ## MODEL - 2

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv1D, Add, GlobalAveragePooling1D, Dense, BatchNormalization, Activation, Dropout
import tensorflow.keras.optimizers as optimizers

visible = Input((12, 1))

x = Conv1D(filters=32, kernel_size=1, activation=None)(visible)
x = BatchNormalization()(x)
x = Activation('relu')(x)

x = Conv1D(filters=32, kernel_size=1, activation=None)(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)

x = Conv1D(filters=64, kernel_size=1, activation=None)(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)

x = Conv1D(filters=64, kernel_size=1, activation=None)(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)

x = Conv1D(filters=128, kernel_size=1, activation=None)(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)

x = Conv1D(filters=128, kernel_size=1, activation=None)(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)

x = Conv1D(filters=256, kernel_size=1, activation=None)(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)

x = Conv1D(filters=256, kernel_size=1, activation=None)(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)

x = GlobalAveragePooling1D()(x)

x = Dense(128, activation='relu')(x)
x = Dropout(0.5)(x)

x = Dense(90, activation='relu')(x)
x = Dropout(0.5)(x)

x = Dense(64, activation='relu')(x)
x = Dropout(0.5)(x)

x = Dense(32, activation='relu')(x)
x = Dropout(0.5)(x)

output = Dense(1, activation='sigmoid')(x)

model = Model(inputs=visible, outputs=output)
opt = optimizers.SGD(learning_rate=0.001, momentum=0.9)
model.compile(optimizer=opt, loss='binary_crossentropy', metrics=["accuracy"])

model.summary()
# Out:
# Model: "functional_11"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_5 (InputLayer)      │ (None, 12, 1)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_40 (Conv1D)              │ (None, 12, 32)         │            64 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_16          │ (None, 12, 32)         │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_16 (Activation)      │ (None, 12, 32)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_41 (Conv1D)              │ (None, 12, 32)         │         1,056 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_17          │ (None, 12, 32)         │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_17 (Activation)      │ (None, 12, 32)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_42 (Conv1D)              │ (None, 12, 64)         │         2,112 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_18          │ (None, 12, 64)         │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_18 (Activation)      │ (None, 12, 64)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_43 (Conv1D)              │ (None, 12, 64)         │         4,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_19          │ (None, 12, 64)         │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_19 (Activation)      │ (None, 12, 64)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_44 (Conv1D)              │ (None, 12, 128)        │         8,320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_20          │ (None, 12, 128)        │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_20 (Activation)      │ (None, 12, 128)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_45 (Conv1D)              │ (None, 12, 128)        │        16,512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_21          │ (None, 12, 128)        │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_21 (Activation)      │ (None, 12, 128)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_46 (Conv1D)              │ (None, 12, 256)        │        33,024 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_22          │ (None, 12, 256)        │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_22 (Activation)      │ (None, 12, 256)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_47 (Conv1D)              │ (None, 12, 256)        │        65,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_23          │ (None, 12, 256)        │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_23 (Activation)      │ (None, 12, 256)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling1d_5      │ (None, 256)            │             0 │
# │ (GlobalAveragePooling1D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_25 (Dense)                │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_8 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_26 (Dense)                │ (None, 90)             │        11,610 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_9 (Dropout)             │ (None, 90)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_27 (Dense)                │ (None, 64)             │         5,824 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_10 (Dropout)            │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_28 (Dense)                │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_11 (Dropout)            │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_29 (Dense)                │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 187,323 (731.73 KB)
#  Trainable params: 185,403 (724.23 KB)
#  Non-trainable params: 1,920 (7.50 KB)

# %%
# Train the model
model2.fit(X_train2, y_train, epochs=150, batch_size=4, validation_data=(X_test2, y_test))
# Out:
# Epoch 1/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6908 - loss: 0.6107 - val_accuracy: 0.6167 - val_loss: 0.6345
# Epoch 2/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7219 - loss: 0.5547 - val_accuracy: 0.6000 - val_loss: 0.6336
# Epoch 3/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7210 - loss: 0.5499 - val_accuracy: 0.6167 - val_loss: 0.6253
# Epoch 4/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7500 - loss: 0.5453 - val_accuracy: 0.6167 - val_loss: 0.6218
# Epoch 5/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7178 - loss: 0.5367 - val_accuracy: 0.6167 - val_loss: 0.6320
# Epoch 6/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6985 - loss: 0.5901 - val_accuracy: 0.6167 - val_loss: 0.6396
# Epoch 7/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6716 - loss: 0.5916 - val_accuracy: 0.6167 - val_loss: 0.6271
# Epoch 8/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7132 - loss: 0.5623 - val_accuracy: 0.6167 - val_loss: 0.6228
# Epoch 9/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7165 - loss: 0.6029 - val_accuracy: 0.6167 - val_loss: 0.6314
# Epoch 10/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7030 - loss: 0.5632 - val_accuracy: 0.6167 - val_loss: 0.6537
# Epoch 11/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7314 - loss: 0.5671 - val_accuracy: 0.6167 - val_loss: 0.6651
# Epoch 12/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7107 - loss: 0.5623 - val_accuracy: 0.6167 - val_loss: 0.6252
# Epoch 13/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7354 - loss: 0.5392 - val_accuracy: 0.6167 - val_loss: 0.6376
# Epoch 14/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6802 - loss: 0.5761 - val_accuracy: 0.6333 - val_loss: 0.6560
# Epoch 15/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7410 - loss: 0.5275 - val_accuracy: 0.6167 - val_loss: 0.6499
# Epoch 16/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7595 - loss: 0.5610 - val_accuracy: 0.6167 - val_loss: 0.6465
# Epoch 17/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7275 - loss: 0.5667 - val_accuracy: 0.6167 - val_loss: 0.6484
# Epoch 18/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7839 - loss: 0.5400 - val_accuracy: 0.6333 - val_loss: 0.6172
# Epoch 19/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6573 - loss: 0.5591 - val_accuracy: 0.6333 - val_loss: 0.6235
# Epoch 20/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7336 - loss: 0.5678 - val_accuracy: 0.6167 - val_loss: 0.6216
# Epoch 21/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7409 - loss: 0.5514 - val_accuracy: 0.6333 - val_loss: 0.6078
# Epoch 22/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7240 - loss: 0.5516 - val_accuracy: 0.6500 - val_loss: 0.6218
# Epoch 23/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6317 - loss: 0.6293 - val_accuracy: 0.6667 - val_loss: 0.6278
# Epoch 24/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7028 - loss: 0.5472 - val_accuracy: 0.6667 - val_loss: 0.6192
# Epoch 25/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6956 - loss: 0.5523 - val_accuracy: 0.6333 - val_loss: 0.6356
# Epoch 26/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7272 - loss: 0.5490 - val_accuracy: 0.6833 - val_loss: 0.6096
# Epoch 27/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7156 - loss: 0.5175 - val_accuracy: 0.6833 - val_loss: 0.6138
# Epoch 28/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7304 - loss: 0.6036 - val_accuracy: 0.6167 - val_loss: 0.6234
# Epoch 29/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7805 - loss: 0.5357 - val_accuracy: 0.6667 - val_loss: 0.5973
# Epoch 30/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7193 - loss: 0.5560 - val_accuracy: 0.6833 - val_loss: 0.5850
# Epoch 31/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6395 - loss: 0.6101 - val_accuracy: 0.6667 - val_loss: 0.6259
# Epoch 32/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7195 - loss: 0.5570 - val_accuracy: 0.6333 - val_loss: 0.6420
# Epoch 33/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7153 - loss: 0.5455 - val_accuracy: 0.6500 - val_loss: 0.6294
# Epoch 34/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7165 - loss: 0.5185 - val_accuracy: 0.6167 - val_loss: 0.6604
# Epoch 35/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6517 - loss: 0.6278 - val_accuracy: 0.6500 - val_loss: 0.6272
# Epoch 36/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7148 - loss: 0.5346 - val_accuracy: 0.6500 - val_loss: 0.6360
# Epoch 37/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7063 - loss: 0.5361 - val_accuracy: 0.6333 - val_loss: 0.6760
# Epoch 38/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7123 - loss: 0.5391 - val_accuracy: 0.6333 - val_loss: 0.6695
# Epoch 39/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7004 - loss: 0.5339 - val_accuracy: 0.6167 - val_loss: 0.6357
# Epoch 40/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7121 - loss: 0.5855 - val_accuracy: 0.6167 - val_loss: 0.6200
# Epoch 41/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7061 - loss: 0.5570 - val_accuracy: 0.6833 - val_loss: 0.6064
# Epoch 42/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6567 - loss: 0.6281 - val_accuracy: 0.6333 - val_loss: 0.6318
# Epoch 43/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7201 - loss: 0.5227 - val_accuracy: 0.6500 - val_loss: 0.6672
# Epoch 44/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6873 - loss: 0.5790 - val_accuracy: 0.6333 - val_loss: 0.6181
# Epoch 45/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7292 - loss: 0.5798 - val_accuracy: 0.6333 - val_loss: 0.6401
# Epoch 46/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7147 - loss: 0.5852 - val_accuracy: 0.6833 - val_loss: 0.6182
# Epoch 47/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7304 - loss: 0.5443 - val_accuracy: 0.6500 - val_loss: 0.6431
# Epoch 48/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7905 - loss: 0.5217 - val_accuracy: 0.6500 - val_loss: 0.6542
# Epoch 49/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7518 - loss: 0.5128 - val_accuracy: 0.6333 - val_loss: 0.6457
# Epoch 50/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6996 - loss: 0.5676 - val_accuracy: 0.6500 - val_loss: 0.6512
# Epoch 51/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7341 - loss: 0.5288 - val_accuracy: 0.6500 - val_loss: 0.6401
# Epoch 52/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7313 - loss: 0.5704 - val_accuracy: 0.6667 - val_loss: 0.6334
# Epoch 53/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7789 - loss: 0.5444 - val_accuracy: 0.6667 - val_loss: 0.6029
# Epoch 54/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7686 - loss: 0.5264 - val_accuracy: 0.6667 - val_loss: 0.6149
# Epoch 55/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6427 - loss: 0.6355 - val_accuracy: 0.6333 - val_loss: 0.6308
# Epoch 56/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7261 - loss: 0.5233 - val_accuracy: 0.6333 - val_loss: 0.6196
# Epoch 57/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7285 - loss: 0.5151 - val_accuracy: 0.6500 - val_loss: 0.6322
# Epoch 58/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7385 - loss: 0.5250 - val_accuracy: 0.6333 - val_loss: 0.6369
# Epoch 59/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7474 - loss: 0.5801 - val_accuracy: 0.6833 - val_loss: 0.6090
# Epoch 60/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6630 - loss: 0.5931 - val_accuracy: 0.6333 - val_loss: 0.6168
# Epoch 61/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7385 - loss: 0.5299 - val_accuracy: 0.6167 - val_loss: 0.6095
# Epoch 62/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6982 - loss: 0.5675 - val_accuracy: 0.7333 - val_loss: 0.5741
# Epoch 63/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7680 - loss: 0.5372 - val_accuracy: 0.6667 - val_loss: 0.5987
# Epoch 64/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8011 - loss: 0.4870 - val_accuracy: 0.6667 - val_loss: 0.6267
# Epoch 65/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7297 - loss: 0.5562 - val_accuracy: 0.6667 - val_loss: 0.6208
# Epoch 66/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7527 - loss: 0.5543 - val_accuracy: 0.6500 - val_loss: 0.6628
# Epoch 67/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7768 - loss: 0.4979 - val_accuracy: 0.6833 - val_loss: 0.6346
# Epoch 68/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6984 - loss: 0.6033 - val_accuracy: 0.6833 - val_loss: 0.5949
# Epoch 69/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7116 - loss: 0.5402 - val_accuracy: 0.6167 - val_loss: 0.6397
# Epoch 70/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8007 - loss: 0.5008 - val_accuracy: 0.6500 - val_loss: 0.6327
# Epoch 71/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7593 - loss: 0.5268 - val_accuracy: 0.6167 - val_loss: 0.6613
# Epoch 72/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7435 - loss: 0.5584 - val_accuracy: 0.6333 - val_loss: 0.6351
# Epoch 73/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7466 - loss: 0.5227 - val_accuracy: 0.6333 - val_loss: 0.6245
# Epoch 74/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6915 - loss: 0.5399 - val_accuracy: 0.7167 - val_loss: 0.5748
# Epoch 75/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7304 - loss: 0.5396 - val_accuracy: 0.6833 - val_loss: 0.6027
# Epoch 76/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7153 - loss: 0.5064 - val_accuracy: 0.6500 - val_loss: 0.5848
# Epoch 77/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7143 - loss: 0.5118 - val_accuracy: 0.6667 - val_loss: 0.5947
# Epoch 78/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8038 - loss: 0.4567 - val_accuracy: 0.6667 - val_loss: 0.5996
# Epoch 79/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7265 - loss: 0.5081 - val_accuracy: 0.6667 - val_loss: 0.6115
# Epoch 80/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7449 - loss: 0.5575 - val_accuracy: 0.6667 - val_loss: 0.5806
# Epoch 81/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7156 - loss: 0.5774 - val_accuracy: 0.6667 - val_loss: 0.5793
# Epoch 82/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7381 - loss: 0.5026 - val_accuracy: 0.6833 - val_loss: 0.5866
# Epoch 83/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7578 - loss: 0.4898 - val_accuracy: 0.6833 - val_loss: 0.5938
# Epoch 84/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7523 - loss: 0.4992 - val_accuracy: 0.6333 - val_loss: 0.6127
# Epoch 85/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7243 - loss: 0.6006 - val_accuracy: 0.6833 - val_loss: 0.5822
# Epoch 86/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7170 - loss: 0.5499 - val_accuracy: 0.6833 - val_loss: 0.5864
# Epoch 87/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6856 - loss: 0.6215 - val_accuracy: 0.6333 - val_loss: 0.6237
# Epoch 88/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7190 - loss: 0.5999 - val_accuracy: 0.6333 - val_loss: 0.6230
# Epoch 89/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7108 - loss: 0.5758 - val_accuracy: 0.6500 - val_loss: 0.6258
# Epoch 90/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7191 - loss: 0.5659 - val_accuracy: 0.6500 - val_loss: 0.6117
# Epoch 91/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7411 - loss: 0.4974 - val_accuracy: 0.6333 - val_loss: 0.6147
# Epoch 92/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7531 - loss: 0.5323 - val_accuracy: 0.6333 - val_loss: 0.6185
# Epoch 93/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6466 - loss: 0.6157 - val_accuracy: 0.6500 - val_loss: 0.5878
# Epoch 94/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7554 - loss: 0.5222 - val_accuracy: 0.7167 - val_loss: 0.5666
# Epoch 95/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7339 - loss: 0.5834 - val_accuracy: 0.6667 - val_loss: 0.6038
# Epoch 96/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6931 - loss: 0.6066 - val_accuracy: 0.6500 - val_loss: 0.6068
# Epoch 97/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7346 - loss: 0.5604 - val_accuracy: 0.6333 - val_loss: 0.6381
# Epoch 98/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7275 - loss: 0.5455 - val_accuracy: 0.6500 - val_loss: 0.6140
# Epoch 99/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7714 - loss: 0.5125 - val_accuracy: 0.6333 - val_loss: 0.6196
# Epoch 100/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7229 - loss: 0.5617 - val_accuracy: 0.6667 - val_loss: 0.6022
# Epoch 101/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6939 - loss: 0.5305 - val_accuracy: 0.6333 - val_loss: 0.6339
# Epoch 102/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7519 - loss: 0.5019 - val_accuracy: 0.6333 - val_loss: 0.6211
# Epoch 103/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7737 - loss: 0.5124 - val_accuracy: 0.6333 - val_loss: 0.6018
# Epoch 104/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.7461 - loss: 0.5356 - val_accuracy: 0.7167 - val_loss: 0.5725
# Epoch 105/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7198 - loss: 0.5699 - val_accuracy: 0.6500 - val_loss: 0.6042
# Epoch 106/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7436 - loss: 0.5154 - val_accuracy: 0.6833 - val_loss: 0.5987
# Epoch 107/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6953 - loss: 0.5634 - val_accuracy: 0.6833 - val_loss: 0.6153
# Epoch 108/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7324 - loss: 0.5204 - val_accuracy: 0.6500 - val_loss: 0.5957
# Epoch 109/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7632 - loss: 0.5342 - val_accuracy: 0.6667 - val_loss: 0.5994
# Epoch 110/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6595 - loss: 0.6117 - val_accuracy: 0.6500 - val_loss: 0.6095
# Epoch 111/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7511 - loss: 0.5086 - val_accuracy: 0.7000 - val_loss: 0.5837
# Epoch 112/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7538 - loss: 0.5219 - val_accuracy: 0.6833 - val_loss: 0.5922
# Epoch 113/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7225 - loss: 0.5518 - val_accuracy: 0.6167 - val_loss: 0.6310
# Epoch 114/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7004 - loss: 0.5882 - val_accuracy: 0.6833 - val_loss: 0.5950
# Epoch 115/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6653 - loss: 0.6475 - val_accuracy: 0.6667 - val_loss: 0.6224
# Epoch 116/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7481 - loss: 0.5042 - val_accuracy: 0.6667 - val_loss: 0.6120
# Epoch 117/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7284 - loss: 0.5519 - val_accuracy: 0.6667 - val_loss: 0.5976
# Epoch 118/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7060 - loss: 0.5191 - val_accuracy: 0.6833 - val_loss: 0.6081
# Epoch 119/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6998 - loss: 0.5672 - val_accuracy: 0.6667 - val_loss: 0.6241
# Epoch 120/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7957 - loss: 0.4917 - val_accuracy: 0.7167 - val_loss: 0.6047
# Epoch 121/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7026 - loss: 0.5986 - val_accuracy: 0.6833 - val_loss: 0.5882
# Epoch 122/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7281 - loss: 0.5342 - val_accuracy: 0.6667 - val_loss: 0.6145
# Epoch 123/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7461 - loss: 0.5335 - val_accuracy: 0.6333 - val_loss: 0.6182
# Epoch 124/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7318 - loss: 0.5459 - val_accuracy: 0.6667 - val_loss: 0.6207
# Epoch 125/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6722 - loss: 0.5396 - val_accuracy: 0.6667 - val_loss: 0.5710
# Epoch 126/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7632 - loss: 0.5074 - val_accuracy: 0.6833 - val_loss: 0.5849
# Epoch 127/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7565 - loss: 0.5145 - val_accuracy: 0.6500 - val_loss: 0.6214
# Epoch 128/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7025 - loss: 0.5310 - val_accuracy: 0.6667 - val_loss: 0.6110
# Epoch 129/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7107 - loss: 0.5248 - val_accuracy: 0.6833 - val_loss: 0.5944
# Epoch 130/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7861 - loss: 0.5002 - val_accuracy: 0.6833 - val_loss: 0.5939
# Epoch 131/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8039 - loss: 0.4559 - val_accuracy: 0.7333 - val_loss: 0.5584
# Epoch 132/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7113 - loss: 0.5749 - val_accuracy: 0.6667 - val_loss: 0.5942
# Epoch 133/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7438 - loss: 0.5173 - val_accuracy: 0.6500 - val_loss: 0.6151
# Epoch 134/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7166 - loss: 0.5672 - val_accuracy: 0.6333 - val_loss: 0.6279
# Epoch 135/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7474 - loss: 0.5477 - val_accuracy: 0.6500 - val_loss: 0.6017
# Epoch 136/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7482 - loss: 0.5181 - val_accuracy: 0.6833 - val_loss: 0.6075
# Epoch 137/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7585 - loss: 0.4835 - val_accuracy: 0.6833 - val_loss: 0.5774
# Epoch 138/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7387 - loss: 0.5055 - val_accuracy: 0.7000 - val_loss: 0.5522
# Epoch 139/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7264 - loss: 0.5625 - val_accuracy: 0.7333 - val_loss: 0.5823
# Epoch 140/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7612 - loss: 0.5203 - val_accuracy: 0.6833 - val_loss: 0.6143
# Epoch 141/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7006 - loss: 0.5403 - val_accuracy: 0.6333 - val_loss: 0.6253
# Epoch 142/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7851 - loss: 0.4809 - val_accuracy: 0.7000 - val_loss: 0.5772
# Epoch 143/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6979 - loss: 0.5652 - val_accuracy: 0.6667 - val_loss: 0.5962
# Epoch 144/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8053 - loss: 0.4575 - val_accuracy: 0.7000 - val_loss: 0.5753
# Epoch 145/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7443 - loss: 0.5242 - val_accuracy: 0.6833 - val_loss: 0.5883
# Epoch 146/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7689 - loss: 0.4986 - val_accuracy: 0.6833 - val_loss: 0.5834
# Epoch 147/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7069 - loss: 0.5580 - val_accuracy: 0.6333 - val_loss: 0.6313
# Epoch 148/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7455 - loss: 0.5173 - val_accuracy: 0.6833 - val_loss: 0.6141
# Epoch 149/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7574 - loss: 0.4808 - val_accuracy: 0.6833 - val_loss: 0.5748
# Epoch 150/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7853 - loss: 0.5057 - val_accuracy: 0.6833 - val_loss: 0.5878

# %%
train_acc2 =  model2.history.history['accuracy']
val_acc2 = model2.history.history['val_accuracy']
train_loss2 = model2.history.history['loss']
val_loss2 = model2.history.history['val_loss']

# %%
from matplotlib import pyplot as plt
epochs = range(len(train_acc2))
plt.plot(epochs, train_acc2, 'b', label='Training Accuracy')
plt.plot(epochs, val_acc2, 'g', label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.grid()
plt.legend()
plt.figure()
plt.show()

plt.plot(epochs, train_loss2, 'b', label='Training Loss')
plt.plot(epochs, val_loss2, 'g', label='Validation Loss')
plt.title('Training and Validation Loss')
plt.grid()
plt.legend()
plt.show()

# %% [markdown]
# ## MODEL - 3

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv1D, Add, Multiply, Concatenate, AveragePooling1D, Flatten, DepthwiseConv2D
from tensorflow.keras.layers import SeparableConv1D, MaxPooling1D, Dense, GlobalAveragePooling1D
import keras

# model = Sequential()
visible = Input((12,1))
x1 = Conv1D(filters = 32, kernel_size = (1), strides = 1, activation = "relu")(visible)
m1 = Conv1D(filters = 32, kernel_size = (1), activation = "relu")(x1)
a1 = Add()([x1, m1])

x2 = Conv1D(filters = 64, kernel_size = (1), strides = 1, activation = "relu")(a1)
m2 = Conv1D(filters = 64, kernel_size = (1), activation = "relu")(x2)
a2 = Add()([x2, m2])

x3 = Conv1D(filters = 128, kernel_size = (1), strides = 1, activation = "relu")(a2)
m3 = Conv1D(filters = 128, kernel_size = (1), activation = "relu")(x3)
a3 = Add()([x3, m3])

x4 = Conv1D(filters = 256, kernel_size = (1), strides = 1, activation = "relu")(a3)
m4 = Conv1D(filters = 256, kernel_size = (1), activation = "relu")(x4)
a4 = Add()([x4, m4])

x5 = MaxPooling1D(pool_size=2, strides=1)(a4)

flat = Flatten()(x4)
gap = GlobalAveragePooling1D()(x5) 

x = Dense(128, activation='relu')(gap)
x = Dense(90, activation='relu')(x)
x = Dense(64, activation='relu')(x)
x = Dense(32, activation='relu')(x)
output = Dense(1, activation='sigmoid')(x)


model = Model(inputs=visible, outputs=output)
opt = keras.optimizers.SGD(learning_rate=0.001,momentum=0.9)
model.compile(optimizer=opt, loss= 'binary_crossentropy', metrics=["accuracy"])

model.summary()
# Out:
# Model: "functional_13"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_6       │ (None, 12, 1)     │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_48 (Conv1D)  │ (None, 12, 32)    │         64 │ input_layer_6[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_49 (Conv1D)  │ (None, 12, 32)    │      1,056 │ conv1d_48[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_12 (Add)        │ (None, 12, 32)    │          0 │ conv1d_48[0][0],  │
# │                     │                   │            │ conv1d_49[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_50 (Conv1D)  │ (None, 12, 64)    │      2,112 │ add_12[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_51 (Conv1D)  │ (None, 12, 64)    │      4,160 │ conv1d_50[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_13 (Add)        │ (None, 12, 64)    │          0 │ conv1d_50[0][0],  │
# │                     │                   │            │ conv1d_51[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_52 (Conv1D)  │ (None, 12, 128)   │      8,320 │ add_13[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_53 (Conv1D)  │ (None, 12, 128)   │     16,512 │ conv1d_52[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_14 (Add)        │ (None, 12, 128)   │          0 │ conv1d_52[0][0],  │
# │                     │                   │            │ conv1d_53[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_54 (Conv1D)  │ (None, 12, 256)   │     33,024 │ add_14[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_55 (Conv1D)  │ (None, 12, 256)   │     65,792 │ conv1d_54[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_15 (Add)        │ (None, 12, 256)   │          0 │ conv1d_54[0][0],  │
# │                     │                   │            │ conv1d_55[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling1d_1     │ (None, 11, 256)   │          0 │ add_15[0][0]      │
# │ (MaxPooling1D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 256)       │          0 │ max_pooling1d_1[… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_30 (Dense)    │ (None, 128)       │     32,896 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_31 (Dense)    │ (None, 90)        │     11,610 │ dense_30[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_32 (Dense)    │ (None, 64)        │      5,824 │ dense_31[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_33 (Dense)    │ (None, 32)        │      2,080 │ dense_32[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_34 (Dense)    │ (None, 1)         │         33 │ dense_33[0][0]    │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 183,483 (716.73 KB)
#  Trainable params: 183,483 (716.73 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Train the model
model.fit(X_train2, y_train, epochs=180, batch_size=8, validation_data=(X_test2, y_test))
# Out:
# Epoch 1/180
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7366 - loss: 0.5583 - val_accuracy: 0.6333 - val_loss: 0.7251
# Epoch 2/180
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7345 - loss: 0.5530 - val_accuracy: 0.6167 - val_loss: 0.7112
# Epoch 3/180
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8016 - loss: 0.4717 - val_accuracy: 0.6500 - val_loss: 0.6483
# Epoch 4/180
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8126 - loss: 0.4745 - val_accuracy: 0.6167 - val_loss: 0.6668
# Epoch 5/180
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7257 - loss: 0.5592 - val_accuracy: 0.6167 - val_loss: 0.6883
# Epoch 6/180
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7268 - loss: 0.5776 - val_accuracy: 0.6167 - val_loss: 0.6558
# Epoch 7/180
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7110 - loss: 0.5416 - val_accuracy: 0.6167 - val_loss: 0.6992
# Epoch 8/180
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7428 - loss: 0.5509 - val_accuracy: 0.6000 - val_loss: 0.6753
# Epoch 9/180
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7707 - loss: 0.5016 - val_accuracy: 0.6000 - val_loss: 0.6893
# Epoch 10/180
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7381 - loss: 0.5781 - val_accuracy: 0.6000 - val_loss: 0.6773
# Epoch 11/180
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7126 - loss: 0.5733 - val_accuracy: 0.6167 - val_loss: 0.6709
# Epoch 12/180
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7296 - loss: 0.5329 - val_accuracy: 0.6167 - val_loss: 0.6735
# Epoch 13/180
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7706 - loss: 0.5301 - val_accuracy: 0.6333 - val_loss: 0.6553
# Epoch 14/180
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7316 - loss: 0.5226 - val_accuracy: 0.6333 - val_loss: 0.7289
# Epoch 15/180
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7132 - loss: 0.5515 - val_accuracy: 0.6333 - val_loss: 0.7205
# Epoch 16/180
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7407 - loss: 0.5566 - val_accuracy: 0.6167 - val_loss: 0.6464
# Epoch 17/180
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7301 - loss: 0.5285 - val_accuracy: 0.6167 - val_loss: 0.6586
# Epoch 18/180
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7790 - loss: 0.4738 - val_accuracy: 0.6167 - val_loss: 0.6614
# Epoch 19/180
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7331 - loss: 0.5332 - val_accuracy: 0.6000 - val_loss: 0.6812
# Epoch 20/180
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7047 - loss: 0.5476 - val_accuracy: 0.6167 - val_loss: 0.6626
# Epoch 21/180
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7644 - loss: 0.4946 - val_accuracy: 0.6167 - val_loss: 0.6580
# Epoch 22/180
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6967 - loss: 0.5659 - val_accuracy: 0.6333 - val_loss: 0.7266
# Epoch 23/180
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7956 - loss: 0.4933 - val_accuracy: 0.6333 - val_loss: 0.6461
# Epoch 24/180
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7080 - loss: 0.5522 - val_accuracy: 0.6167 - val_loss: 0.6610
# Epoch 25/180
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7985 - loss: 0.4781 - val_accuracy: 0.6500 - val_loss: 0.6507
# Epoch 26/180
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7667 - loss: 0.5142 - val_accuracy: 0.6333 - val_loss: 0.6473
# Epoch 27/180
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7298 - loss: 0.5312 - val_accuracy: 0.6333 - val_loss: 0.7246
# Epoch 28/180
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7499 - loss: 0.5493 - val_accuracy: 0.6333 - val_loss: 0.7039
# Epoch 29/180
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7398 - loss: 0.5600 - val_accuracy: 0.6167 - val_loss: 0.6633
# Epoch 30/180
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7426 - loss: 0.5334 - val_accuracy: 0.6000 - val_loss: 0.6872
# Epoch 31/180
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7464 - loss: 0.5179 - val_accuracy: 0.6167 - val_loss: 0.6777
# Epoch 32/180
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7527 - loss: 0.5021 - val_accuracy: 0.6167 - val_loss: 0.6791
# Epoch 33/180
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7640 - loss: 0.4948 - val_accuracy: 0.6167 - val_loss: 0.6683
# Epoch 34/180
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7536 - loss: 0.5165 - val_accuracy: 0.6333 - val_loss: 0.6510
# Epoch 35/180
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7623 - loss: 0.5100 - val_accuracy: 0.6500 - val_loss: 0.6492
# Epoch 36/180
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7474 - loss: 0.5245 - val_accuracy: 0.6000 - val_loss: 0.6767
# Epoch 37/180
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7513 - loss: 0.5209 - val_accuracy: 0.6167 - val_loss: 0.6698
# Epoch 38/180
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7818 - loss: 0.5059 - val_accuracy: 0.6167 - val_loss: 0.6605
# Epoch 39/180
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7639 - loss: 0.5309 - val_accuracy: 0.6333 - val_loss: 0.7025
# Epoch 40/180
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7658 - loss: 0.4927 - val_accuracy: 0.6167 - val_loss: 0.6689
# Epoch 41/180
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7746 - loss: 0.4904 - val_accuracy: 0.6167 - val_loss: 0.6684
# Epoch 42/180
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7079 - loss: 0.5416 - val_accuracy: 0.6167 - val_loss: 0.6678
# Epoch 43/180
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7374 - loss: 0.5370 - val_accuracy: 0.6667 - val_loss: 0.6450
# Epoch 44/180
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7608 - loss: 0.5213 - val_accuracy: 0.6333 - val_loss: 0.6456
# Epoch 45/180
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7498 - loss: 0.5067 - val_accuracy: 0.6167 - val_loss: 0.6589
# Epoch 46/180
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6868 - loss: 0.5668 - val_accuracy: 0.6333 - val_loss: 0.7582
# Epoch 47/180
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7607 - loss: 0.4883 - val_accuracy: 0.6167 - val_loss: 0.6606
# Epoch 48/180
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7323 - loss: 0.5448 - val_accuracy: 0.6167 - val_loss: 0.6644
# Epoch 49/180
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7564 - loss: 0.4994 - val_accuracy: 0.6167 - val_loss: 0.6513
# Epoch 50/180
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7558 - loss: 0.5157 - val_accuracy: 0.6333 - val_loss: 0.6473
# Epoch 51/180
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7319 - loss: 0.5365 - val_accuracy: 0.6333 - val_loss: 0.6452
# Epoch 52/180
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6775 - loss: 0.5731 - val_accuracy: 0.6167 - val_loss: 0.6627
# Epoch 53/180
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7293 - loss: 0.5431 - val_accuracy: 0.6167 - val_loss: 0.7028
# Epoch 54/180
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7339 - loss: 0.5540 - val_accuracy: 0.6167 - val_loss: 0.6524
# Epoch 55/180
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7418 - loss: 0.5012 - val_accuracy: 0.6167 - val_loss: 0.6704
# Epoch 56/180
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7686 - loss: 0.4929 - val_accuracy: 0.6333 - val_loss: 0.6486
# Epoch 57/180
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6994 - loss: 0.5376 - val_accuracy: 0.6167 - val_loss: 0.6968
# Epoch 58/180
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7753 - loss: 0.5250 - val_accuracy: 0.6667 - val_loss: 0.6450
# Epoch 59/180
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7373 - loss: 0.5521 - val_accuracy: 0.6500 - val_loss: 0.6439
# Epoch 60/180
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7415 - loss: 0.5486 - val_accuracy: 0.6333 - val_loss: 0.6519
# Epoch 61/180
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7474 - loss: 0.5123 - val_accuracy: 0.6167 - val_loss: 0.6556
# Epoch 62/180
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7538 - loss: 0.5200 - val_accuracy: 0.6167 - val_loss: 0.6632
# Epoch 63/180
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7275 - loss: 0.5355 - val_accuracy: 0.6167 - val_loss: 0.6844
# Epoch 64/180
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7627 - loss: 0.5021 - val_accuracy: 0.6167 - val_loss: 0.6539
# Epoch 65/180
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7605 - loss: 0.4788 - val_accuracy: 0.6167 - val_loss: 0.6752
# Epoch 66/180
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7781 - loss: 0.5137 - val_accuracy: 0.6000 - val_loss: 0.6829
# Epoch 67/180
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7695 - loss: 0.4760 - val_accuracy: 0.6000 - val_loss: 0.6727
# Epoch 68/180
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7238 - loss: 0.5470 - val_accuracy: 0.6167 - val_loss: 0.6611
# Epoch 69/180
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7261 - loss: 0.5456 - val_accuracy: 0.6167 - val_loss: 0.6968
# Epoch 70/180
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7689 - loss: 0.4965 - val_accuracy: 0.6333 - val_loss: 0.6436
# Epoch 71/180
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7623 - loss: 0.5142 - val_accuracy: 0.6000 - val_loss: 0.6799
# Epoch 72/180
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7652 - loss: 0.4790 - val_accuracy: 0.6333 - val_loss: 0.6450
# Epoch 73/180
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7218 - loss: 0.5934 - val_accuracy: 0.6167 - val_loss: 0.6528
# Epoch 74/180
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7730 - loss: 0.5108 - val_accuracy: 0.6167 - val_loss: 0.7074
# Epoch 75/180
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7555 - loss: 0.5236 - val_accuracy: 0.6167 - val_loss: 0.6931
# Epoch 76/180
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7682 - loss: 0.5065 - val_accuracy: 0.6167 - val_loss: 0.6694
# Epoch 77/180
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7405 - loss: 0.4876 - val_accuracy: 0.6333 - val_loss: 0.6500
# Epoch 78/180
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7157 - loss: 0.5430 - val_accuracy: 0.6167 - val_loss: 0.6681
# Epoch 79/180
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7778 - loss: 0.4941 - val_accuracy: 0.6167 - val_loss: 0.6614
# Epoch 80/180
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7388 - loss: 0.5300 - val_accuracy: 0.6000 - val_loss: 0.6713
# Epoch 81/180
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7374 - loss: 0.5157 - val_accuracy: 0.6167 - val_loss: 0.6639
# Epoch 82/180
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7220 - loss: 0.5529 - val_accuracy: 0.6167 - val_loss: 0.6701
# Epoch 83/180
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7188 - loss: 0.5858 - val_accuracy: 0.6167 - val_loss: 0.6862
# Epoch 84/180
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7442 - loss: 0.5272 - val_accuracy: 0.6333 - val_loss: 0.6526
# Epoch 85/180
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7584 - loss: 0.5043 - val_accuracy: 0.6167 - val_loss: 0.6643
# Epoch 86/180
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7689 - loss: 0.5014 - val_accuracy: 0.6500 - val_loss: 0.6494
# Epoch 87/180
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7309 - loss: 0.5222 - val_accuracy: 0.6500 - val_loss: 0.6490
# Epoch 88/180
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7493 - loss: 0.5127 - val_accuracy: 0.6167 - val_loss: 0.6574
# Epoch 89/180
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8075 - loss: 0.4797 - val_accuracy: 0.6833 - val_loss: 0.6413
# Epoch 90/180
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6826 - loss: 0.5737 - val_accuracy: 0.6167 - val_loss: 0.6549
# Epoch 91/180
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7604 - loss: 0.4954 - val_accuracy: 0.6333 - val_loss: 0.6462
# Epoch 92/180
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7161 - loss: 0.5464 - val_accuracy: 0.6167 - val_loss: 0.6577
# Epoch 93/180
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7493 - loss: 0.5205 - val_accuracy: 0.6167 - val_loss: 0.6720
# Epoch 94/180
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7594 - loss: 0.4886 - val_accuracy: 0.6333 - val_loss: 0.6402
# Epoch 95/180
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7590 - loss: 0.5133 - val_accuracy: 0.6167 - val_loss: 0.6650
# Epoch 96/180
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7494 - loss: 0.5464 - val_accuracy: 0.6167 - val_loss: 0.6655
# Epoch 97/180
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7680 - loss: 0.4788 - val_accuracy: 0.6167 - val_loss: 0.6598
# Epoch 98/180
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7003 - loss: 0.5771 - val_accuracy: 0.6333 - val_loss: 0.7018
# Epoch 99/180
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7191 - loss: 0.5614 - val_accuracy: 0.6500 - val_loss: 0.7074
# Epoch 100/180
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7679 - loss: 0.5044 - val_accuracy: 0.6167 - val_loss: 0.6530
# Epoch 101/180
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7187 - loss: 0.5192 - val_accuracy: 0.6000 - val_loss: 0.6796
# Epoch 102/180
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7591 - loss: 0.4994 - val_accuracy: 0.6167 - val_loss: 0.6645
# Epoch 103/180
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7664 - loss: 0.5239 - val_accuracy: 0.6167 - val_loss: 0.6558
# Epoch 104/180
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7072 - loss: 0.5714 - val_accuracy: 0.6167 - val_loss: 0.7152
# Epoch 105/180
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7781 - loss: 0.5111 - val_accuracy: 0.6167 - val_loss: 0.6457
# Epoch 106/180
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7000 - loss: 0.5485 - val_accuracy: 0.6167 - val_loss: 0.6909
# Epoch 107/180
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7840 - loss: 0.5004 - val_accuracy: 0.6500 - val_loss: 0.7127
# Epoch 108/180
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7116 - loss: 0.5499 - val_accuracy: 0.6167 - val_loss: 0.6642
# Epoch 109/180
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6928 - loss: 0.5772 - val_accuracy: 0.6167 - val_loss: 0.6841
# Epoch 110/180
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7996 - loss: 0.4778 - val_accuracy: 0.6167 - val_loss: 0.6533
# Epoch 111/180
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7248 - loss: 0.5220 - val_accuracy: 0.6167 - val_loss: 0.6652
# Epoch 112/180
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7550 - loss: 0.4959 - val_accuracy: 0.6167 - val_loss: 0.6523
# Epoch 113/180
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7667 - loss: 0.4926 - val_accuracy: 0.6167 - val_loss: 0.6819
# Epoch 114/180
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7967 - loss: 0.4817 - val_accuracy: 0.6167 - val_loss: 0.6520
# Epoch 115/180
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7475 - loss: 0.5412 - val_accuracy: 0.6167 - val_loss: 0.6628
# Epoch 116/180
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7296 - loss: 0.5333 - val_accuracy: 0.6333 - val_loss: 0.7135
# Epoch 117/180
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7904 - loss: 0.4999 - val_accuracy: 0.6833 - val_loss: 0.6366
# Epoch 118/180
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7090 - loss: 0.5777 - val_accuracy: 0.6000 - val_loss: 0.6700
# Epoch 119/180
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7514 - loss: 0.4962 - val_accuracy: 0.6333 - val_loss: 0.6405
# Epoch 120/180
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8058 - loss: 0.5102 - val_accuracy: 0.6167 - val_loss: 0.6577
# Epoch 121/180
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7973 - loss: 0.4801 - val_accuracy: 0.6167 - val_loss: 0.6668
# Epoch 122/180
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7343 - loss: 0.5421 - val_accuracy: 0.6167 - val_loss: 0.6650
# Epoch 123/180
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7437 - loss: 0.4975 - val_accuracy: 0.6167 - val_loss: 0.6618
# Epoch 124/180
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7848 - loss: 0.4620 - val_accuracy: 0.6500 - val_loss: 0.6443
# Epoch 125/180
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8062 - loss: 0.4740 - val_accuracy: 0.6500 - val_loss: 0.6379
# Epoch 126/180
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7861 - loss: 0.5375 - val_accuracy: 0.6000 - val_loss: 0.6693
# Epoch 127/180
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7500 - loss: 0.5336 - val_accuracy: 0.6167 - val_loss: 0.6486
# Epoch 128/180
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7347 - loss: 0.5572 - val_accuracy: 0.6333 - val_loss: 0.7314
# Epoch 129/180
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7678 - loss: 0.5304 - val_accuracy: 0.6167 - val_loss: 0.6876
# Epoch 130/180
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7608 - loss: 0.4989 - val_accuracy: 0.6167 - val_loss: 0.6617
# Epoch 131/180
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7222 - loss: 0.4920 - val_accuracy: 0.6167 - val_loss: 0.6425
# Epoch 132/180
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7400 - loss: 0.5629 - val_accuracy: 0.6167 - val_loss: 0.6645
# Epoch 133/180
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7450 - loss: 0.5138 - val_accuracy: 0.6333 - val_loss: 0.6443
# Epoch 134/180
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7561 - loss: 0.4847 - val_accuracy: 0.6500 - val_loss: 0.6404
# Epoch 135/180
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7586 - loss: 0.5399 - val_accuracy: 0.6000 - val_loss: 0.6669
# Epoch 136/180
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7303 - loss: 0.5330 - val_accuracy: 0.6167 - val_loss: 0.6863
# Epoch 137/180
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7772 - loss: 0.5175 - val_accuracy: 0.6333 - val_loss: 0.6391
# Epoch 138/180
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7711 - loss: 0.4949 - val_accuracy: 0.6167 - val_loss: 0.6564
# Epoch 139/180
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7374 - loss: 0.5284 - val_accuracy: 0.6167 - val_loss: 0.6588
# Epoch 140/180
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7689 - loss: 0.4697 - val_accuracy: 0.6167 - val_loss: 0.6535
# Epoch 141/180
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8116 - loss: 0.4636 - val_accuracy: 0.6500 - val_loss: 0.7221
# Epoch 142/180
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7123 - loss: 0.5553 - val_accuracy: 0.6333 - val_loss: 0.7201
# Epoch 143/180
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7296 - loss: 0.5516 - val_accuracy: 0.6167 - val_loss: 0.6745
# Epoch 144/180
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7751 - loss: 0.4997 - val_accuracy: 0.6167 - val_loss: 0.6476
# Epoch 145/180
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7431 - loss: 0.5323 - val_accuracy: 0.6167 - val_loss: 0.6711
# Epoch 146/180
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7418 - loss: 0.5100 - val_accuracy: 0.6167 - val_loss: 0.6472
# Epoch 147/180
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7203 - loss: 0.5399 - val_accuracy: 0.6333 - val_loss: 0.7308
# Epoch 148/180
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7381 - loss: 0.5779 - val_accuracy: 0.6167 - val_loss: 0.6532
# Epoch 149/180
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7413 - loss: 0.5056 - val_accuracy: 0.6167 - val_loss: 0.6784
# Epoch 150/180
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7577 - loss: 0.4612 - val_accuracy: 0.6167 - val_loss: 0.6600
# Epoch 151/180
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6764 - loss: 0.5713 - val_accuracy: 0.6333 - val_loss: 0.7331
# Epoch 152/180
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8118 - loss: 0.4482 - val_accuracy: 0.6500 - val_loss: 0.6340
# Epoch 153/180
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7180 - loss: 0.5312 - val_accuracy: 0.6500 - val_loss: 0.6966
# Epoch 154/180
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7334 - loss: 0.5675 - val_accuracy: 0.6167 - val_loss: 0.6739
# Epoch 155/180
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7163 - loss: 0.5459 - val_accuracy: 0.6167 - val_loss: 0.6448
# Epoch 156/180
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7897 - loss: 0.4671 - val_accuracy: 0.6333 - val_loss: 0.6753
# Epoch 157/180
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7360 - loss: 0.5400 - val_accuracy: 0.6333 - val_loss: 0.6363
# Epoch 158/180
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7686 - loss: 0.5097 - val_accuracy: 0.6333 - val_loss: 0.6455
# Epoch 159/180
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7623 - loss: 0.4971 - val_accuracy: 0.6167 - val_loss: 0.6685
# Epoch 160/180
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8056 - loss: 0.4757 - val_accuracy: 0.6333 - val_loss: 0.6353
# Epoch 161/180
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7876 - loss: 0.4851 - val_accuracy: 0.6333 - val_loss: 0.6837
# Epoch 162/180
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7515 - loss: 0.5114 - val_accuracy: 0.6167 - val_loss: 0.6732
# Epoch 163/180
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7552 - loss: 0.4997 - val_accuracy: 0.6167 - val_loss: 0.6464
# Epoch 164/180
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7633 - loss: 0.4937 - val_accuracy: 0.6333 - val_loss: 0.6335
# Epoch 165/180
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7528 - loss: 0.5085 - val_accuracy: 0.6167 - val_loss: 0.6761
# Epoch 166/180
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7634 - loss: 0.5065 - val_accuracy: 0.6333 - val_loss: 0.6887
# Epoch 167/180
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7745 - loss: 0.5048 - val_accuracy: 0.6167 - val_loss: 0.6560
# Epoch 168/180
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8098 - loss: 0.4579 - val_accuracy: 0.6500 - val_loss: 0.6359
# Epoch 169/180
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7237 - loss: 0.5388 - val_accuracy: 0.6167 - val_loss: 0.6754
# Epoch 170/180
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7242 - loss: 0.5267 - val_accuracy: 0.6500 - val_loss: 0.6975
# Epoch 171/180
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7072 - loss: 0.5810 - val_accuracy: 0.6333 - val_loss: 0.6719
# Epoch 172/180
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7430 - loss: 0.5399 - val_accuracy: 0.6833 - val_loss: 0.6286
# Epoch 173/180
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7319 - loss: 0.5224 - val_accuracy: 0.6333 - val_loss: 0.6339
# Epoch 174/180
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7604 - loss: 0.5034 - val_accuracy: 0.6667 - val_loss: 0.6319
# Epoch 175/180
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7837 - loss: 0.4618 - val_accuracy: 0.7167 - val_loss: 0.6265
# Epoch 176/180
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6991 - loss: 0.5766 - val_accuracy: 0.6167 - val_loss: 0.6458
# Epoch 177/180
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7960 - loss: 0.4779 - val_accuracy: 0.6833 - val_loss: 0.6295
# Epoch 178/180
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7556 - loss: 0.5249 - val_accuracy: 0.6167 - val_loss: 0.6569
# Epoch 179/180
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7570 - loss: 0.5126 - val_accuracy: 0.6167 - val_loss: 0.6587
# Epoch 180/180
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7689 - loss: 0.4914 - val_accuracy: 0.6167 - val_loss: 0.6524

# %%
train_acc3 =  model.history.history['accuracy']
val_acc3 = model.history.history['val_accuracy']
train_loss3 = model.history.history['loss']
val_loss3 = model.history.history['val_loss']

# %%
from matplotlib import pyplot as plt
epochs = range(len(train_acc))
plt.plot(epochs, train_acc3, 'b', label='Training Accuracy')
plt.plot(epochs, val_acc3, 'g', label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.grid()
plt.legend()
plt.figure()
plt.show()

plt.plot(epochs, train_loss3, 'b', label='Training Loss')
plt.plot(epochs, val_loss3, 'g', label='Validation Loss')
plt.title('Training and Validation Loss')
plt.grid()
plt.legend()
plt.show()

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

rf = RandomForestClassifier(n_estimators=100, random_state=42)
rf.fit(X_train, y_train)
y_pred_rf = rf.predict(X_test)
rf_accuracy = accuracy_score(y_test, y_pred_rf)
print(f'Random Forest Accuracy: {rf_accuracy}')
# Out:
# Random Forest Accuracy: 0.75

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

rf = RandomForestClassifier(n_estimators=100, random_state=42)
rf.fit(X_train, y_train)
y_pred_rf = rf.predict(X_test)
rf_accuracy = accuracy_score(y_test, y_pred_rf)
print(f'Random Forest Accuracy: {rf_accuracy}')

keras_accuracy = model.evaluate(X_test2, y_test)[1]
print(f'Keras Functional Model Accuracy: {keras_accuracy}')

accuracies = {
    'Random Forest': rf_accuracy,
    'Keras Functional Model': keras_accuracy
}

print("Model Accuracies:")
for model_name, accuracy in accuracies.items():
    print(f"{model_name}: {accuracy}")
# Out:
# Random Forest Accuracy: 0.75
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6625 - loss: 0.6398
# Keras Functional Model Accuracy: 0.6499999761581421
# Model Accuracies:
# Random Forest: 0.75
# Keras Functional Model: 0.6499999761581421

# %%
from sklearn.metrics import classification_report

y_pred_nn = (model.predict(X_test2) > 0.5).astype(int)
print("Neural Network:")
print(classification_report(y_test, y_pred_nn))

# Random Forest
print("Random Forest:")
print(classification_report(y_test, y_pred_rf))
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# Neural Network:
#               precision    recall  f1-score   support
#
#            0       0.62      0.91      0.74        35
#            1       0.62      0.20      0.30        25
#
#     accuracy                           0.62        60
#    macro avg       0.62      0.56      0.52        60
# weighted avg       0.62      0.62      0.56        60
#
# Random Forest:
#               precision    recall  f1-score   support
#
#            0       0.72      0.94      0.81        35
#            1       0.86      0.48      0.62        25
#
#     accuracy                           0.75        60
#    macro avg       0.79      0.71      0.72        60
# weighted avg       0.78      0.75      0.73        60

# %%
import matplotlib.pyplot as plt


min_epochs = min(len(train_acc), len(train_acc2), len(train_acc3))
epochs = range(1, min_epochs + 1)

plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1)
plt.plot(epochs, train_acc[:min_epochs], 'r', label='Model 1 Training acc')
plt.plot(epochs, val_acc[:min_epochs], 'r--', label='Model 1 Validation acc')
plt.plot(epochs, train_acc2[:min_epochs], 'g', label='Model 2 Training acc')
plt.plot(epochs, val_acc2[:min_epochs], 'g--', label='Model 2 Validation acc')
plt.plot(epochs, train_acc3[:min_epochs], 'b', label='Model 3 Training acc')
plt.plot(epochs, val_acc3[:min_epochs], 'b--', label='Model 3 Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(epochs, train_loss[:min_epochs], 'r', label='Model 1 Training loss')
plt.plot(epochs, val_loss[:min_epochs], 'r--', label='Model 1 Validation loss')
plt.plot(epochs, train_loss2[:min_epochs], 'g', label='Model 2 Training loss')
plt.plot(epochs, val_loss2[:min_epochs], 'g--', label='Model 2 Validation loss')
plt.plot(epochs, train_loss3[:min_epochs], 'b', label='Model 3 Training loss')
plt.plot(epochs, val_loss3[:min_epochs], 'b--', label='Model 3 Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.show()

# %%
import matplotlib.pyplot as plt

min_epochs = min(len(train_acc), len(train_acc2), len(train_acc3))
epochs = range(1, min_epochs + 1)

plt.figure(figsize=(8, 6))

# Plotting Accuracy
plt.plot(epochs, train_acc[:min_epochs], 'r', label='Model 1 Training acc')
plt.plot(epochs, train_acc2[:min_epochs], 'g', label='Model 2 Training acc')
plt.plot(epochs, train_acc3[:min_epochs], 'b', label='Model 3 Training acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.show()

# %% [markdown]
# ## RESULT

# %%
import matplotlib.pyplot as plt


min_epochs = min(len(train_acc), len(train_acc2), len(train_acc3))
epochs = range(1, min_epochs + 1)

plt.figure(figsize=(8, 6))

plt.plot(epochs, train_acc[:min_epochs], 'r', label='Model 1 Training acc')
plt.plot(epochs, train_acc2[:min_epochs], 'g', label='Model 2 Training acc')
plt.plot(epochs, train_acc3[:min_epochs], 'b', label='Model 3 Training acc')

train_acc_epoch = train_acc.index(max(train_acc)) + 1
train_acc2_epoch = train_acc2.index(max(train_acc2)) + 1
train_acc3_epoch = train_acc3.index(max(train_acc3)) + 1

plt.scatter(train_acc_epoch, max(val_acc), color='r', marker='o', label=f'Model 1 train_acc Acc ({train_acc_epoch})')
plt.scatter(train_acc2_epoch, max(val_acc2), color='g', marker='o', label=f'Model 2 train_acc2 Acc ({train_acc2_epoch})')
plt.scatter(train_acc3_epoch, max(val_acc3), color='b', marker='o', label=f'Model 3 train_acc3 Acc ({train_acc3_epoch})')

plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.show()
