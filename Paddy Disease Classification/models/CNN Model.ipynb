jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/train_images/tungro/107705.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/train_images/tungro/103252.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/train_images/tungro/109447.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/train_images/tungro/103777.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/train_images/tungro/105080.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/train_images/tungro/106389.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/train_images/tungro/104890.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/train_images/tungro/110062.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/train_images/tungro/105077.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/train_images/tungro/110273.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/train_images/tungro/100853.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/train_images/tungro/100949.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/train_images/tungro/105934.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/train_images/tungro/108895.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/train_images/tungro/101040.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/train_images/tungro/102024.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/train_images/tungro/102895.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/train_images/tungro/101230.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/train_images/tungro/100910.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/train_images/tungro/103416.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/train_images/tungro/100689.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/train_images/tungro/106878.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/train_images/tungro/106884.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/train_images/tungro/103528.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/train_images/tungro/102612.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/train_images/tungro/108314.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/train_images/tungro/107239.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/train_images/tungro/102974.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/train_images/tungro/103646.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/train_images/tungro/109600.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/train_images/tungro/103841.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/train_images/tungro/103039.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/train_images/tungro/109169.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/train_images/tungro/102585.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/train_images/tungro/104914.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/train_images/tungro/103537.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/train_images/tungro/105883.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/train_images/tungro/107258.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/train_images/tungro/103091.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/train_images/tungro/107964.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/train_images/tungro/109662.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/train_images/tungro/108835.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/train_images/tungro/107605.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/train_images/tungro/108080.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/train_images/tungro/104492.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/train_images/tungro/106818.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/train_images/tungro/103133.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/train_images/tungro/107746.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/train_images/tungro/109555.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/train_images/tungro/106980.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/train_images/tungro/108933.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/train_images/tungro/102158.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/train_images/tungro/110332.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/train_images/tungro/107415.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/train_images/tungro/106749.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/train_images/tungro/110199.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/train_images/tungro/106699.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/train_images/tungro/101389.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/train_images/tungro/104422.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/train_images/tungro/104063.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/train_images/tungro/106060.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/train_images/tungro/106242.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/train_images/tungro/110220.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/train_images/tungro/109557.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/train_images/tungro/100270.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/train_images/tungro/100911.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/train_images/tungro/109086.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/train_images/tungro/100723.jpg
# ...
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/test_images/203355.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/test_images/202226.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/test_images/201824.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/test_images/203210.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/test_images/200089.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/test_images/203332.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/test_images/201544.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/test_images/203164.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/test_images/202318.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/test_images/201849.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/test_images/200077.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/test_images/202731.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/test_images/201183.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/test_images/200239.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/test_images/201536.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/test_images/200299.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/test_images/202386.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/test_images/201738.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/test_images/201314.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/test_images/201742.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/test_images/201988.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/test_images/200052.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/test_images/200533.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/test_images/200267.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/test_images/203065.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/test_images/202098.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/test_images/200247.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/test_images/200675.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/test_images/203082.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/test_images/200391.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/test_images/202392.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/test_images/200026.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/test_images/200654.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/test_images/201142.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/test_images/201959.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/test_images/202394.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/test_images/200653.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/test_images/200591.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/test_images/203023.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/test_images/201647.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/test_images/200864.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/test_images/200643.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/test_images/203147.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/test_images/201962.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/test_images/200458.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/test_images/203329.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/test_images/201297.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/test_images/202652.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/test_images/201172.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/test_images/201853.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/test_images/200148.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/test_images/201461.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/test_images/201395.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/test_images/201460.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/test_images/202453.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/test_images/201562.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/test_images/203257.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/test_images/200802.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/test_images/200684.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/test_images/201657.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/test_images/203322.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/test_images/201009.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/test_images/201798.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/test_images/202951.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/test_images/203333.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/test_images/200610.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/test_images/202749.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/test_images/200407.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/test_images/202906.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/test_images/202263.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/test_images/203251.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/test_images/203272.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/test_images/200310.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/test_images/201398.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/test_images/200116.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/test_images/202114.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/test_images/201950.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/test_images/201223.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/test_images/201984.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/test_images/203118.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/test_images/203030.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/test_images/201454.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/test_images/203371.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/test_images/201083.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/test_images/200678.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/test_images/201437.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/test_images/202851.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/test_images/203334.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/test_images/200930.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/test_images/202908.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/test_images/200665.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/test_images/201721.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/test_images/202449.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/test_images/200096.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/test_images/201584.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/test_images/200354.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/test_images/203123.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/test_images/201532.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/test_images/202268.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/test_images/200034.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/test_images/201488.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/test_images/200140.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/test_images/202014.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/test_images/202236.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/test_images/202049.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/test_images/200277.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/test_images/202339.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/test_images/202305.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/test_images/201907.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/test_images/201206.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/test_images/201526.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/test_images/200163.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/test_images/201290.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/test_images/201396.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/test_images/201637.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/test_images/201640.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/test_images/200969.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/test_images/202938.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/test_images/201989.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/test_images/200663.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/test_images/203049.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/test_images/200320.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/test_images/200635.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/test_images/203303.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/test_images/201684.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/test_images/202156.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/test_images/200337.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/test_images/200245.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/test_images/203226.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/test_images/202552.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/test_images/202594.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/test_images/201966.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/test_images/202345.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/test_images/200139.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/test_images/200510.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/test_images/203462.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/test_images/202212.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/test_images/200088.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/test_images/200257.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/test_images/200225.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/test_images/200543.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/test_images/203033.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/test_images/201513.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/test_images/200078.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/test_images/200743.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/test_images/203357.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/test_images/202328.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/test_images/200266.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/test_images/203381.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/test_images/201785.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/test_images/201704.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/test_images/200955.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/test_images/200019.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/test_images/203028.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/test_images/200304.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/test_images/201518.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/test_images/201181.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/test_images/202024.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/test_images/203088.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/test_images/201524.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/test_images/201237.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/test_images/202203.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/test_images/202421.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/test_images/201677.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/test_images/202856.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/test_images/201053.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/test_images/201018.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/test_images/202793.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/test_images/202207.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/test_images/201517.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/test_images/201441.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/test_images/201823.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/test_images/202312.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/test_images/200905.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/test_images/202099.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/test_images/201176.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/test_images/203316.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/test_images/201462.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/test_images/200426.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/test_images/202213.jpg
# /kaggle/input/paddy-disease-dataset/paddy-disease-classification/test_images/202862.jpg

# %% [markdown]
# ### Importing libraries

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns 
import tensorflow as tf 
from tensorflow import keras 
from keras import Sequential
from keras.layers import Dense,Conv2D,MaxPooling2D,Flatten,BatchNormalization,Dropout

# %% [markdown]
# ### Dataset

# %%
seed = 40
train_ds = keras.utils.image_dataset_from_directory(
    directory='/kaggle/input/paddy-disease-dataset/paddy-disease-classification/train_images',
    labels="inferred",
    label_mode="int",
    class_names=None,
    color_mode="rgb",
    batch_size=32,
    image_size=(256, 256),
    validation_split=0.2,
    subset="training",
    seed=seed  # Add seed argument
)

validation_ds = keras.utils.image_dataset_from_directory(
    directory='/kaggle/input/paddy-disease-dataset/paddy-disease-classification/train_images',
    labels="inferred",
    label_mode="int",
    class_names=None,
    color_mode="rgb",
    batch_size=32,
    image_size=(256, 256),
    validation_split=0.2,
    subset="validation",
    seed=seed  # Add seed argument
)
# Out:
# Found 10407 files belonging to 10 classes.
# Using 8326 files for training.
# Found 10407 files belonging to 10 classes.
# Using 2081 files for validation.

# %%
# Normalizing the data 
def process(image,label):
    image = tf.cast(image/255,tf.float32)
    return image,label
train_ds = train_ds.map(process)
validation_ds = validation_ds.map(process)

# %%
import os

# Get the directory path from the DirectoryIterator object
dataset_path = '/kaggle/input/paddy-disease-dataset/paddy-disease-classification/train_images'

# Count the number of subdirectories (classes)
num_classes = len([name for name in os.listdir(dataset_path) if os.path.isdir(os.path.join(dataset_path, name))])

print("Number of classes:", num_classes)
# Out:
# Number of classes: 10

# %%
# create CNN model

model = Sequential()


model.add(Conv2D(128,kernel_size=(3,3),padding='valid',strides = 1,activation='relu',input_shape=(256,256,3)))
model.add(MaxPooling2D(pool_size=(3,3),padding='valid'))

model.add(Conv2D(64,kernel_size=(3,3),padding='valid',strides = 1,activation='relu'))
model.add(MaxPooling2D(pool_size=(3,3),padding='valid'))

model.add(Conv2D(32,kernel_size=(3,3),padding='same',strides = 1,activation='relu'))
model.add(MaxPooling2D(pool_size=(3,3),padding='valid'))

model.add(Conv2D(16,kernel_size=(3,3),padding='same',strides = 1,activation='relu'))
model.add(MaxPooling2D(pool_size=(3,3),padding='valid'))

model.add(Flatten())

model.add(Dense(128,activation='relu'))
model.add(Dropout(0.1))
model.add(Dense(64,activation='relu'))
model.add(Dropout(0.1))
model.add(Dense(num_classes,activation='softmax'))
# Out:
# /opt/conda/lib/python3.10/site-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 254, 254, 128)  │         3,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 84, 84, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 82, 82, 64)     │        73,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 27, 27, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 27, 27, 32)     │        18,464 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 9, 9, 32)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 9, 9, 16)       │         4,624 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 3, 3, 16)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 144)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │        18,560 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 10)             │           650 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 127,930 (499.73 KB)
#  Trainable params: 127,930 (499.73 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
from tensorflow.keras.optimizers.legacy import Adam

model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
early_stopping = keras.callbacks.EarlyStopping(
    monitor="val_loss",
    min_delta=0,
    patience=5,
    verbose=0,
    mode="auto",
    baseline=None,  # Set to the value of val_loss at the desired epoch
    restore_best_weights=False,
)

# %%
# real waly images use ni hongy jo images transform han wo use hongy
history = model.fit(train_ds, validation_data=validation_ds, epochs=500,callbacks=[early_stopping] )
# Out:
# Epoch 1/500
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1728655961.819403      82 service.cc:145] XLA service 0x7c73c400ded0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1728655961.819481      82 service.cc:153]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
#   3/261 ━━━━━━━━━━━━━━━━━━━━ 11s 43ms/step - accuracy: 0.0816 - loss: 2.3086
# I0000 00:00:1728655969.761492      82 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 35s 96ms/step - accuracy: 0.1964 - loss: 2.1369 - val_accuracy: 0.3878 - val_loss: 1.7645
# Epoch 2/500
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 14s 52ms/step - accuracy: 0.3765 - loss: 1.7563 - val_accuracy: 0.4224 - val_loss: 1.6145
# Epoch 3/500
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 13s 50ms/step - accuracy: 0.4598 - loss: 1.5672 - val_accuracy: 0.5103 - val_loss: 1.4529
# Epoch 4/500
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 14s 53ms/step - accuracy: 0.5365 - loss: 1.3625 - val_accuracy: 0.5579 - val_loss: 1.3062
# Epoch 5/500
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 13s 51ms/step - accuracy: 0.6096 - loss: 1.1708 - val_accuracy: 0.6468 - val_loss: 1.0728
# Epoch 6/500
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 14s 52ms/step - accuracy: 0.6581 - loss: 1.0325 - val_accuracy: 0.6444 - val_loss: 1.0699
# Epoch 7/500
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 14s 52ms/step - accuracy: 0.7060 - loss: 0.8909 - val_accuracy: 0.7088 - val_loss: 0.9128
# Epoch 8/500
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 14s 52ms/step - accuracy: 0.7196 - loss: 0.8401 - val_accuracy: 0.7299 - val_loss: 0.8351
# Epoch 9/500
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 14s 54ms/step - accuracy: 0.7680 - loss: 0.7192 - val_accuracy: 0.7400 - val_loss: 0.8307
# Epoch 10/500
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 14s 52ms/step - accuracy: 0.7833 - loss: 0.6559 - val_accuracy: 0.7564 - val_loss: 0.8046
# Epoch 11/500
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 14s 54ms/step - accuracy: 0.8006 - loss: 0.5920 - val_accuracy: 0.7684 - val_loss: 0.7828
# Epoch 12/500
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 13s 51ms/step - accuracy: 0.8176 - loss: 0.5438 - val_accuracy: 0.7674 - val_loss: 0.7860
# Epoch 13/500
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 14s 54ms/step - accuracy: 0.8381 - loss: 0.4842 - val_accuracy: 0.7746 - val_loss: 0.7670
# Epoch 14/500
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 13s 51ms/step - accuracy: 0.8524 - loss: 0.4322 - val_accuracy: 0.7987 - val_loss: 0.7146
# Epoch 15/500
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 13s 51ms/step - accuracy: 0.8601 - loss: 0.4153 - val_accuracy: 0.8160 - val_loss: 0.6475
# Epoch 16/500
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 14s 52ms/step - accuracy: 0.8770 - loss: 0.3655 - val_accuracy: 0.8097 - val_loss: 0.6803
# Epoch 17/500
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 13s 51ms/step - accuracy: 0.8883 - loss: 0.3430 - val_accuracy: 0.7847 - val_loss: 0.7986
# Epoch 18/500
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 14s 54ms/step - accuracy: 0.8857 - loss: 0.3348 - val_accuracy: 0.8169 - val_loss: 0.7037
# Epoch 19/500
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 13s 51ms/step - accuracy: 0.8796 - loss: 0.3517 - val_accuracy: 0.8169 - val_loss: 0.7019
# Epoch 20/500
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 13s 51ms/step - accuracy: 0.8951 - loss: 0.3125 - val_accuracy: 0.8318 - val_loss: 0.7073

# %%
# Plotting the training and validation accuracy
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Training and Validation Accuracy')
plt.legend()
plt.show()

# %%
model.save('rice_model.h5')
