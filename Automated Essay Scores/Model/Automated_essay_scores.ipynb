# %% [markdown]
# ## Importing Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import re
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense, SpatialDropout1D, Input, Activation, Dropout
from keras.models import Model
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from keras.callbacks import EarlyStopping
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Dataset

# %%
df = pd.read_csv('../Dataset/train.csv')
df
# Out:
#       essay_id                                          full_text  score
# 0      000d118  Many people have car where they live. The thin...      3
# 1      000fe60  I am a scientist at NASA that is discussing th...      3
# 2      001ab80  People always wish they had the same technolog...      4
# 3      001bdc0  We all heard about Venus, the planet without a...      4
# 4      002ba53  Dear, State Senator\n\nThis is a letter to arg...      3
# ...        ...                                                ...    ...
# 17302  ffd378d  the story " The Challenge of Exploing Venus " ...      2
# 17303  ffddf1f  Technology has changed a lot of ways that we l...      4
# 17304  fff016d  If you don't like sitting around all day than ...      2
# 17305  fffb49b  In "The Challenge of Exporing Venus," the auth...      1
# 17306  fffed3e  Venus is worthy place to study but dangerous. ...      2
#
# [17307 rows x 3 columns]

# %% [markdown]
# ### Scoring Criteria
#
# The score indicates the quality of student-written argumentative essays, rated based on perspective, critical thinking, evidence, organization, language, and grammar/mechanics.
#
# | Score | Description |
# |-------|-------------|
# | 6     | Clear mastery, few errors, outstanding critical thinking, appropriate evidence, well-organized, skilled language use. |
# | 5     | Reasonable mastery, some errors, strong critical thinking, generally appropriate evidence, well-organized, good language use. |
# | 4     | Adequate mastery, occasional lapses, competent critical thinking, adequate evidence, generally organized, fair language use. |
# | 3     | Developing mastery, weaknesses, limited critical thinking, inconsistent evidence, some organization, fair language use. |
# | 2     | Little mastery, serious flaws, weak critical thinking, insufficient evidence, poor organization, frequent errors. |
# | 1     | Very little mastery, severe flaws, no viable point of view, disorganized, pervasive errors. |

# %% [markdown]
# ## EDA (Exploratory Data Analysis)

# %%
# displaying basic information

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17307 entries, 0 to 17306
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   essay_id   17307 non-null  object
#  1   full_text  17307 non-null  object
#  2   score      17307 non-null  int64
# dtypes: int64(1), object(2)
# memory usage: 405.8+ KB

# %%
# displaying basic information

df.describe()
# Out:
#               score
# count  17307.000000
# mean       2.948402
# std        1.044899
# min        1.000000
# 25%        2.000000
# 50%        3.000000
# 75%        4.000000
# max        6.000000

# %%
# checking for missing values

df.isnull().sum()
# Out:
# essay_id     0
# full_text    0
# score        0
# dtype: int64

# %%
# Analyze the distribution of essay scores

sns.histplot(df['score'], kde=True)
plt.title('Distribution of Essay Scores')
plt.xlabel('Score')
plt.ylabel('Frequency')
plt.savefig('../Images/Score Distribution.png')
plt.show()

# %%
# Calculate the length of each essay
df['essay_length'] = df['full_text'].apply(lambda x: len(x.split()))

# Plot the distribution of essay lengths
plt.figure(figsize=(10, 6))
sns.histplot(df['essay_length'], kde=True, bins=30)
plt.title('Distribution of Essay Lengths')
plt.xlabel('Essay Length (Number of Words)')
plt.ylabel('Frequency')
plt.savefig('../Images/Length Distribution.png')
plt.show()

# %% [markdown]
# ## Data Preprocessing

# %%
stop_words = set(stopwords.words('english'))
def remove_stop_words(essay):
    word_tokens = word_tokenize(essay) 
    filtered_sentence = [] 
    for w in word_tokens: 
        if w not in stop_words: 
            filtered_sentence.append(w)
    return ' '.join(filtered_sentence)

# %%
def preprocess_text(essay):
    essay = re.sub(r'\d+', '', essay)
    essay = re.sub(r'[^\w\s]', '', essay)
    tokens = word_tokenize(essay.lower())
    return tokens

# %%
df['clean_essay'] = df['full_text'].apply(lambda x:remove_stop_words(x))

# %%
df['clean_essay'] = df['clean_essay'].apply(preprocess_text)

# %%
df['cleaned_essay'].head()
# Out:
# 0    Many people car live . The thing n't know use ...
# 1    I scientist NASA discussing `` face '' mars . ...
# 2    People always wish technology seen movies , be...
# 3    We heard Venus , planet without almost oxygen ...
# 4    Dear , State Senator This letter argue favor k...
# Name: cleaned_essay, dtype: object

# %% [markdown]
# ## LSTM Model

# %%
# Tokenize the text

tokenizer = Tokenizer(num_words=5000)
tokenizer.fit_on_texts(df['cleaned_essay'])
X = tokenizer.texts_to_sequences(df['cleaned_essay'])
X = pad_sequences(X, maxlen=200)
Y = df['score']

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %%
def model():
    model = Sequential()
    model.add(Embedding(input_dim=5000, output_dim=128, input_length=200))
    model.add(SpatialDropout1D(0.2))
    model.add(LSTM(128, dropout=0.2, recurrent_dropout=0.2, return_sequences=True))
    model.add(LSTM(64, dropout=0.2, recurrent_dropout=0.2))
    model.add(Dense(32, activation='relu'))
    model.add(Dropout(0.2))
    model.add(Dense(1, activation='linear'))
    return model

# %%
model = model()
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_7 (Embedding)     (None, 200, 128)          640000
#
#  spatial_dropout1d_6 (Spati  (None, 200, 128)          0
#  alDropout1D)
#
#  lstm_8 (LSTM)               (None, 200, 128)          131584
#
#  lstm_9 (LSTM)               (None, 64)                49408
#
#  dense_3 (Dense)             (None, 32)                2080
#
#  dropout_4 (Dropout)         (None, 32)                0
#
#  dense_4 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 823105 (3.14 MB)
# Trainable params: 823105 (3.14 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.compile(loss='mean_squared_error', optimizer='adam', metrics=['mean_squared_error'])

# %%
history = model.fit(X_train ,y_train,batch_size=64, validation_split=0.2, epochs=15)
# Out:
# Epoch 1/15
# 174/174 [==============================] - 175s 1s/step - loss: 0.8395 - mean_squared_error: 0.8395 - val_loss: 0.6107 - val_mean_squared_error: 0.6107
# Epoch 2/15
# 174/174 [==============================] - 172s 989ms/step - loss: 0.7017 - mean_squared_error: 0.7017 - val_loss: 0.6134 - val_mean_squared_error: 0.6134
# Epoch 3/15
# 174/174 [==============================] - 171s 982ms/step - loss: 0.6136 - mean_squared_error: 0.6136 - val_loss: 0.4824 - val_mean_squared_error: 0.4824
# Epoch 4/15
# 174/174 [==============================] - 173s 993ms/step - loss: 0.5499 - mean_squared_error: 0.5499 - val_loss: 0.4952 - val_mean_squared_error: 0.4952
# Epoch 5/15
# 174/174 [==============================] - 174s 997ms/step - loss: 0.6212 - mean_squared_error: 0.6212 - val_loss: 0.5294 - val_mean_squared_error: 0.5294
# Epoch 6/15
# 174/174 [==============================] - 170s 979ms/step - loss: 0.6346 - mean_squared_error: 0.6346 - val_loss: 0.4950 - val_mean_squared_error: 0.4950
# Epoch 7/15
# 174/174 [==============================] - 173s 993ms/step - loss: 0.5895 - mean_squared_error: 0.5895 - val_loss: 0.5201 - val_mean_squared_error: 0.5201
# Epoch 8/15
# 174/174 [==============================] - 174s 998ms/step - loss: 0.5689 - mean_squared_error: 0.5689 - val_loss: 0.5085 - val_mean_squared_error: 0.5085
# Epoch 9/15
# 174/174 [==============================] - 177s 1s/step - loss: 0.5132 - mean_squared_error: 0.5132 - val_loss: 0.5175 - val_mean_squared_error: 0.5175
# Epoch 10/15
# 174/174 [==============================] - 181s 1s/step - loss: 0.4526 - mean_squared_error: 0.4526 - val_loss: 0.4903 - val_mean_squared_error: 0.4903
# Epoch 11/15
# 174/174 [==============================] - 175s 1s/step - loss: 0.4426 - mean_squared_error: 0.4426 - val_loss: 0.5113 - val_mean_squared_error: 0.5113
# Epoch 12/15
# 174/174 [==============================] - 172s 989ms/step - loss: 0.4111 - mean_squared_error: 0.4111 - val_loss: 0.6207 - val_mean_squared_error: 0.6207
# Epoch 13/15
# 174/174 [==============================] - 174s 997ms/step - loss: 0.4121 - mean_squared_error: 0.4121 - val_loss: 0.5109 - val_mean_squared_error: 0.5109
# Epoch 14/15
# 174/174 [==============================] - 182s 1s/step - loss: 0.5258 - mean_squared_error: 0.5258 - val_loss: 0.5341 - val_mean_squared_error: 0.5341
# Epoch 15/15
# 174/174 [==============================] - 170s 979ms/step - loss: 0.4582 - mean_squared_error: 0.4582 - val_loss: 0.5380 - val_mean_squared_error: 0.5380

# %%
# Evaluation with Quadratic Weighted Kappa

from sklearn.metrics import cohen_kappa_score
import numpy as np

# Predict using the trained model
y_pred = model.predict(X_test).flatten()
y_pred = np.rint(y_pred)  # Round predictions to nearest integer

# Calculate Quadratic Weighted Kappa
kappa_score = cohen_kappa_score(y_test, y_pred, weights='quadratic')
print(f'Quadratic Weighted Kappa: {kappa_score}')
# Out:
# 109/109 [==============================] - 11s 96ms/step
# Quadratic Weighted Kappa: 0.6764134409230693

# %%
# Visualization of Training History

plt.figure(figsize=(12, 6))
plt.plot(history.history['loss'], label='MSE')
plt.plot(history.history['val_loss'], label='Val MSE')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loass')
plt.legend()
plt.savefig('../Images/LSTM Loss.png')
plt.show()

# %% [markdown]
# ## GRU Model

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, GRU, Dense, Dropout, SpatialDropout1D

# Define the GRU model
def model():
    model_gru = Sequential()
    model_gru.add(Embedding(input_dim=5000, output_dim=128, input_length=200))
    model_gru.add(SpatialDropout1D(0.2))
    model_gru.add(GRU(128, dropout=0.2, recurrent_dropout=0.2, return_sequences=True))
    model_gru.add(GRU(64, dropout=0.2, recurrent_dropout=0.2))
    model_gru.add(Dense(32, activation='relu'))
    model_gru.add(Dropout(0.2))
    model_gru.add(Dense(1, activation='linear'))
    return model_gru

# %%
model_gru = model()
model_gru.compile(loss='mean_squared_error', optimizer='adam', metrics=['mean_squared_error'])
model_gru.summary()

# Train the model
history_gru = model_gru.fit(X, Y, epochs=20, batch_size=64, validation_split=0.2)
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_8 (Embedding)     (None, 200, 128)          640000
#
#  spatial_dropout1d_7 (Spati  (None, 200, 128)          0
#  alDropout1D)
#
#  gru (GRU)                   (None, 200, 128)          99072
#
#  gru_1 (GRU)                 (None, 64)                37248
#
#  dense_5 (Dense)             (None, 32)                2080
#
#  dropout_5 (Dropout)         (None, 32)                0
#
#  dense_6 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 778433 (2.97 MB)
# Trainable params: 778433 (2.97 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/20
# 217/217 [==============================] - 182s 821ms/step - loss: 1.5501 - mean_squared_error: 1.5501 - val_loss: 0.7223 - val_mean_squared_error: 0.7223
# Epoch 2/20
# 217/217 [==============================] - 1462s 7s/step - loss: 0.6975 - mean_squared_error: 0.6975 - val_loss: 0.4571 - val_mean_squared_error: 0.4571
# Epoch 3/20
# 217/217 [==============================] - 177s 817ms/step - loss: 0.5652 - mean_squared_error: 0.5652 - val_loss: 0.4535 - val_mean_squared_error: 0.4535
# Epoch 4/20
# 217/217 [==============================] - 178s 819ms/step - loss: 0.4778 - mean_squared_error: 0.4778 - val_loss: 0.4478 - val_mean_squared_error: 0.4478
# Epoch 5/20
# 217/217 [==============================] - 179s 826ms/step - loss: 0.4496 - mean_squared_error: 0.4496 - val_loss: 0.4588 - val_mean_squared_error: 0.4588
# Epoch 6/20
# 217/217 [==============================] - 178s 821ms/step - loss: 0.4170 - mean_squared_error: 0.4170 - val_loss: 0.4712 - val_mean_squared_error: 0.4712
# Epoch 7/20
# 217/217 [==============================] - 176s 813ms/step - loss: 0.3913 - mean_squared_error: 0.3913 - val_loss: 0.5747 - val_mean_squared_error: 0.5747
# Epoch 8/20
# 217/217 [==============================] - 180s 828ms/step - loss: 0.3592 - mean_squared_error: 0.3592 - val_loss: 0.4855 - val_mean_squared_error: 0.4855
# Epoch 9/20
# 217/217 [==============================] - 179s 823ms/step - loss: 0.3426 - mean_squared_error: 0.3426 - val_loss: 0.4959 - val_mean_squared_error: 0.4959
# Epoch 10/20
# 217/217 [==============================] - 177s 816ms/step - loss: 0.3300 - mean_squared_error: 0.3300 - val_loss: 0.5238 - val_mean_squared_error: 0.5238
# Epoch 11/20
# 217/217 [==============================] - 1450s 7s/step - loss: 0.3040 - mean_squared_error: 0.3040 - val_loss: 0.5251 - val_mean_squared_error: 0.5251
# Epoch 12/20
# 217/217 [==============================] - 175s 807ms/step - loss: 0.2896 - mean_squared_error: 0.2896 - val_loss: 0.5125 - val_mean_squared_error: 0.5125
# Epoch 13/20
# 217/217 [==============================] - 175s 806ms/step - loss: 0.2719 - mean_squared_error: 0.2719 - val_loss: 0.5848 - val_mean_squared_error: 0.5848
# Epoch 14/20
# 217/217 [==============================] - 193s 892ms/step - loss: 0.2603 - mean_squared_error: 0.2603 - val_loss: 0.5622 - val_mean_squared_error: 0.5622
# Epoch 15/20
# 217/217 [==============================] - 183s 844ms/step - loss: 0.2465 - mean_squared_error: 0.2465 - val_loss: 0.5593 - val_mean_squared_error: 0.5593
# Epoch 16/20
# 217/217 [==============================] - 197s 908ms/step - loss: 0.2374 - mean_squared_error: 0.2374 - val_loss: 0.5633 - val_mean_squared_error: 0.5633
# Epoch 17/20
# 217/217 [==============================] - 176s 813ms/step - loss: 0.2186 - mean_squared_error: 0.2186 - val_loss: 0.5528 - val_mean_squared_error: 0.5528
# Epoch 18/20
# 217/217 [==============================] - 175s 805ms/step - loss: 0.2112 - mean_squared_error: 0.2112 - val_loss: 0.5962 - val_mean_squared_error: 0.5962
# Epoch 19/20
# 217/217 [==============================] - 173s 797ms/step - loss: 0.2021 - mean_squared_error: 0.2021 - val_loss: 0.6144 - val_mean_squared_error: 0.6144
# Epoch 20/20
# 217/217 [==============================] - 493s 2s/step - loss: 0.1879 - mean_squared_error: 0.1879 - val_loss: 0.5887 - val_mean_squared_error: 0.5887

# %%
# Evaluation with Quadratic Weighted Kappa

from sklearn.metrics import cohen_kappa_score
import numpy as np

# Predict using the trained model
y_pred_gru = model_gru.predict(X_test).flatten()
y_pred_gru = np.rint(y_pred_gru)  # Round predictions to nearest integer

# Calculate Quadratic Weighted Kappa
kappa_score_gru = cohen_kappa_score(y_test, y_pred_gru, weights='quadratic')
print(f'Quadratic Weighted Kappa: {kappa_score_gru}')
# Out:
# 109/109 [==============================] - 9s 75ms/step
# Quadratic Weighted Kappa: 0.9048019008494427

# %%
# Visualization of Training History

plt.figure(figsize=(12, 6))
plt.plot(history_gru.history['loss'], label='MSE')
plt.plot(history_gru.history['val_loss'], label='Val MSE')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.savefig('../Images/GRU Loss.png')
plt.show()

# %% [markdown]
# ## CNN for Text

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, Conv1D, MaxPooling1D, GlobalMaxPooling1D, Dense, Dropout, SpatialDropout1D

# Define the CNN model
def model():
    model_cnn = Sequential()
    model_cnn.add(Embedding(input_dim=5000, output_dim=128, input_length=200))
    model_cnn.add(Conv1D(128, 5, activation='relu'))
    model_cnn.add(MaxPooling1D(5))
    model_cnn.add(Conv1D(64, 5, activation='relu'))
    model_cnn.add(GlobalMaxPooling1D())
    model_cnn.add(Dense(32, activation='relu'))
    model_cnn.add(Dropout(0.2))
    model_cnn.add(Dense(1, activation='linear'))
    return model_cnn

# %%
model_cnn=model()
model_cnn.compile(loss='mean_squared_error', optimizer='adam', metrics=['mean_squared_error'])
model_cnn.summary()

# Train the model
history_cnn = model_cnn.fit(X, Y, epochs=20, batch_size=64, validation_split=0.2)
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_9 (Embedding)     (None, 200, 128)          640000
#
#  conv1d (Conv1D)             (None, 196, 128)          82048
#
#  max_pooling1d (MaxPooling1  (None, 39, 128)           0
#  D)
#
#  conv1d_1 (Conv1D)           (None, 35, 64)            41024
#
#  global_max_pooling1d (Glob  (None, 64)                0
#  alMaxPooling1D)
#
#  dense_7 (Dense)             (None, 32)                2080
#
#  dropout_6 (Dropout)         (None, 32)                0
#
#  dense_8 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 765185 (2.92 MB)
# Trainable params: 765185 (2.92 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/20
# 217/217 [==============================] - 15s 65ms/step - loss: 1.4410 - mean_squared_error: 1.4410 - val_loss: 0.5516 - val_mean_squared_error: 0.5516
# Epoch 2/20
# 217/217 [==============================] - 14s 63ms/step - loss: 0.7295 - mean_squared_error: 0.7295 - val_loss: 0.4949 - val_mean_squared_error: 0.4949
# Epoch 3/20
# 217/217 [==============================] - 14s 62ms/step - loss: 0.6285 - mean_squared_error: 0.6285 - val_loss: 0.5632 - val_mean_squared_error: 0.5632
# Epoch 4/20
# 217/217 [==============================] - 15s 67ms/step - loss: 0.5595 - mean_squared_error: 0.5595 - val_loss: 0.5008 - val_mean_squared_error: 0.5008
# Epoch 5/20
# 217/217 [==============================] - 14s 64ms/step - loss: 0.4998 - mean_squared_error: 0.4998 - val_loss: 0.5417 - val_mean_squared_error: 0.5417
# Epoch 6/20
# 217/217 [==============================] - 14s 66ms/step - loss: 0.4497 - mean_squared_error: 0.4497 - val_loss: 0.5444 - val_mean_squared_error: 0.5444
# Epoch 7/20
# 217/217 [==============================] - 14s 62ms/step - loss: 0.4016 - mean_squared_error: 0.4016 - val_loss: 0.4895 - val_mean_squared_error: 0.4895
# Epoch 8/20
# 217/217 [==============================] - 14s 62ms/step - loss: 0.3680 - mean_squared_error: 0.3680 - val_loss: 0.4886 - val_mean_squared_error: 0.4886
# Epoch 9/20
# 217/217 [==============================] - 14s 63ms/step - loss: 0.3411 - mean_squared_error: 0.3411 - val_loss: 0.5339 - val_mean_squared_error: 0.5339
# Epoch 10/20
# 217/217 [==============================] - 14s 63ms/step - loss: 0.3189 - mean_squared_error: 0.3189 - val_loss: 0.4943 - val_mean_squared_error: 0.4943
# Epoch 11/20
# 217/217 [==============================] - 13s 62ms/step - loss: 0.2930 - mean_squared_error: 0.2930 - val_loss: 0.5056 - val_mean_squared_error: 0.5056
# Epoch 12/20
# 217/217 [==============================] - 14s 63ms/step - loss: 0.2733 - mean_squared_error: 0.2733 - val_loss: 0.4860 - val_mean_squared_error: 0.4860
# Epoch 13/20
# 217/217 [==============================] - 14s 63ms/step - loss: 0.2673 - mean_squared_error: 0.2673 - val_loss: 0.4941 - val_mean_squared_error: 0.4941
# Epoch 14/20
# 217/217 [==============================] - 14s 62ms/step - loss: 0.2447 - mean_squared_error: 0.2447 - val_loss: 0.6050 - val_mean_squared_error: 0.6050
# Epoch 15/20
# 217/217 [==============================] - 14s 64ms/step - loss: 0.2226 - mean_squared_error: 0.2226 - val_loss: 0.5088 - val_mean_squared_error: 0.5088
# Epoch 16/20
# 217/217 [==============================] - 14s 65ms/step - loss: 0.2137 - mean_squared_error: 0.2137 - val_loss: 0.4856 - val_mean_squared_error: 0.4856
# Epoch 17/20
# 217/217 [==============================] - 14s 64ms/step - loss: 0.1987 - mean_squared_error: 0.1987 - val_loss: 0.4955 - val_mean_squared_error: 0.4955
# Epoch 18/20
# 217/217 [==============================] - 14s 63ms/step - loss: 0.1831 - mean_squared_error: 0.1831 - val_loss: 0.4860 - val_mean_squared_error: 0.4860
# Epoch 19/20
# 217/217 [==============================] - 14s 63ms/step - loss: 0.1718 - mean_squared_error: 0.1718 - val_loss: 0.4875 - val_mean_squared_error: 0.4875
# Epoch 20/20
# 217/217 [==============================] - 14s 66ms/step - loss: 0.1627 - mean_squared_error: 0.1627 - val_loss: 0.5060 - val_mean_squared_error: 0.5060

# %%
# Evaluation with Quadratic Weighted Kappa

from sklearn.metrics import cohen_kappa_score
import numpy as np

# Predict using the trained model
y_pred_cnn = model_cnn.predict(X_test).flatten()
y_pred_cnn = np.rint(y_pred_cnn)  # Round predictions to nearest integer

# Calculate Quadratic Weighted Kappa
kappa_score_cnn = cohen_kappa_score(y_test, y_pred_cnn, weights='quadratic')
print(f'Quadratic Weighted Kappa (CNN): {kappa_score_cnn}')
# Out:
# 109/109 [==============================] - 1s 10ms/step
# Quadratic Weighted Kappa (CNN): 0.9239185991304903

# %%
# Visualization of Training History

plt.figure(figsize=(12, 6))
plt.plot(history_cnn.history['loss'], label='MSE')
plt.plot(history_cnn.history['val_loss'], label='Val MSE')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.savefig('../Images/CNN Loss.png')
plt.show()
