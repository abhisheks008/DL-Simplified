# %%
pip install tensorflow
# Out:
# ...
#   Using cached tensorflow-2.13.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.4 kB)
# ...
#   Using cached absl_py-2.1.0-py3-none-any.whl.metadata (2.3 kB)
# ...
#   Using cached astunparse-1.6.3-py2.py3-none-any.whl.metadata (4.4 kB)
# ...
#   Using cached flatbuffers-24.3.25-py2.py3-none-any.whl.metadata (850 bytes)
# ...
#   Using cached gast-0.4.0-py3-none-any.whl.metadata (1.1 kB)
# ...
#   Using cached google_pasta-0.2.0-py3-none-any.whl.metadata (814 bytes)
# ...
#   Using cached grpcio-1.64.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.3 kB)
# ...
#   Using cached h5py-3.11.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.5 kB)
# ...
#   Using cached keras-2.13.1-py3-none-any.whl.metadata (2.4 kB)
# ...
#   Using cached libclang-18.1.1-py2.py3-none-manylinux2010_x86_64.whl.metadata (5.2 kB)
# ...
#   Using cached numpy-1.24.3-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.6 kB)
# ...

# %%
# !python keras_retinanet/bin/train.py --epoch 10 --batch-size 2 --steps 10 --snapshot-path /home/arismita/ML/RetinaNet/landcover/Snaps --tensorboard-dir /home/arismita/ML/RetinaNet/landcover/Log pascal /home/arismita/ML/RetinaNet/landcover/dataset
# Out:
# 2024-06-27 19:44:51.048086: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-06-27 19:44:51.083067: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-06-27 19:44:51.550470: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Creating model, this may take a second...
# ...

# %%
import os

# Set this if you want to force TensorFlow to use CPU
os.environ['CUDA_VISIBLE_DEVICES'] = ''

# Define the paths
script_path = '/home/arismita/ML/RetinaNet/landcover/testing_code/resnet50_retinanet2.py'
model_path = '/home/arismita/ML/RetinaNet/landcover/Snaps/resnet50_pascal_06.h5'
output_path = '/home/arismita/ML/RetinaNet/landcover/Inference/resnet50_pascal_06.h5'

# Check if the script file exists
if not os.path.exists(script_path):
    print(f"Script file not found at: {script_path}")
else:
    print(f"Script file found at: {script_path}")

# Check if the model file exists
if not os.path.exists(model_path):
    print(f"Model file not found at: {model_path}")
else:
    print(f"Model file found at: {model_path}")

# Check if the output directory exists, create if not
output_dir = os.path.dirname(output_path)
if not os.path.exists(output_dir):
    os.makedirs(output_dir)
    print(f"Created directory: {output_dir}")

# Run the script using the shell command
command = f'python {script_path} {model_path} {output_path}'
print(f"Running command: {command}")
# !{command}
# Out:
# Script file found at: /home/arismita/ML/RetinaNet/landcover/testing_code/resnet50_retinanet2.py
# Model file found at: /home/arismita/ML/RetinaNet/landcover/Snaps/resnet50_pascal_06.h5
# Running command: python /home/arismita/ML/RetinaNet/landcover/testing_code/resnet50_retinanet2.py /home/arismita/ML/RetinaNet/landcover/Snaps/resnet50_pascal_06.h5 /home/arismita/ML/RetinaNet/landcover/Inference/resnet50_pascal_06.h5
# Loading model from: /home/arismita/ML/RetinaNet/landcover/Snaps/resnet50_pascal_06.h5
# 2024-06-27 21:29:22.270587: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-06-27 21:29:22.297711: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# ...

# %%
import os
from IPython.display import Image, display

# Set this if you want to force TensorFlow to use CPU
os.environ['CUDA_VISIBLE_DEVICES'] = ''

# Define the paths
script_path = '/home/arismita/ML/RetinaNet/landcover/testing_code/resnet50_retinanet2.py'
model_path = '/home/arismita/ML/RetinaNet/landcover/Snaps/resnet50_pascal_06.h5'
output_path = '/home/arismita/ML/RetinaNet/landcover/Inference/resnet50_pascal_06.h5'
test_image_path = '/home/arismita/ML/RetinaNet/landcover/testing_code/aachen_3.jpg'

# Check if the script file exists
if not os.path.exists(script_path):
    print(f"Script file not found at: {script_path}")
else:
    print(f"Script file found at: {script_path}")

# Check if the model file exists
if not os.path.exists(model_path):
    print(f"Model file not found at: {model_path}")
else:
    print(f"Model file found at: {model_path}")

# Check if the output directory exists, create if not
output_dir = os.path.dirname(output_path)
if not os.path.exists(output_dir):
    os.makedirs(output_dir)
    print(f"Created directory: {output_dir}")

# Run the script using the shell command
command = f'python {script_path} {model_path} {output_path} {test_image_path}'
print(f"Running command: {command}")
# !{command}

# Display the output image
output_image_path = os.path.join(output_dir, 'output_image.png')
if os.path.exists(output_image_path):
    display(Image(output_image_path))
else:
    print("Output image not found.")
# Out:
# Script file found at: /home/arismita/ML/RetinaNet/landcover/testing_code/resnet50_retinanet2.py
# Model file found at: /home/arismita/ML/RetinaNet/landcover/Snaps/resnet50_pascal_06.h5
# Running command: python /home/arismita/ML/RetinaNet/landcover/testing_code/resnet50_retinanet2.py /home/arismita/ML/RetinaNet/landcover/Snaps/resnet50_pascal_06.h5 /home/arismita/ML/RetinaNet/landcover/Inference/resnet50_pascal_06.h5 /home/arismita/ML/RetinaNet/landcover/testing_code/aachen_3.jpg
# Loading model from: /home/arismita/ML/RetinaNet/landcover/Snaps/resnet50_pascal_06.h5
# 2024-06-27 21:33:02.601416: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# ...

# %%
import os
from IPython.display import Image, display

# Set this if you want to force TensorFlow to use CPU
os.environ['CUDA_VISIBLE_DEVICES'] = ''

# Define the paths
script_path = '/home/arismita/ML/RetinaNet/landcover/testing_code/resnet50_retinanet2.py'
model_path = '/home/arismita/ML/RetinaNet/landcover/Snaps/resnet50_pascal_06.h5'
output_path = '/home/arismita/ML/RetinaNet/landcover/Inference/resnet50_pascal_06.h5'
test_image_path = '/home/arismita/ML/RetinaNet/landcover/testing_code/aachen_3.jpg'

# Check if the script file exists
if not os.path.exists(script_path):
    print(f"Script file not found at: {script_path}")
else:
    print(f"Script file found at: {script_path}")

# Check if the model file exists
if not os.path.exists(model_path):
    print(f"Model file not found at: {model_path}")
else:
    print(f"Model file found at: {model_path}")

# Check if the output directory exists, create if not
output_dir = os.path.dirname(output_path)
if not os.path.exists(output_dir):
    os.makedirs(output_dir)
    print(f"Created directory: {output_dir}")

# Run the script using the shell command
command = f'python {script_path} {model_path} {output_path} {test_image_path}'
print(f"Running command: {command}")
# !{command}

# Display the output image
output_image_path = os.path.join(output_dir, 'output_image.png')
if os.path.exists(output_image_path):
    display(Image(output_image_path))
else:
    print("Output image not found.")
# Out:
# Script file found at: /home/arismita/ML/RetinaNet/landcover/testing_code/resnet50_retinanet2.py
# Model file found at: /home/arismita/ML/RetinaNet/landcover/Snaps/resnet50_pascal_06.h5
# Running command: python /home/arismita/ML/RetinaNet/landcover/testing_code/resnet50_retinanet2.py /home/arismita/ML/RetinaNet/landcover/Snaps/resnet50_pascal_06.h5 /home/arismita/ML/RetinaNet/landcover/Inference/resnet50_pascal_06.h5 /home/arismita/ML/RetinaNet/landcover/testing_code/aachen_3.jpg
# Loading model from: /home/arismita/ML/RetinaNet/landcover/Snaps/resnet50_pascal_06.h5
# 2024-06-27 21:34:59.258935: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# ...

# %%
import os
from IPython.display import Image, display

# Set this if you want to force TensorFlow to use CPU
os.environ['CUDA_VISIBLE_DEVICES'] = ''

# Define the paths
script_path = '/home/arismita/ML/RetinaNet/landcover/testing_code/resnet50_retinanet2.py'
model_path = '/home/arismita/ML/RetinaNet/landcover/Snaps/resnet50_pascal_06.h5'
output_path = '/home/arismita/ML/RetinaNet/landcover/Inference/resnet50_pascal_06.h5'
test_image_path = '/home/arismita/ML/RetinaNet/landcover/testing_code/aachen_3.jpg'

# Check if the script file exists
if not os.path.exists(script_path):
    print(f"Script file not found at: {script_path}")
else:
    print(f"Script file found at: {script_path}")

# Check if the model file exists
if not os.path.exists(model_path):
    print(f"Model file not found at: {model_path}")
else:
    print(f"Model file found at: {model_path}")

# Check if the output directory exists, create if not
output_dir = os.path.dirname(output_path)
if not os.path.exists(output_dir):
    os.makedirs(output_dir)
    print(f"Created directory: {output_dir}")

# Run the script using the shell command
command = f'python {script_path} {model_path} {output_path} {test_image_path}'
print(f"Running command: {command}")
# !{command}

# Display the output image
output_image_path = os.path.join(output_dir, 'output_image.png')
if os.path.exists(output_image_path):
    display(Image(output_image_path))
else:
    print("Output image not found.")
# Out:
# Script file found at: /home/arismita/ML/RetinaNet/landcover/testing_code/resnet50_retinanet2.py
# Model file found at: /home/arismita/ML/RetinaNet/landcover/Snaps/resnet50_pascal_06.h5
# Running command: python /home/arismita/ML/RetinaNet/landcover/testing_code/resnet50_retinanet2.py /home/arismita/ML/RetinaNet/landcover/Snaps/resnet50_pascal_06.h5 /home/arismita/ML/RetinaNet/landcover/Inference/resnet50_pascal_06.h5 /home/arismita/ML/RetinaNet/landcover/testing_code/aachen_3.jpg
# Loading model from: /home/arismita/ML/RetinaNet/landcover/Snaps/resnet50_pascal_06.h5
# 2024-06-27 21:38:47.421702: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# ...

# %%
import os
from IPython.display import Image, display

# Set this if you want to force TensorFlow to use CPU
os.environ['CUDA_VISIBLE_DEVICES'] = ''

# Define the paths
script_path = '/home/arismita/ML/RetinaNet/landcover/testing_code/resnet50_retinanet2.py'
model_path = '/home/arismita/ML/RetinaNet/landcover/Snaps/resnet50_pascal_06.h5'
output_path = '/home/arismita/ML/RetinaNet/landcover/Inference/resnet50_pascal_06.h5'
test_image_path = '/home/arismita/ML/RetinaNet/landcover/testing_code/aachen_3.jpg'

# Check if the script file exists
if not os.path.exists(script_path):
    print(f"Script file not found at: {script_path}")
else:
    print(f"Script file found at: {script_path}")

# Check if the model file exists
if not os.path.exists(model_path):
    print(f"Model file not found at: {model_path}")
else:
    print(f"Model file found at: {model_path}")

# Check if the output directory exists, create if not
output_dir = os.path.dirname(output_path)
if not os.path.exists(output_dir):
    os.makedirs(output_dir)
    print(f"Created directory: {output_dir}")

# Run the script using the shell command
command = f'python {script_path} {model_path} {output_path} {test_image_path}'
print(f"Running command: {command}")
# !{command}

# Display the output image
output_image_path = os.path.join(output_dir, 'output_image.png')
if os.path.exists(output_image_path):
    display(Image(output_image_path))
else:
    print("Output image not found.")
# Out:
# Script file found at: /home/arismita/ML/RetinaNet/landcover/testing_code/resnet50_retinanet2.py
# Model file found at: /home/arismita/ML/RetinaNet/landcover/Snaps/resnet50_pascal_06.h5
# Running command: python /home/arismita/ML/RetinaNet/landcover/testing_code/resnet50_retinanet2.py /home/arismita/ML/RetinaNet/landcover/Snaps/resnet50_pascal_06.h5 /home/arismita/ML/RetinaNet/landcover/Inference/resnet50_pascal_06.h5 /home/arismita/ML/RetinaNet/landcover/testing_code/aachen_3.jpg
# Loading model from: /home/arismita/ML/RetinaNet/landcover/Snaps/resnet50_pascal_06.h5
# 2024-06-27 21:40:25.945079: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# ...

# %%
import os
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

def display_images_in_folder(folder_path):
    # Get all files in the folder
    files = os.listdir(folder_path)
    
    # Filter out non-image files (assuming images have extensions like .png, .jpg, .jpeg)
    image_files = [f for f in files if f.endswith(('png', 'jpg', 'jpeg'))]
    
    # Display each image using matplotlib
    for img_file in image_files:
        img_path = os.path.join(folder_path, img_file)
        img = mpimg.imread(img_path)
        plt.figure(figsize=(8, 8))
        plt.imshow(img)
        plt.axis('off')  # Turn off axis numbers and ticks
        plt.show()

# Example usage:
folder_path = '/home/arismita/tp'
display_images_in_folder(folder_path)
