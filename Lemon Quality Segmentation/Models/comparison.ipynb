# %% [markdown]
# # Visual Representation of accuracy scores of different deep learning models that are being applied for lemon image segmentation

# %% [markdown]
# # **Importing Libraries**

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from wordcloud import WordCloud
import plotly.graph_objects as go

# %% [markdown]
# # **LINE PLOT**

# %%
# Accuracy scores
accuracy_scores = [0.9841897233201581, 0.9881422924901185, 0.9960474308300395]
model_names = ['VGG16', 'simpleCNN', 'AlexNet']

# Set the figure size
plt.figure(figsize=(8, 6))

# Create the line plot
plt.plot(model_names, accuracy_scores, marker='o', linestyle='-', color='b', linewidth=2)

# Add data labels with adjusted vertical alignment and offset
offset = 0.0001 
for i in range(len(model_names)):
    plt.text(model_names[i], accuracy_scores[i]+offset, str(accuracy_scores[i]), ha='center')

# Add labels and title
plt.xlabel('Model')
plt.ylabel('Accuracy Score')
plt.title('Accuracy Scores of Different Models')

# Show the plot
plt.show()

# %% [markdown]
# # **DISTRIBUTION PLOT**

# %%
plt.figure(figsize=(8, 6))
plt.hist(accuracy_scores, bins=10, color='b', alpha=0.7)
plt.xlabel('Accuracy Score')
plt.ylabel('Frequency')
plt.title('Distribution of Accuracy Scores')
plt.show()

# %% [markdown]
# # **HEAT-MAP**

# %%
data = np.array(accuracy_scores).reshape(1, -1)
plt.figure(figsize=(8, 6))
sns.heatmap(data, cmap='Blues', annot=True, xticklabels=model_names, yticklabels=False, cbar=False)
plt.xlabel('Model')
plt.ylabel('')
plt.title('Accuracy Scores of Different Models')
plt.show()

# %% [markdown]
# # **WORDCLOUD**

# %%
# Convert scores to frequencies
frequencies = {model: score for model, score in zip(model_names, accuracy_scores)}

# Generate word cloud
wordcloud = WordCloud(width=900, height=500, background_color='white').generate_from_frequencies(frequencies)

# Plot word cloud
plt.figure(figsize=(15,10))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('Accuracy Scores of Different Models')

# Show the plot
plt.show()

# %% [markdown]
# # **BUBBLE-CHART**

# %%
# Create the bubble chart
fig = go.Figure(data=go.Scatter(
    x=model_names,
    y=accuracy_scores,
    mode='markers',
    marker=dict(
        size=[score * 1000 for score in accuracy_scores],
        color=accuracy_scores,
        colorscale='Blues',
        showscale=True
    )
))

# Set title and axis labels
fig.update_layout(title='Accuracy Scores of Different Models')
fig.update_xaxes(title_text='Model')
fig.update_yaxes(title_text='Accuracy Score')

# Show the chart
fig.show()
# Out:
# <div>                            <div id="08df4a80-ffea-4985-b82b-e4b9aeb648de" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("08df4a80-ffea-4985-b82b-e4b9aeb648de")) {                    Plotly.newPlot(                        "08df4a80-ffea-4985-b82b-e4b9aeb648de",                        [{"marker":{"color":[0.9841897233201581,0.9881422924901185,0.9960474308300395],"colorscale":[[0.0,"rgb(247,251,255)"],[0.125,"rgb(222,235,247)"],[0.25,"rgb(198,219,239)"],[0.375,"rgb(158,202,225)"],[0.5,"rgb(107,174,214)"],[0.625,"rgb(66,146,198)"],[0.75,"rgb(33,113,181)"],[0.875,"rgb(8,81,156)"],[1.0,"rgb(8,48,107)"]],"showscale":true,"size":[984.1897233201581,988.1422924901185,996.0474308300395]},"mode":"markers","x":["VGG16","simpleCNN","AlexNet"],"y":[0.984189
# ...
