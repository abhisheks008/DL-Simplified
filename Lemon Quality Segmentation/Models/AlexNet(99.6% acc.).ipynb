from sklearn.model_selection import train_test_split

# %% [markdown]
# **Loading the Dataset:**

# %%
root="/kaggle/input/lemon-quality-dataset/lemon_dataset/"

# %%
categories=os.listdir(root)
categories.remove('.git')
categories
# Out:
# ['empty_background', 'good_quality', 'bad_quality']

# %% [markdown]
# **Creating Image and Label Lists**

# %%
images = []
labels = []
for category in categories:
    directory = root + category + '/'
    for image_file in os.listdir(directory):
        images.append(directory + image_file)
        labels.append(category)

# %% [markdown]
# **Creating a DataFrame**

# %%
images = pd.Series(images, name="Image")
labels = pd.Series(labels, name="Quality")

# %%
data=pd.concat([images,labels], axis=1)
data.head()
# Out:
#                                                Image           Quality
# 0  /kaggle/input/lemon-quality-dataset/lemon_data...  empty_background
# 1  /kaggle/input/lemon-quality-dataset/lemon_data...  empty_background
# 2  /kaggle/input/lemon-quality-dataset/lemon_data...  empty_background
# 3  /kaggle/input/lemon-quality-dataset/lemon_data...  empty_background
# 4  /kaggle/input/lemon-quality-dataset/lemon_data...  empty_background

# %% [markdown]
# ****Shuffling the DataFrame****

# %%
data=data.sample(frac=1).reset_index(drop = True)
data.head()
# Out:
#                                                Image           Quality
# 0  /kaggle/input/lemon-quality-dataset/lemon_data...      good_quality
# 1  /kaggle/input/lemon-quality-dataset/lemon_data...       bad_quality
# 2  /kaggle/input/lemon-quality-dataset/lemon_data...  empty_background
# 3  /kaggle/input/lemon-quality-dataset/lemon_data...       bad_quality
# 4  /kaggle/input/lemon-quality-dataset/lemon_data...      good_quality

# %% [markdown]
# **Displaying Random Images**

# %%
fig, axes = plt.subplots(2, 5, figsize=(15, 7))

for ax in axes.flat:
    i = np.random.randint(0, data.shape[0])
    ax.imshow(Image.open(data.loc[i, "Image"]))
    ax.grid(False)  

plt.tight_layout()
plt.show()

# %% [markdown]
# **Train-Test Split:**

# %%
dev, held_out =train_test_split(
    data, 
    train_size=0.9, 
    shuffle=True,
    random_state=42)

# %% [markdown]
# **Printing Shape Information:**

# %%
print(dev.shape)
print(held_out.shape)
# Out:
# (2275, 2)
# (253, 2)

# %% [markdown]
# # Data Preprocessing and Image Data Generators

# %%
import keras

# %%
from keras.preprocessing import image

# %% [markdown]
# **Rescaling,Data Augmentation and rescaling**

# %%
# Rescaling and Data Augmentation
dev_generator = image.ImageDataGenerator(
    rescale=1./255,
    horizontal_flip=True,
    rotation_range=40,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.2,
    zoom_range=0.2,
    validation_split=0.2
)

# In this case, the generator performs rescaling (normalization) on the image.
# Each pixel value is divided by 255 to obtain values in the range [0, 1].
held_generator = image.ImageDataGenerator(rescale=1./255)

# %% [markdown]
# **Flow from DataFrame:**

# %%
train_images = dev_generator.flow_from_dataframe(
    dataframe=dev,  # Make sure to provide the correct DataFrame
    x_col='Image',  # Update to the correct column name for images
    y_col='Quality',  # Update to the correct column name for labels
    target_size=(150, 150),
    color_mode='rgb',
    class_mode='categorical',
    batch_size=32,
    shuffle=True,
    seed=42,
    subset='training'
)
# Out:
# Found 1820 validated image filenames belonging to 3 classes.

# %%
val_images = dev_generator.flow_from_dataframe(
    dataframe=dev,
    x_col='Image',
    y_col='Quality',
    target_size=(150, 150),
    color_mode='rgb',
    class_mode='categorical',
    batch_size=32,
    shuffle=True,
    seed=42,
    subset='validation'
)
# Out:
# Found 455 validated image filenames belonging to 3 classes.

# %% [markdown]
# **Flow from DataFrame for Testing**

# %%
held_images = held_generator.flow_from_dataframe(
    dataframe=held_out,
    x_col='Image',
    y_col='Quality',
    target_size=(150, 150),
    color_mode='rgb',
    class_mode='categorical',
    batch_size=32,
    shuffle=False
)
# Out:
# Found 253 validated image filenames belonging to 3 classes.

# %% [markdown]
# **class indices**

# %%
labels = train_images.class_indices
labels
# Out:
# {'bad_quality': 0, 'empty_background': 1, 'good_quality': 2}

# %% [markdown]
# # AlexNet Architecture for Image Classification
#
# This code implements the AlexNet architecture using Keras. It defines a sequential model and adds convolutional, pooling, and dense layers to construct the network. The model consists of **8 convolutional layers** with **ReLU activation**, **max pooling**, and **zero padding**. It also includes 3 **fully connected layers** with dropout for regularization. The output layer has softmax activation for **multi-class classification**. The model is compiled with the **SGD optimizer** and categorical cross-entropy loss. Two callbacks, **early stopping and reduce learning rate on plateau**, are defined. The model is trained using the `fit()` function with provided training and validation datasets.

# %%
from keras.models import Model
from keras.models import Sequential
from keras.layers import Convolution2D, MaxPooling2D, Activation, ZeroPadding2D, Flatten, Dense, Dropout
from keras.optimizers import SGD
from keras.callbacks import EarlyStopping, ReduceLROnPlateau

# %%
# Create AlexNet model
model = Sequential()

# %%
# Layer 1
model.add(Convolution2D(filters=96, kernel_size=(11, 11), strides=(4, 4), padding='valid', input_shape=(150, 150, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(3, 3), strides=(2, 2)))

# Layer 2
model.add(ZeroPadding2D(padding=(2, 2)))
model.add(Convolution2D(filters=256, kernel_size=(5, 5), strides=(1, 1)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(3, 3), strides=(2, 2)))

# Layer 3
model.add(ZeroPadding2D(padding=(1, 1)))
model.add(Convolution2D(filters=384, kernel_size=(3, 3), strides=(1, 1)))
model.add(Activation('relu'))

# Layer 4
model.add(ZeroPadding2D(padding=(1, 1)))
model.add(Convolution2D(filters=384, kernel_size=(3, 3), strides=(1, 1)))
model.add(Activation('relu'))

# Layer 5
model.add(ZeroPadding2D(padding=(1, 1)))
model.add(Convolution2D(filters=256, kernel_size=(3, 3), strides=(1, 1)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(3, 3), strides=(2, 2)))

# Flatten layer
model.add(Flatten())

# Layer 6
model.add(Dense(4096))
model.add(Activation('relu'))
model.add(Dropout(0.5))

# Layer 7
model.add(Dense(4096))
model.add(Activation('relu'))
model.add(Dropout(0.5))

# Layer 8
model.add(Dense(1000))
model.add(Activation('relu'))
model.add(Dropout(0.5))

# Output layer
model.add(Dense(3))
model.add(Activation('softmax'))

# %%
# Print model summary
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 35, 35, 96)        34944
#
#  activation (Activation)     (None, 35, 35, 96)        0
#
#  max_pooling2d (MaxPooling2D  (None, 17, 17, 96)       0
#  )
#
#  zero_padding2d (ZeroPadding  (None, 21, 21, 96)       0
#  2D)
#
#  conv2d_1 (Conv2D)           (None, 17, 17, 256)       614656
#
#  activation_1 (Activation)   (None, 17, 17, 256)       0
#
#  max_pooling2d_1 (MaxPooling  (None, 8, 8, 256)        0
#  2D)
#
#  zero_padding2d_1 (ZeroPaddi  (None, 10, 10, 256)      0
#  ng2D)
#
#  conv2d_2 (Conv2D)           (None, 8, 8, 384)         885120
#
#  activation_2 (Activation)   (None, 8, 8, 384)         0
#
#  zero_padding2d_2 (ZeroPaddi  (None, 10, 10, 384)      0
#  ng2D)
#
#  conv2d_3 (Conv2D)           (None, 8, 8, 384)         1327488
#
#  activation_3 (Activation)   (None, 8, 8, 384)         0
#
#  zero_padding2d_3 (ZeroPaddi  (None, 10, 10, 384)      0
#  ng2D)
#
#  conv2d_4 (Conv2D)           (None, 8, 8, 256)         884992
#
#  activation_4 (Activation)   (None, 8, 8, 256)         0
#
#  max_pooling2d_2 (MaxPooling  (None, 3, 3, 256)        0
#  2D)
#
#  flatten (Flatten)           (None, 2304)              0
#
#  dense (Dense)               (None, 4096)              9441280
#
#  activation_5 (Activation)   (None, 4096)              0
#
#  dropout (Dropout)           (None, 4096)              0
#
#  dense_1 (Dense)             (None, 4096)              16781312
#
#  activation_6 (Activation)   (None, 4096)              0
#
#  dropout_1 (Dropout)         (None, 4096)              0
#
#  dense_2 (Dense)             (None, 1000)              4097000
#
#  activation_7 (Activation)   (None, 1000)              0
#
#  dropout_2 (Dropout)         (None, 1000)              0
#
#  dense_3 (Dense)             (None, 3)                 3003
#
#  activation_8 (Activation)   (None, 3)                 0
#
# =================================================================
# Total params: 34,069,795
# Trainable params: 34,069,795
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow.keras.optimizers import Adam

# Compile model
model.compile(optimizer=Adam(learning_rate=0.001), loss='categorical_crossentropy', metrics=['acc', 'mse'])

# %%
# Define callbacks
early_stop = EarlyStopping(monitor='val_loss', patience=75, verbose=1, min_delta=1e-4, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=4, verbose=1, min_delta=1e-4)
callbacks_list = [early_stop, reduce_lr]

# %%
# Train the model
history = model.fit(train_images, validation_data=val_images,epochs=50, callbacks=callbacks_list)
# Out:
# Epoch 1/50
# 57/57 [==============================] - 20s 270ms/step - loss: 0.2716 - acc: 0.9159 - mse: 0.0446 - val_loss: 0.1293 - val_acc: 0.9626 - val_mse: 0.0196 - lr: 0.0010
# Epoch 2/50
# 57/57 [==============================] - 16s 282ms/step - loss: 0.1979 - acc: 0.9247 - mse: 0.0354 - val_loss: 0.1829 - val_acc: 0.9319 - val_mse: 0.0339 - lr: 0.0010
# Epoch 3/50
# 57/57 [==============================] - 16s 273ms/step - loss: 0.1919 - acc: 0.9363 - mse: 0.0330 - val_loss: 0.1175 - val_acc: 0.9495 - val_mse: 0.0219 - lr: 0.0010
# Epoch 4/50
# 57/57 [==============================] - 16s 278ms/step - loss: 0.1531 - acc: 0.9412 - mse: 0.0292 - val_loss: 0.2562 - val_acc: 0.8835 - val_mse: 0.0517 - lr: 0.0010
# Epoch 5/50
# 57/57 [==============================] - 14s 254ms/step - loss: 0.1562 - acc: 0.9582 - mse: 0.0239 - val_loss: 0.1124 - val_acc: 0.9582 - val_mse: 0.0201 - lr: 0.0010
# Epoch 6/50
# 57/57 [==============================] - 15s 260ms/step - loss: 0.1280 - acc: 0.9560 - mse: 0.0234 - val_loss: 0.1634 - val_acc: 0.9187 - val_mse: 0.0347 - lr: 0.0010
# Epoch 7/50
# 57/57 [==============================] - 15s 261ms/step - loss: 0.2125 - acc: 0.9445 - mse: 0.0287 - val_loss: 1.9189 - val_acc: 0.7473 - val_mse: 0.1555 - lr: 0.0010
# Epoch 8/50
# 57/57 [==============================] - 15s 258ms/step - loss: 0.2107 - acc: 0.9346 - mse: 0.0342 - val_loss: 0.1237 - val_acc: 0.9538 - val_mse: 0.0229 - lr: 0.0010
# Epoch 9/50
# 57/57 [==============================] - 16s 275ms/step - loss: 0.1757 - acc: 0.9456 - mse: 0.0274 - val_loss: 0.1039 - val_acc: 0.9538 - val_mse: 0.0214 - lr: 0.0010
# Epoch 10/50
# 57/57 [==============================] - 15s 263ms/step - loss: 0.1565 - acc: 0.9451 - mse: 0.0281 - val_loss: 0.3788 - val_acc: 0.8769 - val_mse: 0.0707 - lr: 0.0010
# Epoch 11/50
# 57/57 [==============================] - 16s 274ms/step - loss: 0.1564 - acc: 0.9533 - mse: 0.0279 - val_loss: 0.0886 - val_acc: 0.9714 - val_mse: 0.0172 - lr: 0.0010
# Epoch 12/50
# 57/57 [==============================] - 15s 268ms/step - loss: 0.1423 - acc: 0.9462 - mse: 0.0256 - val_loss: 0.1012 - val_acc: 0.9692 - val_mse: 0.0189 - lr: 0.0010
# Epoch 13/50
# 57/57 [==============================] - 14s 254ms/step - loss: 0.1131 - acc: 0.9676 - mse: 0.0186 - val_loss: 0.1541 - val_acc: 0.9429 - val_mse: 0.0278 - lr: 0.0010
# Epoch 14/50
# 57/57 [==============================] - 15s 262ms/step - loss: 0.1015 - acc: 0.9648 - mse: 0.0170 - val_loss: 0.1652 - val_acc: 0.9692 - val_mse: 0.0168 - lr: 0.0010
# Epoch 15/50
# 57/57 [==============================] - ETA: 0s - loss: 0.1388 - acc: 0.9555 - mse: 0.0239
# Epoch 15: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 57/57 [==============================] - 15s 257ms/step - loss: 0.1388 - acc: 0.9555 - mse: 0.0239 - val_loss: 0.1470 - val_acc: 0.9560 - val_mse: 0.0284 - lr: 0.0010
# Epoch 16/50
# 57/57 [==============================] - 15s 261ms/step - loss: 0.0875 - acc: 0.9637 - mse: 0.0169 - val_loss: 0.1169 - val_acc: 0.9604 - val_mse: 0.0210 - lr: 1.0000e-04
# Epoch 17/50
# 57/57 [==============================] - 14s 251ms/step - loss: 0.0880 - acc: 0.9687 - mse: 0.0161 - val_loss: 0.1120 - val_acc: 0.9692 - val_mse: 0.0168 - lr: 1.0000e-04
# Epoch 18/50
# 57/57 [==============================] - 15s 264ms/step - loss: 0.0729 - acc: 0.9720 - mse: 0.0140 - val_loss: 0.0842 - val_acc: 0.9714 - val_mse: 0.0165 - lr: 1.0000e-04
# Epoch 19/50
# 57/57 [==============================] - 15s 264ms/step - loss: 0.0641 - acc: 0.9808 - mse: 0.0115 - val_loss: 0.0753 - val_acc: 0.9692 - val_mse: 0.0153 - lr: 1.0000e-04
# Epoch 20/50
# 57/57 [==============================] - 14s 252ms/step - loss: 0.0645 - acc: 0.9791 - mse: 0.0121 - val_loss: 0.0792 - val_acc: 0.9736 - val_mse: 0.0140 - lr: 1.0000e-04
# Epoch 21/50
# 57/57 [==============================] - 15s 263ms/step - loss: 0.0662 - acc: 0.9753 - mse: 0.0126 - val_loss: 0.0641 - val_acc: 0.9648 - val_mse: 0.0131 - lr: 1.0000e-04
# Epoch 22/50
# 57/57 [==============================] - 14s 254ms/step - loss: 0.0570 - acc: 0.9742 - mse: 0.0119 - val_loss: 0.0943 - val_acc: 0.9692 - val_mse: 0.0155 - lr: 1.0000e-04
# Epoch 23/50
# 57/57 [==============================] - 15s 267ms/step - loss: 0.0623 - acc: 0.9725 - mse: 0.0124 - val_loss: 0.0526 - val_acc: 0.9824 - val_mse: 0.0105 - lr: 1.0000e-04
# Epoch 24/50
# 57/57 [==============================] - 14s 249ms/step - loss: 0.0646 - acc: 0.9742 - mse: 0.0125 - val_loss: 0.0724 - val_acc: 0.9758 - val_mse: 0.0117 - lr: 1.0000e-04
# Epoch 25/50
# 57/57 [==============================] - 15s 265ms/step - loss: 0.0587 - acc: 0.9802 - mse: 0.0108 - val_loss: 0.0477 - val_acc: 0.9824 - val_mse: 0.0095 - lr: 1.0000e-04
# Epoch 26/50
# 57/57 [==============================] - 14s 253ms/step - loss: 0.0513 - acc: 0.9797 - mse: 0.0097 - val_loss: 0.0783 - val_acc: 0.9626 - val_mse: 0.0163 - lr: 1.0000e-04
# Epoch 27/50
# 57/57 [==============================] - 14s 253ms/step - loss: 0.0539 - acc: 0.9786 - mse: 0.0104 - val_loss: 0.0733 - val_acc: 0.9670 - val_mse: 0.0147 - lr: 1.0000e-04
# Epoch 28/50
# 57/57 [==============================] - 15s 266ms/step - loss: 0.0503 - acc: 0.9797 - mse: 0.0095 - val_loss: 0.0468 - val_acc: 0.9780 - val_mse: 0.0097 - lr: 1.0000e-04
# Epoch 29/50
# 57/57 [==============================] - 15s 259ms/step - loss: 0.0485 - acc: 0.9769 - mse: 0.0098 - val_loss: 0.0542 - val_acc: 0.9780 - val_mse: 0.0105 - lr: 1.0000e-07
# Epoch 43/50
# 57/57 [==============================] - 14s 254ms/step - loss: 0.0460 - acc: 0.9808 - mse: 0.0092 - val_loss: 0.0473 - val_acc: 0.9758 - val_mse: 0.0100 - lr: 1.0000e-07
# Epoch 44/50
# 57/57 [==============================] - ETA: 0s - loss: 0.0539 - acc: 0.9808 - mse: 0.0095
# Epoch 44: ReduceLROnPlateau reducing learning rate to 1.000000082740371e-08.
# 57/57 [==============================] - 15s 263ms/step - loss: 0.0539 - acc: 0.9808 - mse: 0.0095 - val_loss: 0.0485 - val_acc: 0.9780 - val_mse: 0.0100 - lr: 1.0000e-07
# Epoch 45/50
# 57/57 [==============================] - 15s 265ms/step - loss: 0.0445 - acc: 0.9846 - mse: 0.0079 - val_loss: 0.0659 - val_acc: 0.9714 - val_mse: 0.0138 - lr: 1.0000e-08
# Epoch 46/50
# 57/57 [==============================] - 15s 259ms/step - loss: 0.0471 - acc: 0.9797 - mse: 0.0094 - val_loss: 0.0400 - val_acc: 0.9846 - val_mse: 0.0083 - lr: 1.0000e-08
# Epoch 47/50
# 57/57 [==============================] - 14s 254ms/step - loss: 0.0582 - acc: 0.9802 - mse: 0.0100 - val_loss: 0.0530 - val_acc: 0.9758 - val_mse: 0.0116 - lr: 1.0000e-08
# Epoch 48/50
# 57/57 [==============================] - 14s 254ms/step - loss: 0.0478 - acc: 0.9841 - mse: 0.0087 - val_loss: 0.0502 - val_acc: 0.9758 - val_mse: 0.0100 - lr: 1.0000e-08
# Epoch 49/50
# 57/57 [==============================] - 15s 265ms/step - loss: 0.0484 - acc: 0.9791 - mse: 0.0098 - val_loss: 0.0523 - val_acc: 0.9802 - val_mse: 0.0108 - lr: 1.0000e-08
# Epoch 50/50
# 57/57 [==============================] - ETA: 0s - loss: 0.0458 - acc: 0.9819 - mse: 0.0081
# Epoch 50: ReduceLROnPlateau reducing learning rate to 1.000000082740371e-09.
# 57/57 [==============================] - 14s 253ms/step - loss: 0.0458 - acc: 0.9819 - mse: 0.0081 - val_loss: 0.0489 - val_acc: 0.9846 - val_mse: 0.0082 - lr: 1.0000e-08

# %% [markdown]
# # Training and Validation Metrics Visualization

# %%
fig, axes = plt.subplots(2, 3, figsize=(12, 8))

# Plot training loss
axes[0, 0].plot(history.history['loss'], label='Training Loss')
axes[0, 0].set_title('Training Loss')
axes[0, 0].set_xlabel('Epoch')
axes[0, 0].set_ylabel('Loss')
axes[0, 0].legend()
axes[0, 0].grid(True)
axes[0, 0].set_xlim([0, 50])  # Set x-axis limits

# Plot validation loss
axes[0, 1].plot(history.history['val_loss'], label='Validation Loss')
axes[0, 1].set_title('Validation Loss')
axes[0, 1].set_xlabel('Epoch')
axes[0, 1].set_ylabel('Loss')
axes[0, 1].legend()
axes[0, 1].grid(True)
axes[0, 1].set_xlim([0,50])  # Set x-axis limits

# Plot training accuracy
axes[0, 2].plot(history.history['acc'], label='Training Accuracy')
axes[0, 2].set_title('Training Accuracy')
axes[0, 2].set_xlabel('Epoch')
axes[0, 2].set_ylabel('Accuracy')
axes[0, 2].legend()
axes[0, 2].grid(True)
axes[0, 2].set_xlim([0,50])  # Set x-axis limits

# Plot validation accuracy
axes[1, 0].plot(history.history['val_acc'], label='Validation Accuracy')
axes[1, 0].set_title('Validation Accuracy')
axes[1, 0].set_xlabel('Epoch')
axes[1, 0].set_ylabel('Accuracy')
axes[1, 0].legend()
axes[1, 0].grid(True)
axes[1, 0].set_xlim([0,50])  # Set x-axis limits

# Plot training MSE (mean squared error)
axes[1, 1].plot(history.history['mse'], label='Training MSE')
axes[1, 1].set_title('Training MSE')
axes[1, 1].set_xlabel('Epoch')
axes[1, 1].set_ylabel('MSE')
axes[1, 1].legend()
axes[1, 1].grid(True)
axes[1, 1].set_xlim([0,50])  # Set x-axis limits

# Plot validation MSE
axes[1, 2].plot(history.history['val_mse'], label='Validation MSE')
axes[1, 2].set_title('Validation MSE')
axes[1, 2].set_xlabel('Epoch')
axes[1, 2].set_ylabel('MSE')
axes[1, 2].legend()
axes[1, 2].grid(True)
axes[1, 2].set_xlim([0,50])  # Set x-axis limits

plt.tight_layout()
plt.show()

# %% [markdown]
# **Model Prediction and Evaluation**

# %%
prediction=model.predict(held_images)
# Out:
# 8/8 [==============================] - 1s 169ms/step

# %%
prediction=np.argmax(prediction, axis=1)
prediction.shape
# Out:
# (253,)

# %%
labels = train_images.class_indices
labels = {v: k for k, v in labels.items()}

# %%
y_prediction = [labels.get(k) for k in prediction]
y_test = held_out["Quality"].values

# %% [markdown]
# **Accuracy Evaluation**

# %%
from sklearn.metrics import accuracy_score, classification_report
print(classification_report(y_test, y_prediction))
# Out:
#                   precision    recall  f1-score   support
#
#      bad_quality       1.00      0.99      0.99        96
# empty_background       1.00      1.00      1.00        50
#     good_quality       0.99      1.00      1.00       107
#
#         accuracy                           1.00       253
#        macro avg       1.00      1.00      1.00       253
#     weighted avg       1.00      1.00      1.00       253

# %%
accuracy_score(y_prediction, y_test)
# Out:
# 0.9960474308300395

# %% [markdown]
# **Confusion Matrix**

# %%
from sklearn.metrics import confusion_matrix

# %%
cm = confusion_matrix(y_test, y_prediction)

# Plot the confusion matrix as a heatmap
plt.figure(figsize=(10,8))
sns.heatmap(cm, annot=True, fmt="d", cmap="Greens")
plt.title("Confusion Matrix")
plt.xlabel("Predicted Labels")
plt.ylabel("Exact Labels")
plt.show()

# %% [markdown]
# # Visualizing Predicted Labels on Random Images

# %%
held_out.reset_index(drop=True, inplace=True)
held_out.head()
# Out:
#                                                Image           Quality
# 0  /kaggle/input/lemon-quality-dataset/lemon_data...  empty_background
# 1  /kaggle/input/lemon-quality-dataset/lemon_data...       bad_quality
# 2  /kaggle/input/lemon-quality-dataset/lemon_data...      good_quality
# 3  /kaggle/input/lemon-quality-dataset/lemon_data...       bad_quality
# 4  /kaggle/input/lemon-quality-dataset/lemon_data...      good_quality

# %%
random_index = np.random.randint(0, held_out.shape[0])
image_path = held_out.loc[random_index, "Image"]
predicted_label = y_prediction[random_index]

# %%
# Create a 2x5 grid of subplots
fig, axes = plt.subplots(2, 5, figsize=(12, 6))

# Iterate over the axes and randomly select 10 indices
for i, ax in enumerate(axes.flatten()):
    random_index = np.random.randint(0, held_out.shape[0])
    image_path = held_out.loc[random_index, "Image"]
    predicted_label = y_prediction[random_index]

    # Plot the image on the current subplot
    image = Image.open(image_path)
    ax.imshow(image)
    ax.axis('off')
    ax.set_title(predicted_label)

# Adjust spacing and display the plot
plt.tight_layout()
plt.show()

# %%
import tensorflow as tf

# %%
tf.keras.utils.plot_model(model, to_file='complex_model.png', show_shapes=True)
