# %%
import warnings

warnings.filterwarnings('ignore')

import tensorflow as tf
import pandas as pd
import nlpaug.augmenter.word as naw
import numpy as np
from transformers import BertTokenizer, TFBertForSequenceClassification
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from tensorflow.keras.utils import to_categorical
from gensim.models import Word2Vec
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Bidirectional
from sklearn.feature_extraction.text import TfidfVectorizer
import matplotlib.pyplot as plt
from collections import Counter

# %%
df = pd.read_csv('../Dataset/Autor_detection.csv')

# %% [markdown]
# # Preprocessing and EDA

# %%
print(df.head())
# Out:
#                                               Quotes      Writter name
# 0  Reading Kafka I sense that the elicited questi...  Alberto Manguel,
# 1  All animals are equal but some animals are mor...     George Orwell
# 2  I am old Gandalf I dont look it but I am begin...    J.R.R. Tolkien
# 3  How can we live without our lives How will we ...    John Steinbeck
# 4  I was only foolin George I dont want no ketchu...    John Steinbeck

# %%
df.describe()
# Out:
#                                                    Quotes Writter name
# count                                                1571         1578
# unique                                               1554           83
# top     The coward dies a thousand deaths the brave bu...  Jane Austen
# freq                                                    2          191

# %%
# Conversion to lowercase
df['Quotes'] = df['Quotes'].str.lower()
df['Writter name'] = df['Writter name'].str.lower()

# Removal of NaN values
df.dropna(inplace=True)

# Removal of Duplicate entries
df.drop_duplicates(inplace=True)

# Removal of extra commas in end of author name
df['Writter name'] = df['Writter name'].str.rstrip(',')

# Removal of \r and \n from the Quotes column of the dataframe
df['Quotes'] = df['Quotes'].str.replace('\r', '')
df['Quotes'] = df['Quotes'].str.replace('\n', '')

# Removal of extra spaces from the Quotes column of the dataframe
df['Quotes'] = df['Quotes'].str.strip()

# Removal of non-ascii characters from the Writter name column
df['Writter name'] = df['Writter name'].str.encode('ascii', 'ignore').str.decode('ascii')

# Encode author names into numerical labels
label_encoder = {author: label for label, author in enumerate(df['Writter name'].unique())}
df['label'] = df['Writter name'].map(label_encoder)

# %%
print(df['Writter name'].value_counts())
# Out:
# Writter name
# jane austen             187
# j.r.r. tolkien          156
# john steinbeck          147
# charles dickens         143
# william shakespeare     132
#                        ...
# gnther anders             1
# ernst pawel               1
# kafka franz               1
# hartmut m. rastalsky      1
# kurt vonnegut jr.         1
# Name: count, Length: 77, dtype: int64

# %%
# plot the number of samples in each class
plt.figure(figsize=(16,4))
df['Writter name'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Writter name'>

# %%
plt.figure(figsize=(16,4))
plt.hist([len(sample.split()) for sample in df['Quotes']], bins=50)
plt.xlabel('Length of samples')
plt.ylabel('Number of samples')
plt.title('Sample length distribution')
plt.show()

# %%
# Pie chart of top 20 words
top_5_words = Counter(" ".join(df['Quotes']).split()).most_common(20)
labels, values = zip(*top_5_words)
plt.pie(values, labels=labels, autopct='%1.1f%%', shadow=True, startangle=140)
plt.axis('equal')
plt.show()

# %% [markdown]
# ### So we have 1554 data points. Actually during training, it was discovered that 1554 data points is not enough to generate good performance. So Data Augmentation techniques are being used to increase the number of data points.

# %%
for i in range(2):
    aug = naw.SynonymAug(aug_src='wordnet')
    augmented_quotes = []
    for quote in df['Quotes']:
        augmented_quotes.append(str(aug.augment(quote)))
    augmented_df = pd.DataFrame({'Quotes': augmented_quotes, 'Writter name': df['Writter name'], 'label': df['label']})
    df = pd.concat([df, augmented_df], ignore_index=True)
    df['Quotes'] = df['Quotes'].str.replace('[', '')
    df['Quotes'] = df['Quotes'].str.replace(']', '')
    df['Quotes'] = df['Quotes'].str.replace("'", '')
    df.reset_index(inplace=True, drop=True)
    df = df.sample(frac=1).reset_index(drop=True)

# %%
df.describe()
# Out:
#              label
# count  6216.000000
# mean     10.228443
# std      10.497455
# min       0.000000
# 25%       4.000000
# 50%       8.000000
# 75%      13.000000
# max      76.000000

# %%
df
# Out:
#                                                  Quotes         Writter name  \
# 0     cunto la hemos hecho sufrir por tu forma de se...          franz kafka
# 1     the music of the pearl was pipe with victory i...       john steinbeck
# 2     melvil dewey dell rise heaving to her feet she...     william faulkner
# 3                 love all trust a few do wrong to none  william shakespeare
# 4     mr darcy soon drew the attention of the room b...          jane austen
# ...                                                 ...                  ...
# 6211  man is the only real foe we experience move ou...        george orwell
# 6212  at that place live nothing in the world so irr...      charles dickens
# 6213  feeling herself suddenly shriveled aged breast...       virginia woolf
# 6214  whole the missy in the earthly concern were di...          leo tolstoy
# 6215  windmill or no windmill lifespan would run on ...        george orwell
#
#       label
# 0        16
# 1         3
# 2        17
# 3        10
# 4         5
# ...     ...
# 6211      1
# 6212      8
# 6213     20
# 6214     13
# 6215      1
#
# [6216 rows x 3 columns]

# %% [markdown]
# # Model 1 : BERT

# %%
num_classes = len(label_encoder)

train_data, test_data = train_test_split(df, test_size=0.2, stratify=df['label'], random_state=42)

train_data, valid_data = train_test_split(train_data, test_size=0.1, stratify=train_data['label'], random_state=42)

tokenizer = BertTokenizer.from_pretrained("bert-base-uncased")
train_encodings = tokenizer(list(train_data['Quotes']), truncation=True, padding=True, max_length=128, return_tensors='tf')
test_encodings = tokenizer(list(test_data['Quotes']), truncation=True, padding=True, max_length=128, return_tensors='tf')
valid_encodings = tokenizer(list(valid_data['Quotes']), truncation=True, padding=True, max_length=128, return_tensors='tf')

train_dataset = tf.data.Dataset.from_tensor_slices((dict(train_encodings), to_categorical(train_data['label'], num_classes=num_classes)))
test_dataset = tf.data.Dataset.from_tensor_slices((dict(test_encodings), to_categorical(test_data['label'], num_classes=num_classes)))
valid_dataset = tf.data.Dataset.from_tensor_slices((dict(valid_encodings), to_categorical(valid_data['label'], num_classes=num_classes)))

model = TFBertForSequenceClassification.from_pretrained("bert-base-uncased", num_labels=num_classes)

optimizer = tf.keras.optimizers.Adam(learning_rate=2e-5)
loss = tf.keras.losses.CategoricalCrossentropy(from_logits=True)

model.compile(optimizer=optimizer, loss=loss, metrics=['accuracy'])

history = model.fit(train_dataset.shuffle(1000).batch(16), epochs=10, batch_size=16, validation_data=valid_dataset.shuffle(1000).batch(16))

results = model.evaluate(test_dataset.batch(16))
print("The accuracy on the test set is:", results[1] * 100)
# Out:
# 2024-01-09 23:36:32.231234: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M1 Pro
# 2024-01-09 23:36:32.231256: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 16.00 GB
# 2024-01-09 23:36:32.231260: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 5.33 GB
# 2024-01-09 23:36:32.231295: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-01-09 23:36:32.231314: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# All PyTorch model weights were used when initializing TFBertForSequenceClassification.
#
# Some weights or buffers of the TF 2.0 model TFBertForSequenceClassification were not initialized from the PyTorch model and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# Epoch 1/10
# 2024-01-09 23:36:46.289330: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:117] Plugin optimizer for device_type GPU is enabled.
# 2024-01-09 23:36:47.642130: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:961] model_pruner failed: INVALID_ARGUMENT: Graph does not contain terminal node Adam/AssignAddVariableOp_10.
# 280/280 [==============================] - 233s 757ms/step - loss: 3.1426 - accuracy: 0.1911 - val_loss: 2.5587 - val_accuracy: 0.3273
# Epoch 2/10
# 280/280 [==============================] - 194s 689ms/step - loss: 2.2090 - accuracy: 0.4222 - val_loss: 1.8454 - val_accuracy: 0.5442
# Epoch 3/10
# 280/280 [==============================] - 195s 694ms/step - loss: 1.3979 - accuracy: 0.6457 - val_loss: 1.2168 - val_accuracy: 0.6888
# Epoch 4/10
# 280/280 [==============================] - 192s 684ms/step - loss: 0.8004 - accuracy: 0.8230 - val_loss: 0.8056 - val_accuracy: 0.8173
# Epoch 5/10
# 280/280 [==============================] - 194s 691ms/step - loss: 0.4889 - accuracy: 0.9012 - val_loss: 0.6059 - val_accuracy: 0.8554
# Epoch 6/10
# 280/280 [==============================] - 194s 693ms/step - loss: 0.3302 - accuracy: 0.9334 - val_loss: 0.5058 - val_accuracy: 0.8916
# Epoch 7/10
# 280/280 [==============================] - 193s 688ms/step - loss: 0.2523 - accuracy: 0.9511 - val_loss: 0.5055 - val_accuracy: 0.8855
# Epoch 8/10
# 280/280 [==============================] - 193s 688ms/step - loss: 0.2029 - accuracy: 0.9624 - val_loss: 0.4118 - val_accuracy: 0.9076
# Epoch 9/10
# 280/280 [==============================] - 201s 715ms/step - loss: 0.1918 - accuracy: 0.9636 - val_loss: 0.4399 - val_accuracy: 0.8916
# Epoch 10/10
# 280/280 [==============================] - 196s 698ms/step - loss: 0.1551 - accuracy: 0.9754 - val_loss: 0.4034 - val_accuracy: 0.9076
# 78/78 [==============================] - 26s 330ms/step - loss: 0.3831 - accuracy: 0.9132
# The accuracy on the test set is: 91.31832718849182

# %% [markdown]
# # Model 2 : Word2Vec + RNN(LSTM)

# %%
train_texts, test_texts, train_labels, test_labels = train_test_split(
    df['Quotes'], df['label'], test_size=0.2, random_state=42
)

train_texts, val_texts, train_labels, val_labels = train_test_split(
    train_texts, train_labels, test_size=0.2, random_state=42
)

train_texts = [text.split() for text in train_texts]
test_texts = [text.split() for text in test_texts]
val_texts = [text.split() for text in val_texts]

word2vec_model = Word2Vec(sentences=train_texts, vector_size=100, window=5, min_count=1, workers=4)

max_len = 100
train_sequences = [[word2vec_model.wv[word] for word in text if word in word2vec_model.wv.key_to_index] for text in train_texts]
test_sequences = [[word2vec_model.wv[word] for word in text if word in word2vec_model.wv.key_to_index] for text in test_texts]
val_sequences = [[word2vec_model.wv[word] for word in text if word in word2vec_model.wv.key_to_index] for text in val_texts]

train_sequences_pad = pad_sequences(train_sequences, maxlen=max_len, dtype='float32')
test_sequences_pad = pad_sequences(test_sequences, maxlen=max_len, dtype='float32')
val_sequences_pad = pad_sequences(val_sequences, maxlen=max_len, dtype='float32')

model = Sequential()
model.add(Bidirectional(LSTM(228, return_sequences=True, input_shape=(max_len, 100))))
model.add(Dropout(0.3))
model.add(Bidirectional(LSTM(250, return_sequences=True)))
model.add(Dropout(0.3)) 
model.add(Bidirectional(LSTM(270, return_sequences=True)))
model.add(Dropout(0.3))
model.add(Bidirectional(LSTM(300))) 
model.add(Dropout(0.3)) 
model.add(Dense(len(df['Writter name'].unique()), activation='softmax'))

model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

history = model.fit(train_sequences_pad, train_labels, epochs=100, batch_size=64, validation_data=(val_sequences_pad, val_labels))

test_loss, test_accuracy = model.evaluate(test_sequences_pad, test_labels)
print(f"Test Accuracy: {test_accuracy * 100}")
# Out:
# Epoch 1/100
# 63/63 [==============================] - 37s 413ms/step - loss: 3.0705 - accuracy: 0.1179 - val_loss: 2.9325 - val_accuracy: 0.1337
# Epoch 2/100
# 63/63 [==============================] - 16s 256ms/step - loss: 2.8655 - accuracy: 0.1260 - val_loss: 2.8372 - val_accuracy: 0.1668
# Epoch 3/100
# 63/63 [==============================] - 16s 260ms/step - loss: 2.7832 - accuracy: 0.1531 - val_loss: 2.7922 - val_accuracy: 0.1769
# Epoch 4/100
# 63/63 [==============================] - 16s 250ms/step - loss: 2.7498 - accuracy: 0.1494 - val_loss: 2.7747 - val_accuracy: 0.1869
# Epoch 5/100
# 63/63 [==============================] - 17s 263ms/step - loss: 2.7004 - accuracy: 0.1634 - val_loss: 2.7416 - val_accuracy: 0.1779
# Epoch 6/100
# 63/63 [==============================] - 16s 260ms/step - loss: 2.6804 - accuracy: 0.1655 - val_loss: 2.7421 - val_accuracy: 0.1518
# Epoch 7/100
# 63/63 [==============================] - 16s 253ms/step - loss: 2.6499 - accuracy: 0.1634 - val_loss: 2.7728 - val_accuracy: 0.1709
# Epoch 8/100
# 63/63 [==============================] - 16s 248ms/step - loss: 2.6410 - accuracy: 0.1755 - val_loss: 2.7112 - val_accuracy: 0.1618
# Epoch 9/100
# 63/63 [==============================] - 16s 261ms/step - loss: 2.6247 - accuracy: 0.1727 - val_loss: 2.7108 - val_accuracy: 0.1668
# Epoch 10/100
# 63/63 [==============================] - 16s 251ms/step - loss: 2.5980 - accuracy: 0.1848 - val_loss: 2.6904 - val_accuracy: 0.1920
# Epoch 11/100
# 63/63 [==============================] - 16s 252ms/step - loss: 2.5893 - accuracy: 0.1858 - val_loss: 2.6923 - val_accuracy: 0.1879
# Epoch 12/100
# 63/63 [==============================] - 16s 257ms/step - loss: 2.5841 - accuracy: 0.1861 - val_loss: 2.6911 - val_accuracy: 0.1638
# Epoch 13/100
# 63/63 [==============================] - 16s 251ms/step - loss: 2.5854 - accuracy: 0.1871 - val_loss: 2.6593 - val_accuracy: 0.1709
# Epoch 14/100
# 63/63 [==============================] - 16s 246ms/step - loss: 2.5449 - accuracy: 0.1929 - val_loss: 2.6435 - val_accuracy: 0.1769
# Epoch 15/100
# 63/63 [==============================] - 16s 247ms/step - loss: 2.5279 - accuracy: 0.1921 - val_loss: 2.6318 - val_accuracy: 0.1899
# Epoch 16/100
# 63/63 [==============================] - 16s 249ms/step - loss: 2.5199 - accuracy: 0.1979 - val_loss: 2.6563 - val_accuracy: 0.1829
# Epoch 17/100
# 63/63 [==============================] - 15s 246ms/step - loss: 2.4973 - accuracy: 0.2062 - val_loss: 2.6734 - val_accuracy: 0.1538
# Epoch 18/100
# 63/63 [==============================] - 16s 247ms/step - loss: 2.4813 - accuracy: 0.2057 - val_loss: 2.6385 - val_accuracy: 0.1668
# Epoch 19/100
# 63/63 [==============================] - 16s 248ms/step - loss: 2.4697 - accuracy: 0.2054 - val_loss: 2.6102 - val_accuracy: 0.1889
# Epoch 20/100
# 63/63 [==============================] - 16s 247ms/step - loss: 2.4418 - accuracy: 0.2183 - val_loss: 2.6012 - val_accuracy: 0.2010
# Epoch 21/100
# 63/63 [==============================] - 16s 248ms/step - loss: 2.4240 - accuracy: 0.2167 - val_loss: 2.5817 - val_accuracy: 0.1819
# Epoch 22/100
# 63/63 [==============================] - 16s 248ms/step - loss: 2.3974 - accuracy: 0.2263 - val_loss: 2.6061 - val_accuracy: 0.1889
# Epoch 23/100
# 63/63 [==============================] - 16s 247ms/step - loss: 2.3894 - accuracy: 0.2349 - val_loss: 2.5732 - val_accuracy: 0.1879
# Epoch 24/100
# 63/63 [==============================] - 16s 249ms/step - loss: 2.4372 - accuracy: 0.2230 - val_loss: 2.6093 - val_accuracy: 0.1960
# Epoch 25/100
# 63/63 [==============================] - 16s 251ms/step - loss: 2.3843 - accuracy: 0.2343 - val_loss: 2.5652 - val_accuracy: 0.2000
# Epoch 26/100
# 63/63 [==============================] - 16s 251ms/step - loss: 2.3208 - accuracy: 0.2487 - val_loss: 2.5424 - val_accuracy: 0.2141
# Epoch 27/100
# 63/63 [==============================] - 16s 252ms/step - loss: 2.2825 - accuracy: 0.2693 - val_loss: 2.5639 - val_accuracy: 0.2040
# Epoch 28/100
# 63/63 [==============================] - 16s 248ms/step - loss: 2.2602 - accuracy: 0.2733 - val_loss: 2.5272 - val_accuracy: 0.2020
# Epoch 29/100
# 63/63 [==============================] - 15s 246ms/step - loss: 2.2265 - accuracy: 0.2841 - val_loss: 2.5479 - val_accuracy: 0.2050
# Epoch 30/100
# 63/63 [==============================] - 15s 246ms/step - loss: 2.2626 - accuracy: 0.2693 - val_loss: 2.4903 - val_accuracy: 0.2020
# Epoch 31/100
# 63/63 [==============================] - 15s 246ms/step - loss: 2.1513 - accuracy: 0.3005 - val_loss: 2.4901 - val_accuracy: 0.2141
# Epoch 32/100
# 63/63 [==============================] - 16s 251ms/step - loss: 2.1073 - accuracy: 0.3156 - val_loss: 2.4671 - val_accuracy: 0.2342
# Epoch 33/100
# 63/63 [==============================] - 16s 251ms/step - loss: 2.0507 - accuracy: 0.3372 - val_loss: 2.4549 - val_accuracy: 0.2452
# Epoch 34/100
# 63/63 [==============================] - 16s 253ms/step - loss: 1.9916 - accuracy: 0.3505 - val_loss: 2.4395 - val_accuracy: 0.2492
# Epoch 35/100
# 63/63 [==============================] - 16s 246ms/step - loss: 1.9530 - accuracy: 0.3719 - val_loss: 2.4557 - val_accuracy: 0.2533
# Epoch 36/100
# 63/63 [==============================] - 16s 252ms/step - loss: 1.8958 - accuracy: 0.3842 - val_loss: 2.4221 - val_accuracy: 0.2462
# Epoch 37/100
# 63/63 [==============================] - 16s 247ms/step - loss: 1.8387 - accuracy: 0.4026 - val_loss: 2.4356 - val_accuracy: 0.2583
# Epoch 38/100
# 63/63 [==============================] - 16s 253ms/step - loss: 1.7583 - accuracy: 0.4363 - val_loss: 2.4192 - val_accuracy: 0.2663
# Epoch 39/100
# 63/63 [==============================] - 16s 254ms/step - loss: 1.7213 - accuracy: 0.4405 - val_loss: 2.4335 - val_accuracy: 0.2633
# Epoch 40/100
# 63/63 [==============================] - 16s 257ms/step - loss: 1.6359 - accuracy: 0.4702 - val_loss: 2.4224 - val_accuracy: 0.2794
# Epoch 41/100
# 63/63 [==============================] - 16s 255ms/step - loss: 1.5788 - accuracy: 0.4911 - val_loss: 2.4078 - val_accuracy: 0.2905
# Epoch 42/100
# 63/63 [==============================] - 16s 257ms/step - loss: 1.5027 - accuracy: 0.5210 - val_loss: 2.4275 - val_accuracy: 0.3025
# Epoch 43/100
# 63/63 [==============================] - 16s 250ms/step - loss: 1.4294 - accuracy: 0.5371 - val_loss: 2.3628 - val_accuracy: 0.3106
# Epoch 44/100
# 63/63 [==============================] - 16s 250ms/step - loss: 1.3206 - accuracy: 0.5748 - val_loss: 2.3925 - val_accuracy: 0.3166
# Epoch 45/100
# 63/63 [==============================] - 16s 247ms/step - loss: 1.2463 - accuracy: 0.6035 - val_loss: 2.3554 - val_accuracy: 0.3307
# Epoch 46/100
# 63/63 [==============================] - 16s 248ms/step - loss: 1.1911 - accuracy: 0.6170 - val_loss: 2.3913 - val_accuracy: 0.3327
# Epoch 47/100
# 63/63 [==============================] - 16s 248ms/step - loss: 1.0790 - accuracy: 0.6558 - val_loss: 2.3829 - val_accuracy: 0.3638
# Epoch 48/100
# 63/63 [==============================] - 16s 248ms/step - loss: 1.0140 - accuracy: 0.6844 - val_loss: 2.4059 - val_accuracy: 0.3618
# Epoch 49/100
# 63/63 [==============================] - 16s 248ms/step - loss: 0.9236 - accuracy: 0.7161 - val_loss: 2.4695 - val_accuracy: 0.3538
# Epoch 50/100
# 63/63 [==============================] - 16s 248ms/step - loss: 0.8638 - accuracy: 0.7315 - val_loss: 2.4752 - val_accuracy: 0.3578
# Epoch 51/100
# 63/63 [==============================] - 16s 248ms/step - loss: 0.8078 - accuracy: 0.7460 - val_loss: 2.4562 - val_accuracy: 0.3719
# Epoch 52/100
# 63/63 [==============================] - 16s 247ms/step - loss: 0.6731 - accuracy: 0.7936 - val_loss: 2.5033 - val_accuracy: 0.3889
# Epoch 53/100
# 63/63 [==============================] - 16s 247ms/step - loss: 0.6303 - accuracy: 0.8036 - val_loss: 2.5267 - val_accuracy: 0.3899
# Epoch 54/100
# 63/63 [==============================] - 15s 246ms/step - loss: 0.5450 - accuracy: 0.8366 - val_loss: 2.5311 - val_accuracy: 0.4060
# Epoch 55/100
# 63/63 [==============================] - 16s 248ms/step - loss: 0.4989 - accuracy: 0.8544 - val_loss: 2.5457 - val_accuracy: 0.3970
# Epoch 56/100
# 63/63 [==============================] - 16s 247ms/step - loss: 0.4538 - accuracy: 0.8667 - val_loss: 2.5610 - val_accuracy: 0.4352
# Epoch 57/100
# 63/63 [==============================] - 16s 247ms/step - loss: 0.4171 - accuracy: 0.8823 - val_loss: 2.5856 - val_accuracy: 0.4211
# Epoch 58/100
# 63/63 [==============================] - 16s 248ms/step - loss: 0.3481 - accuracy: 0.9032 - val_loss: 2.6409 - val_accuracy: 0.4141
# Epoch 59/100
# 63/63 [==============================] - 16s 248ms/step - loss: 0.3285 - accuracy: 0.9082 - val_loss: 2.7458 - val_accuracy: 0.4171
# Epoch 60/100
# 63/63 [==============================] - 16s 247ms/step - loss: 0.2958 - accuracy: 0.9188 - val_loss: 2.7758 - val_accuracy: 0.4261
# Epoch 61/100
# 63/63 [==============================] - 16s 247ms/step - loss: 0.2474 - accuracy: 0.9309 - val_loss: 2.7794 - val_accuracy: 0.4281
# Epoch 62/100
# 63/63 [==============================] - 16s 248ms/step - loss: 0.2669 - accuracy: 0.9213 - val_loss: 2.8210 - val_accuracy: 0.4201
# Epoch 63/100
# 63/63 [==============================] - 16s 248ms/step - loss: 0.2559 - accuracy: 0.9281 - val_loss: 2.9072 - val_accuracy: 0.4070
# Epoch 64/100
# 63/63 [==============================] - 16s 247ms/step - loss: 0.2946 - accuracy: 0.9138 - val_loss: 2.8521 - val_accuracy: 0.4221
# Epoch 65/100
# 63/63 [==============================] - 16s 247ms/step - loss: 0.2153 - accuracy: 0.9439 - val_loss: 2.7957 - val_accuracy: 0.4342
# Epoch 66/100
# 63/63 [==============================] - 16s 249ms/step - loss: 0.1842 - accuracy: 0.9517 - val_loss: 2.8445 - val_accuracy: 0.4573
# Epoch 67/100
# 63/63 [==============================] - 16s 247ms/step - loss: 0.1437 - accuracy: 0.9640 - val_loss: 2.8889 - val_accuracy: 0.4492
# Epoch 68/100
# 63/63 [==============================] - 16s 248ms/step - loss: 0.1239 - accuracy: 0.9716 - val_loss: 2.9571 - val_accuracy: 0.4593
# Epoch 69/100
# 63/63 [==============================] - 16s 247ms/step - loss: 0.1165 - accuracy: 0.9713 - val_loss: 2.9868 - val_accuracy: 0.4492
# Epoch 70/100
# 63/63 [==============================] - 16s 248ms/step - loss: 0.0970 - accuracy: 0.9786 - val_loss: 2.9738 - val_accuracy: 0.4683
# Epoch 71/100
# 63/63 [==============================] - 16s 247ms/step - loss: 0.0924 - accuracy: 0.9779 - val_loss: 3.0541 - val_accuracy: 0.4462
# Epoch 72/100
# 63/63 [==============================] - 16s 246ms/step - loss: 0.1207 - accuracy: 0.9693 - val_loss: 3.0755 - val_accuracy: 0.4503
# Epoch 73/100
# 63/63 [==============================] - 15s 246ms/step - loss: 0.0873 - accuracy: 0.9776 - val_loss: 3.1037 - val_accuracy: 0.4643
# Epoch 74/100
# 63/63 [==============================] - 16s 247ms/step - loss: 0.0785 - accuracy: 0.9814 - val_loss: 3.0782 - val_accuracy: 0.4683
# Epoch 75/100
# 63/63 [==============================] - 16s 246ms/step - loss: 0.0838 - accuracy: 0.9804 - val_loss: 3.1297 - val_accuracy: 0.4653
# Epoch 76/100
# 63/63 [==============================] - 16s 247ms/step - loss: 0.0721 - accuracy: 0.9832 - val_loss: 3.1816 - val_accuracy: 0.4643
# Epoch 77/100
# 63/63 [==============================] - 16s 246ms/step - loss: 0.0874 - accuracy: 0.9766 - val_loss: 3.1538 - val_accuracy: 0.4603
# Epoch 78/100
# 63/63 [==============================] - 16s 246ms/step - loss: 0.0934 - accuracy: 0.9756 - val_loss: 3.1637 - val_accuracy: 0.4472
# Epoch 79/100
# 63/63 [==============================] - 16s 247ms/step - loss: 0.1137 - accuracy: 0.9716 - val_loss: 3.2416 - val_accuracy: 0.4563
# Epoch 80/100
# 63/63 [==============================] - 16s 247ms/step - loss: 0.0928 - accuracy: 0.9721 - val_loss: 3.3256 - val_accuracy: 0.4503
# Epoch 81/100
# 63/63 [==============================] - 16s 247ms/step - loss: 0.0925 - accuracy: 0.9741 - val_loss: 3.1658 - val_accuracy: 0.4432
# Epoch 82/100
# 63/63 [==============================] - 16s 247ms/step - loss: 0.1702 - accuracy: 0.9485 - val_loss: 3.1253 - val_accuracy: 0.4543
# Epoch 83/100
# 63/63 [==============================] - 15s 245ms/step - loss: 0.1069 - accuracy: 0.9711 - val_loss: 3.2109 - val_accuracy: 0.4693
# Epoch 84/100
# 63/63 [==============================] - 16s 248ms/step - loss: 0.0973 - accuracy: 0.9761 - val_loss: 3.2255 - val_accuracy: 0.4553
# Epoch 85/100
# 63/63 [==============================] - 16s 248ms/step - loss: 0.0940 - accuracy: 0.9746 - val_loss: 3.2125 - val_accuracy: 0.4633
# Epoch 86/100
# 63/63 [==============================] - 16s 248ms/step - loss: 0.0616 - accuracy: 0.9859 - val_loss: 3.2123 - val_accuracy: 0.4663
# Epoch 87/100
# 63/63 [==============================] - 16s 248ms/step - loss: 0.0452 - accuracy: 0.9894 - val_loss: 3.2319 - val_accuracy: 0.4724
# Epoch 88/100
# 63/63 [==============================] - 16s 247ms/step - loss: 0.0476 - accuracy: 0.9882 - val_loss: 3.2931 - val_accuracy: 0.4693
# Epoch 89/100
# 63/63 [==============================] - 16s 249ms/step - loss: 0.0662 - accuracy: 0.9862 - val_loss: 3.2495 - val_accuracy: 0.4764
# Epoch 90/100
# 63/63 [==============================] - 16s 247ms/step - loss: 0.0521 - accuracy: 0.9869 - val_loss: 3.2556 - val_accuracy: 0.4754
# Epoch 91/100
# 63/63 [==============================] - 16s 248ms/step - loss: 0.0602 - accuracy: 0.9839 - val_loss: 3.2920 - val_accuracy: 0.4804
# Epoch 92/100
# 63/63 [==============================] - 16s 247ms/step - loss: 0.0553 - accuracy: 0.9857 - val_loss: 3.2708 - val_accuracy: 0.4814
# Epoch 93/100
# 63/63 [==============================] - 16s 248ms/step - loss: 0.0628 - accuracy: 0.9824 - val_loss: 3.2864 - val_accuracy: 0.4714
# Epoch 94/100
# 63/63 [==============================] - 16s 247ms/step - loss: 0.0442 - accuracy: 0.9902 - val_loss: 3.3408 - val_accuracy: 0.4844
# Epoch 95/100
# 63/63 [==============================] - 16s 248ms/step - loss: 0.0555 - accuracy: 0.9844 - val_loss: 3.3638 - val_accuracy: 0.4724
# Epoch 96/100
# 63/63 [==============================] - 16s 246ms/step - loss: 0.0494 - accuracy: 0.9874 - val_loss: 3.4807 - val_accuracy: 0.4623
# Epoch 97/100
# 63/63 [==============================] - 15s 246ms/step - loss: 0.0928 - accuracy: 0.9738 - val_loss: 3.3615 - val_accuracy: 0.4623
# Epoch 98/100
# 63/63 [==============================] - 16s 247ms/step - loss: 0.0605 - accuracy: 0.9832 - val_loss: 3.4357 - val_accuracy: 0.4633
# Epoch 99/100
# 63/63 [==============================] - 16s 246ms/step - loss: 0.0364 - accuracy: 0.9907 - val_loss: 3.4037 - val_accuracy: 0.4693
# Epoch 100/100
# 63/63 [==============================] - 16s 247ms/step - loss: 0.0646 - accuracy: 0.9806 - val_loss: 3.4780 - val_accuracy: 0.4693
# 39/39 [==============================] - 4s 98ms/step - loss: 3.1927 - accuracy: 0.5000
# Test Accuracy: 50.0

# %% [markdown]
# # Model 3 : TF-IDF + Softmax Regression

# %%
X_train, X_test, y_train, y_test = train_test_split(df['Quotes'], df['label'], test_size=0.2, random_state=42)

X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=42)

tfidf_vectorizer = TfidfVectorizer()
X_train_tfidf = tfidf_vectorizer.fit_transform(X_train)
X_test_tfidf = tfidf_vectorizer.transform(X_test)
X_val_tfidf = tfidf_vectorizer.transform(X_val)

model = Sequential()
model.add(Dense(128, activation='relu', input_shape=(X_train_tfidf.shape[1],)))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(len(label_encoder), activation='softmax'))

model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

history = model.fit(X_train_tfidf.toarray(), y_train, validation_data=(X_val_tfidf.toarray(), y_val), epochs=10, batch_size=32)

loss, accuracy = model.evaluate(X_test_tfidf.toarray(), y_test)
print(f"Test Accuracy: {accuracy * 100}")
# Out:
# Epoch 1/10
# 125/125 [==============================] - 3s 20ms/step - loss: 3.4966 - accuracy: 0.1026 - val_loss: 2.9673 - val_accuracy: 0.1276
# Epoch 2/10
# 125/125 [==============================] - 1s 11ms/step - loss: 2.8166 - accuracy: 0.1637 - val_loss: 2.7052 - val_accuracy: 0.3136
# Epoch 3/10
# 125/125 [==============================] - 2s 13ms/step - loss: 2.3586 - accuracy: 0.3515 - val_loss: 2.2311 - val_accuracy: 0.4533
# Epoch 4/10
# 125/125 [==============================] - 1s 11ms/step - loss: 1.6606 - accuracy: 0.5831 - val_loss: 1.6559 - val_accuracy: 0.6432
# Epoch 5/10
# 125/125 [==============================] - 1s 10ms/step - loss: 1.0278 - accuracy: 0.7795 - val_loss: 1.2236 - val_accuracy: 0.7658
# Epoch 6/10
# 125/125 [==============================] - 1s 10ms/step - loss: 0.6216 - accuracy: 0.8846 - val_loss: 0.9526 - val_accuracy: 0.8161
# Epoch 7/10
# 125/125 [==============================] - 1s 10ms/step - loss: 0.4033 - accuracy: 0.9324 - val_loss: 0.8034 - val_accuracy: 0.8362
# Epoch 8/10
# 125/125 [==============================] - 1s 11ms/step - loss: 0.2822 - accuracy: 0.9552 - val_loss: 0.6931 - val_accuracy: 0.8563
# Epoch 9/10
# 125/125 [==============================] - 1s 10ms/step - loss: 0.2166 - accuracy: 0.9650 - val_loss: 0.6261 - val_accuracy: 0.8673
# Epoch 10/10
# 125/125 [==============================] - 1s 10ms/step - loss: 0.1694 - accuracy: 0.9713 - val_loss: 0.5804 - val_accuracy: 0.8693
# 39/39 [==============================] - 0s 7ms/step - loss: 0.5917 - accuracy: 0.8658
# Test Accuracy: 86.57556176185608
